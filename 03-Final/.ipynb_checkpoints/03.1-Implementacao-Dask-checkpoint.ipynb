# %% [markdown]
# # Implementacão - Dask
#
# ## Detalhes
#
# 1. Gestão de Dados
# - Dask não herda variáveis globais via Copy-on-Write (fork) da mesma forma transparente que o *multiprocessing*.
# - Os daods precisam ser movidos epxlicitamente
# - É necessário utilizar *client.scatter* para enviar as matrizes aos workers de forma eficiente.
# - Usando client.scatter, os dadossão enviados uma única vez para a memória distribuída do cluster, e os workers acessam essa referência. Isso adiciona um overhead de comunicação que não existia no script original.
#
# 2. Scheduler e Workers
# - O Dask sobe um Scheduler (agendador) e Workers (trabalhadores).
# - Os workers são processos "daemon" de longa duração que ficam aguardando instruções via protocolo TCP (mesmo localmente).
# - Eles não "herdam" o estado do script principal da mesma forma simples.
# - O Dask serializa (empacota com pickle ou cloudpickle) **a função e os dados** e os envia via rede/socket para o worker.
#
# 3. Vantagens de utilizar Dask
# - Multi-Node: Dask consegue executar programas utilizando usando múltiplas CPUs (múltiplos nodos) de diferentes computadores da rede. O multiprocessing não faz isso; o Dask faz transparentemente (basta apontar o IP do scheduler).
# - Matrizes Gigantes (Out-of-Core): Se MATRIX_SIZE fosse 50.000 e não coubesse na RAM o comando *dask.array* quebraria a matriz em pedaços menores e carregaria do disco sob demanda.
#
# ## Dashboard
#
# - O Dask oferece um dashboard web (porta 8787) para visualizar o uso de CPU/Memória em tempo real.
# - Dashboard: http://127.0.0.1:8787
# - Dependência:
#
# ```bash
# pip install "bokeh!=3.0.*,>=2.4.2" --proxy "http://proxy.tjrs.gov.br:8080"
# ```
#
# ## Funcinamento do script
#
# 1. **O Cluster Dask** (*LocalCluster* e *Client*)
#
# ```python
# with LocalCluster(n_workers=len(cores), threads_per_worker=1, processes=True...) as cluster:
#     with Client(cluster) as client:
# ```
#
# - **LocalCluster**: Cria um "mini datacenter" dentro do seu computador.
# - **processes=True**: Em Python, threads normais não rodam em paralelo real (devido ao GIL). Ao usar processos, cada worker é um programa Python independente com sua própria memória.
# - **threads_per_worker=1**: Reforça que cada worker é puramente single-threaded. Isso é ideal para tarefas CPU-bound (matemática pesada), pois evita a troca de contexto desnecessária.
#
# 2. Compartilhamento de dados com *client.scatter*
#
# ```python
# A_future = client.scatter(A_host, broadcast=True)
# B_future = client.scatter(B_host, broadcast=True)
# ```
#
# - Em bibliotecas comuns (multiprocessing), ao enviar dados para um processo filho, o Python precisa "serializar" (pickle) e copiar os dados. Se a matriz possui 1GB e existem 8 workers, são copiados 8GB de dados, saturando a RAM.
# - Ao utilziar *scatter* a matriz é enviada para a memória dos workers antes da computação começar (memória compartilhada).
# - É retornado um *Future* (uma espécie de "ticket" ou ponteiro).
# - Os workers acessam os dados pelo "ticket", sem necessidade de copiar a matriz inteira novamente. Ao utilizar *broadcast=True*, todos os workers já têm uma cópia da matriz B e do pedaço de A prontos em suas memórias locais.

# %% [markdown]
# ## Versão do Python
#
# - O Python 3.12 deve ser executado para o script Dask.
#
# 1. Verificar com *pyenv* as versões
#
# ```bash
# pyenv versions
# ```
#
# 2. Para instalar o Python 3.12 no *pyenv*. Ao selecionar a versão 3.12, acabou instalado o Python 3.12.12
#
# ```bash
# pyenv install 3.12
# ```
#
# 3. Versão global: selecionar a versão 3.12.12
# - Isto define a versão padrão para todos os shells e diretórios, a menos que uma versão local ou shell a substitua.
#
# ```bash
# pyenv global 3.12.12
# ```
#
# 4. Nível Shell (Temporário)
# - Isto define a versão apenas para a sessão atual do terminal. É temporário e se reverte ao fechar o terminal.
#
#
# ```bash
# pyenv shell 3.12.12
# ```

# %% [markdown]
# ## Execução do Jupyer Notebook
#
# ```python
# # -----------------------------------------------------------
# # CONFIGURAÇÃO CRÍTICA DE THREADS (BLAS/NUMPY)
# # Deve vir ANTES de importar numpy ou dask
# # -----------------------------------------------------------
# os.environ["OMP_NUM_THREADS"] = "1"
# os.environ["MKL_NUM_THREADS"] = "1"
# os.environ["OPENBLAS_NUM_THREADS"] = "1"
# os.environ["VECLIB_MAXIMUM_THREADS"] = "1"
# os.environ["NUMEXPR_NUM_THREADS"] = "1"
# # -----------------------------------------------------------
# ```
#
# ### Comando Bash
#
# ```bash
# OMP_NUM_THREADS=1 MKL_NUM_THREADS=1 VECLIB_MAXIMUM_THREADS=1 OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 jupyter notebook
# ```
#
# - Isso garante que o teste (P-cores vs E-cores) seja cientificamente preciso e que **1 Worker = 1 Núcleo = 1 Thread**.
#
# - Essa é a maneira **mais segura e robusta** de garantir o comportamento desejado.
#
# - Ao iniciar o Jupyter dessa forma, são definidas as variáveis de ambiente no processo pai (o servidor do Notebook). Por padrão, em sistemas Linux/Unix:
#     - O **Jupyter Notebook** herda essas variáveis.
#     - O **Kernel do Python** (onde o script executa) é filho do Jupyter e herda dele.
#     - Os **Workers do Dask** (*LocalCluster*) são filhos do Kernel e herdam dele.
#     - O **NumPy/BLAS** (carregado dentro dos workers) lê as variáveis de ambiente na hora da importação.

# %%
import os
import numpy as np

# 1. Verificar se a variável existe no ambiente do Kernel
print(f"OMP_NUM_THREADS: {os.environ.get('OMP_NUM_THREADS')}")
print(f"OPENBLAS_NUM_THREADS: {os.environ.get('OPENBLAS_NUM_THREADS')}")
# Out:
# OMP_NUM_THREADS: 1
# OPENBLAS_NUM_THREADS: 1

# %% [markdown]
# ## Confirmação de versão do Python em uso

# %%
import sys
print(sys.version_info)
# Out:
# sys.version_info(major=3, minor=14, micro=0, releaselevel='final', serial=0)

# %%
import psutil
import getpass
import os
import sys
import time
import numpy as np
import pandas as pd
from datetime import datetime
from dask.distributed import Client, LocalCluster

# --------------------------------------
# CONFIGURATION
MATRIX_SIZE = 2000
CPU_SETS = {   
    "8P_HT_OFF": [0, 2, 4, 6, 8, 10, 12, 14], # p-cores (8 cores, 1 thread per core)
    "4P_HT_ON": [0, 1, 2, 3, 4, 5, 6, 7], # p-cores (4 cores, 2 threads per core)
    "4P_4E_HT_OFF": [0, 2, 4, 6, 16, 17, 18, 19], # p-cores e e-cores (4 cores p-core, 4 cores e-core)
    "8E": [16, 17, 18, 19, 20, 21, 22, 23] # e-cores (8 cores, 1 thread per core)
}
NUM_RUNS = 5
GOVERNOR = "performance"
IDLE_TIME = 5

# --------------------------------------
# Helper Functions (Governor & Safety)
def safety_check(cpu_ids):
    if MATRIX_SIZE % len(cpu_ids) != 0:
        print(f"Error: MATRIX_SIZE ({MATRIX_SIZE}) not divisible by workers ({len(cpu_ids)}).")
        sys.exit(1)

def set_governor(governor: str):
    """
    Altera o CPU governor de todos os núcleos para o valor especificado.

    Parâmetros:
        governor (str): nome do governor (ex.: "performance", "powersave", "schedutil").
    """
    password = getpass.getpass("Sudo password: ")

    # Interpolamos o valor do parâmetro governor dirTempetamente no comando bash
    bash_command = f"""
    for cpu_file in $(ls -v /sys/devices/system/cpu/cpu*/cpufreq/scaling_governor); do
        cpu_name=$(basename $(dirname $(dirname $cpu_file)))
        
        echo "{governor}" | sudo tee $cpu_file > /dev/null
        
        current_gov=$(cat $cpu_file)
        #echo "$cpu_name: $current_gov"
    done
    """

    # Usa sudo -S para aceitar senha via stdin
    command = f'echo "{password}" | sudo -S bash -c \'{bash_command}\''
    os.system(command)   

def get_governor(cpu_id):
    path = f"/sys/devices/system/cpu/cpu{cpu_id}/cpufreq/scaling_governor"
    try:
        with open(path) as f: return f.read().strip()
    except FileNotFoundError: return "N/A"

# --------------------------------------
# Worker Task Adaptada para Dask
def worker_task_dask(args):
    """
    Recebe os dados explicitamente (A e B são referências scatter do Dask).
    """
    row_index, chunk_size, cpu_ids, A_matrix, B_matrix = args
    
    # Identificação rudimentar do worker baseada no chunk (assumindo ordem)
    # Em Dask, isso é menos determinístico, mas funciona se tasks == workers
    worker_id = row_index // chunk_size 
    target_cpu = cpu_ids[worker_id % len(cpu_ids)]

    # Define afinidade
    p = psutil.Process(os.getpid())
    p.cpu_affinity([target_cpu])
    
    # Fatia a matriz A localmente
    start_row = row_index
    end_row = row_index + chunk_size
    A_chunk = A_matrix[start_row:end_row, :]

    # -------------------------------------------------------------------------
    # LER A AFINIDADE REGISTRADA PELO SISTEMA
    # p.cpu_affinity() sem argumentos retorna a lista de cores restritos
    
    # O Dask worker é um processo, então esperamos que a lista tenha apenas um elemento
    #registered_cores = p.cpu_affinity() 
    
    # Usamos [0] para obter o ID do núcleo
    #system_core = registered_cores[0] if registered_cores else "N/A"
    
    #print(f"Worker PID: {os.getpid()} | Core Definido (target_cpu): {target_cpu} | Core REGISTRADO pelo Sistema: {system_core}")
    # -------------------------------------------------------------------------
    
    # Cálculo
    return np.dot(A_chunk, B_matrix)

# --------------------------------------
# Main Execution
if __name__ == "__main__":
    # print("Passo 1: Configurar governor")
    set_governor(GOVERNOR) # Descomente se tiver permissões sudo

    results = []
    print("Passo 2: Execuções com Dask")

    # Gerar dados
    A_host = np.random.rand(MATRIX_SIZE, MATRIX_SIZE).astype(np.float64)
    B_host = np.random.rand(MATRIX_SIZE, MATRIX_SIZE).astype(np.float64)
    
    for run in range(1, NUM_RUNS + 1):
        for label, cores in CPU_SETS.items():
            safety_check(cores)
            governor = get_governor(cores[0])            

            chunk_size = MATRIX_SIZE // len(cores)

            # -------------------------------------------------------
            # INÍCIO DO BLOCO DASK
            # Criamos um cluster local efêmero para simular o Pool
            # threads_per_worker=1 garante que é multiprocesso puro, não multithread
            # -------------------------------------------------------
            with LocalCluster(n_workers=len(cores), 
                              threads_per_worker=1, 
                              processes=True,
                              silence_logs=40) as cluster:
                
                with Client(cluster) as client:
                    # 1. SCATTER: Enviar dados para a memória comparitlhada dos workers
                    # Isso substitui a herança de memória global do fork()
                    # broadcast=True envia para todos os workers antecipadamente
                    A_future = client.scatter(A_host, broadcast=True)
                    B_future = client.scatter(B_host, broadcast=True)

                    # 2. PREPARAR TASKS
                    # Passamos os futures (A_future, B_future) ao invés dos dados crus
                    tasks_args = []
                    for i in range(len(cores)):
                        args = (i * chunk_size, chunk_size, cores, A_future, B_future)
                        tasks_args.append(args)

                    start_time = time.time()     
                        
                    # 3. SUBMIT & GATHER
                    # map envia as tarefas e retorna futures
                    futures = client.map(worker_task_dask, tasks_args)
                    
                    # gather bloqueia até terminar e traz os resultados
                    C_chunks = client.gather(futures)
                    
                    # 4. COMBINAR
                    C = np.vstack(C_chunks)
                    
                    end_time = time.time()
            # -------------------------------------------------------

            total_time = end_time - start_time
            
            # Validação de resultados
            #C_reference = np.matmul(A_host, B_host)
            #is_match = np.allclose(C, C_reference)
            #validacao_ok = "OK" if is_match else "FAIL"
            #print(f"  -> Validação: {validacao_ok}")
            
            results.append({
                "Run": run, "Scenario": label, "CPUs_used": cores,
                "Governor": governor, "Time_sec": total_time, "Result_shape": C.shape
            })
            print(f"Run {run} | Time: {total_time:.4f}s | {label}: {cores}")
            time.sleep(IDLE_TIME)

    df_results = pd.DataFrame(results)
    print("\nResumo Dask:\n", df_results[["Run", "Scenario", "Time_sec"]].sort_values(by="Scenario"))
    
    # cria dataframe com todos os resultados
    df_results = pd.DataFrame(results)
    pd.set_option('display.width', 1000) # Evita quebra de linha do print do df  
    df_reduced = df_results[["Run", "Scenario", "Governor", "Time_sec"]]
    df_sorted = df_reduced.sort_values(by="Scenario", ascending=False)
    print("\nResumo em DataFrame:\n", df_sorted)
    
    # salvar em CSV
    now = datetime.now()
    data_str = now.strftime("%Y%m%d") # formato aaaammdd
    hora_str = now.strftime("%H%M%S") # formato hhmmss
    filename = (
    f"experimentos02-dask/{data_str}_{hora_str}_matrix{MATRIX_SIZE}_"
        f"numruns{NUM_RUNS}_{GOVERNOR}.csv"
    )
    df_results.to_csv(filename, index=False)
    print(f"\nResultados salvos em: {filename}")
# Out:
# Sudo password: ········
# [sudo] senha para jgross:
# Passo 2: Execuções com Dask
# Run 1 | Time: 1.4230s | 8P_HT_OFF: [0, 2, 4, 6, 8, 10, 12, 14]
# Run 1 | Time: 1.4646s | 4P_HT_ON: [0, 1, 2, 3, 4, 5, 6, 7]
# Run 1 | Time: 1.4488s | 4P_4E_HT_OFF: [0, 2, 4, 6, 16, 17, 18, 19]
# Run 1 | Time: 1.4226s | 8E: [16, 17, 18, 19, 20, 21, 22, 23]
# Run 2 | Time: 1.5527s | 8P_HT_OFF: [0, 2, 4, 6, 8, 10, 12, 14]
# Run 2 | Time: 1.4520s | 4P_HT_ON: [0, 1, 2, 3, 4, 5, 6, 7]
# Run 2 | Time: 1.4410s | 4P_4E_HT_OFF: [0, 2, 4, 6, 16, 17, 18, 19]
# Run 2 | Time: 1.4743s | 8E: [16, 17, 18, 19, 20, 21, 22, 23]
# Run 3 | Time: 1.6094s | 8P_HT_OFF: [0, 2, 4, 6, 8, 10, 12, 14]
# Run 3 | Time: 1.4656s | 4P_HT_ON: [0, 1, 2, 3, 4, 5, 6, 7]
# Run 3 | Time: 1.4865s | 4P_4E_HT_OFF: [0, 2, 4, 6, 16, 17, 18, 19]
# Run 3 | Time: 1.5602s | 8E: [16, 17, 18, 19, 20, 21, 22, 23]
# Run 4 | Time: 1.5069s | 8P_HT_OFF: [0, 2, 4, 6, 8, 10, 12, 14]
# Run 4 | Time: 1.4540s | 4P_HT_ON: [0, 1, 2, 3, 4, 5, 6, 7]
# Run 4 | Time: 1.4950s | 4P_4E_HT_OFF: [0, 2, 4, 6, 16, 17, 18, 19]
# Run 4 | Time: 1.4646s | 8E: [16, 17, 18, 19, 20, 21, 22, 23]
# Run 5 | Time: 1.4671s | 8P_HT_OFF: [0, 2, 4, 6, 8, 10, 12, 14]
# Run 5 | Time: 1.4923s | 4P_HT_ON: [0, 1, 2, 3, 4, 5, 6, 7]
# Run 5 | Time: 1.4283s | 4P_4E_HT_OFF: [0, 2, 4, 6, 16, 17, 18, 19]
# Run 5 | Time: 1.6244s | 8E: [16, 17, 18, 19, 20, 21, 22, 23]
#
# Resumo Dask:
#      Run      Scenario  Time_sec
# 2     1  4P_4E_HT_OFF  1.448761
# 6     2  4P_4E_HT_OFF  1.440950
# 14    4  4P_4E_HT_OFF  1.495034
# 18    5  4P_4E_HT_OFF  1.428323
# 10    3  4P_4E_HT_OFF  1.486517
# 9     3      4P_HT_ON  1.465551
# 1     1      4P_HT_ON  1.464644
# 17    5      4P_HT_ON  1.492310
# 5     2      4P_HT_ON  1.451987
# 13    4      4P_HT_ON  1.454019
# 15    4            8E  1.464605
# 19    5            8E  1.624419
# 7     2            8E  1.474282
# 3     1            8E  1.422631
# 11    3            8E  1.560180
# 12    4     8P_HT_OFF  1.506904
# 8     3     8P_HT_OFF  1.609386
# 4     2     8P_HT_OFF  1.552660
# 16    5     8P_HT_OFF  1.467074
# 0     1     8P_HT_OFF  1.423008
#
# Resumo em DataFrame:
#      Run      Scenario     Governor  Time_sec
# 0     1     8P_HT_OFF  performance  1.423008
# 8     3     8P_HT_OFF  performance  1.609386
# 16    5     8P_HT_OFF  performance  1.467074
# 4     2     8P_HT_OFF  performance  1.552660
# 12    4     8P_HT_OFF  performance  1.506904
# 15    4            8E  performance  1.464605
# 11    3            8E  performance  1.560180
# 19    5            8E  performance  1.624419
# 7     2            8E  performance  1.474282
# 3     1            8E  performance  1.422631
# 9     3      4P_HT_ON  performance  1.465551
# 1     1      4P_HT_ON  performance  1.464644
# 5     2      4P_HT_ON  performance  1.451987
# 13    4      4P_HT_ON  performance  1.454019
# 17    5      4P_HT_ON  performance  1.492310
# 6     2  4P_4E_HT_OFF  performance  1.440950
# 14    4  4P_4E_HT_OFF  performance  1.495034
# 2     1  4P_4E_HT_OFF  performance  1.448761
# 18    5  4P_4E_HT_OFF  performance  1.428323
# 10    3  4P_4E_HT_OFF  performance  1.486517
#
# Resultados salvos em: experimentos02-dask/20251123_193053_matrix2000_numruns5_performance.csv

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Supondo que seus arquivos estejam em CSV
df1 = pd.read_csv('experimentos03_dask_native_affinity/20251123_194703_matrix2000.csv') # Com Turbo Bost
#df2 = pd.read_csv('20251111_170848_matrix1000_numruns5_performance.csv') 

df1['Dataset'] = 'TB-ON'
#df2['Dataset'] = '-'

#df_combined = pd.concat([df1, df2], ignore_index=True)

plt.figure(figsize=(10,6))
#sns.barplot(x='Scenario', y='Time_sec', hue='Dataset', data=df_combined, ci='sd')
sns.barplot(
    x='Scenario',
    y='Time_sec',
    hue='Dataset',
    data=df1,
    estimator='mean'       # calcula a média automaticamente
    #errorbar='sd'           # mostra desvio padrão
)
plt.title('Comparação de Tempo de Execução por Cenário (média ± desvio padrão)')
plt.ylabel('Tempo (segundos)')
plt.xlabel('Cenário')
plt.legend(title='Observações')

# Salvar como PDF
#plt.savefig('grafico_time_sec.pdf', format='pdf', bbox_inches='tight')

# Salvar como PNG
plt.savefig('grafico_time_sec.png', format='png', dpi=300, bbox_inches='tight')

plt.show()

# %% [markdown]
# # Dask - sem afinidade de CPU
#
# - Dask nativo
# - Sem afinidade e CPU; o próprio scheduler do Dask aloca as tarefas para cada um dos 8 Workers, sem pré-estabelecer o núcleo de CPU
# - Utilziado comando nativo do Dask para muitiplicação de matrizes *da.matmul*

# %%
import getpass
import os
import sys
import time
import numpy as np
import pandas as pd
import dask.array as da
from datetime import datetime
from dask.distributed import Client, LocalCluster

# --------------------------------------
# CONFIGURATION
MATRIX_SIZE = 2000
N_WORKERS = 8           # Número fixo de workers solicitado
NUM_RUNS = 5
GOVERNOR = "performance"
IDLE_TIME = 5

# Configuração de Chunks para o Dask Array
# Dividimos a dimensão das linhas pelo número de workers para tentar balancear a carga
CHUNK_SIZE = MATRIX_SIZE // N_WORKERS 

# --------------------------------------
# Helper Functions (Governor)
def set_governor(governor: str):
    """
    Altera o CPU governor de todos os núcleos para o valor especificado.
    """
    try:
        password = getpass.getpass("Sudo password (para governor): ")
        
        # Interpolamos o valor do parâmetro governor diretamente no comando bash
        bash_command = f"""
        for cpu_file in $(ls -v /sys/devices/system/cpu/cpu*/cpufreq/scaling_governor); do
            echo "{governor}" | sudo tee $cpu_file > /dev/null
        done
        """
        command = f'echo "{password}" | sudo -S bash -c \'{bash_command}\''
        os.system(command)
        print(f"Governor definido para: {governor}")
    except Exception as e:
        print(f"Não foi possível definir o governor (talvez falte permissão): {e}")

def get_current_governor():
    # Lê apenas do primeiro núcleo para referência
    path = "/sys/devices/system/cpu/cpu0/cpufreq/scaling_governor"
    try:
        with open(path) as f: return f.read().strip()
    except FileNotFoundError: return "N/A"

# --------------------------------------
# Main Execution
if __name__ == "__main__":
    # 1. Configuração inicial
    # set_governor(GOVERNOR) # Descomente se quiser alterar o governor via script

    results = []
    print(f"Passo 1: Iniciando Dask com {N_WORKERS} workers e Matrizes {MATRIX_SIZE}x{MATRIX_SIZE}")
    print(f"Chunk Size definido: {CHUNK_SIZE} linhas por bloco (aprox)")

    # Criamos o cluster uma única vez ou recriamos a cada run? 
    # Para manter o isolamento similar ao script anterior, vamos criar aqui.
    # threads_per_worker=1 mantém o comportamento de multiprocesso puro.
    with LocalCluster(n_workers=N_WORKERS, 
                      threads_per_worker=1, 
                      processes=True,
                      silence_logs=40) as cluster:
        
        with Client(cluster) as client:
            print(f"Dask Client Dashboard: {client.dashboard_link}")

            # Gerar dados (no Host/Master)
            print("Gerando matrizes aleatórias...")
            A_host = np.random.rand(MATRIX_SIZE, MATRIX_SIZE).astype(np.float64)
            B_host = np.random.rand(MATRIX_SIZE, MATRIX_SIZE).astype(np.float64)
            
            for run in range(1, NUM_RUNS + 1):
                current_gov = get_current_governor()
                
                # -------------------------------------------------------
                # DASK NATIVE ARRAY OPERATIONS
                # -------------------------------------------------------

                # 1. Converter Numpy -> Dask Array
                # O parametro 'chunks' define como a matriz é quebrada.
                # (CHUNK_SIZE, MATRIX_SIZE) significa que cortamos em fatias horizontais (linhas)
                # mantendo todas as colunas inteiras, ideal para multiplicação A x B
                dask_A = da.from_array(A_host, chunks=(CHUNK_SIZE, MATRIX_SIZE))
                dask_B = da.from_array(B_host, chunks=(MATRIX_SIZE, CHUNK_SIZE))

                start_time = time.time()
                
                # 2. Definir a operação (Preguiçosa/Lazy)
                # da.matmul é a função nativa de álgebra linear do Dask
                result_lazy = da.matmul(dask_A, dask_B)

                # 3. Executar (Compute)
                # Isso dispara o grafo de tarefas para os 8 workers
                C = result_lazy.compute()

                end_time = time.time()
                # -------------------------------------------------------

                total_time = end_time - start_time
                
                results.append({
                    "Run": run, 
                    "Scenario": f"Dask_Native_{N_WORKERS}Workers", 
                    "Workers": N_WORKERS,
                    "Governor": current_gov, 
                    "Time_sec": total_time, 
                    "Result_shape": C.shape
                })
                
                print(f"Run {run} | Time: {total_time:.4f}s | Workers: {N_WORKERS}")
                
                # Pausa para resfriamento/estabilização
                time.sleep(IDLE_TIME)

    # Consolidação dos resultados
    df_results = pd.DataFrame(results)
    
    # Exibir resumo
    print("\nResumo Dask Nativo:\n", df_results[["Run", "Time_sec"]])
    
    # Salvar CSV
    now = datetime.now()
    data_str = now.strftime("%Y%m%d")
    hora_str = now.strftime("%H%M%S")
    filename = (
        f"experimentos02-dask_native/{data_str}_{hora_str}_matrix{MATRIX_SIZE}_"
        f"numruns{NUM_RUNS}_{GOVERNOR}.csv"
    )
    
    # Garantir que diretório existe
    os.makedirs(os.path.dirname(filename), exist_ok=True)
    
    df_results.to_csv(filename, index=False)
    print(f"\nResultados salvos em: {filename}")
# Out:
# Passo 1: Iniciando Dask com 8 workers e Matrizes 2000x2000
# Chunk Size definido: 250 linhas por bloco (aprox)
# Dask Client Dashboard: http://127.0.0.1:8787/status
# Gerando matrizes aleatórias...
# /usr/lib/python3/dist-packages/distributed/client.py:3162: UserWarning: Sending large graph of size 61.04 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# Run 1 | Time: 0.9447s | Workers: 8
# /usr/lib/python3/dist-packages/distributed/client.py:3162: UserWarning: Sending large graph of size 61.04 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# Run 2 | Time: 0.7739s | Workers: 8
# /usr/lib/python3/dist-packages/distributed/client.py:3162: UserWarning: Sending large graph of size 61.04 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# Run 3 | Time: 0.7771s | Workers: 8
# /usr/lib/python3/dist-packages/distributed/client.py:3162: UserWarning: Sending large graph of size 61.04 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# Run 4 | Time: 0.7560s | Workers: 8
# /usr/lib/python3/dist-packages/distributed/client.py:3162: UserWarning: Sending large graph of size 61.04 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# Run 5 | Time: 0.8298s | Workers: 8
#
# Resumo Dask Nativo:
#     Run  Time_sec
# 0    1  0.944652
# 1    2  0.773882
# 2    3  0.777101
# 3    4  0.755967
# 4    5  0.829764
#
# Resultados salvos em: experimentos02-dask_native/20251123_192752_matrix2000_numruns5_performance.csv

# %% [markdown]
# # Diferenças: Dask com CPU set vs. Dask nativo
#
# - Dask com CPU set:
#     - Script elaborado com afinidade de CPu para cada Worker
#     - Utiliza *np.dot(A_chunk, B_matrix)* para calcular partes da matriz final e *C = np.vstack(C_chunks)* para agregar os resultados de todos os workers.
#
# - Dask nativo:
#     - Não seta o núcleo de CPU que cada worker utiliza. Isso fica a cargo do Scheduler do Cluster Dask (transparente)
#     - Utiliza *da.matmul* para calcular a multiplicação das duas matrizes. A função faz a distribuição dos dados, computação fracionada em cada worker e agregação dos resultados.
#
# ## 1. "Black Box" vs. "White Box" (Otimização do Grafo)
# - **Seu script manual** (*client.map*): Para o Dask, a sua função *worker_task_dask* é uma **"caixa preta"**. O Dask não sabe que você está fazendo uma multiplicação de matrizes; ele apenas vê uma função Python genérica. Ele serializa (empacota) essa função, envia para o worker, o worker desempacota, roda o interpretador Python, chama o *psutil*, faz o slice manual e só então chama o NumPy.
#
# - **Dask Nativo** (*da.matmul*): O Dask **sabe** exatamente o que é essa operação. Ele *cria um grafo de tarefas otimizado especificamente para álgebra linear*. Ele evita o overhead de serializar funções Python customizadas pesadas e pula direto para as rotinas otimizadas de baixo nível.
#
#
# ## 2. O Custo das "System Calls" (Overhead do psutil)
# No seu script original, cada tarefa executa isto:
#
# ```python
# p = psutil.Process(os.getpid())
# p.cpu_affinity([target_cpu])
# ```
#
# Essa operação é uma **System Call** (chamada de sistema). O processo Python tem que parar, pedir ao Kernel do Linux para mudar sua afinidade, o Kernel aplica a mudança e devolve o controle. Em uma computação de 1.4 segundos, gastar alguns milissegundos conversando com o Kernel repetidamente em cada worker adiciona uma latência desnecessária. O Dask nativo não perde tempo negociando com o SO; ele apenas calcula.
#
#
# ## 3. Rigidez vs. Flexibilidade do SO
# Ao forçar a afinidade (*cpu_affinity*), você está lutando contra o escalonador do Linux:
#
# - **Cenário Manual**: Se você força o Worker 1 a usar o Core 0, mas o Core 0 de repente precisa processar uma interrupção de rede ou uma tarefa do sistema, o Worker 1 fica **parado** esperando o Core 0 liberar.
#
# - **Cenário Nativo**: O Dask deixa o Sistema Operacional decidir. Se o Core 0 estiver ocupado, o Linux move o processo instantaneamente para o Core 1 (que pode estar ocioso). Essa fluidez mantém a CPU em 100% de uso efetivo muito mais tempo.
#
#
# ## 4. Gestão de Memória e Slicing
# - **Manual**: Você passa *row_index* e *chunk_size* e faz o slice *A_chunk = A_matrix\[start:end\]* dentro do tempo de execução da tarefa. Isso envolve operações Python para calcular índices e criar visualizações de memória.
#
# - **Nativo**: O *dask.array* já possui a estrutura de blocos ("chunks") pré-calculada nos metadados. Quando a tarefa chega ao processador, o ponteiro de memória correto já está pronto para ser entregue ao BLAS (biblioteca matemática de C/Fortran), com quase zero interferência do Python.
#
#
# ## Resultado
#
# O script Dask nativo é mais rápido porque **remove o "middleware" Python**.
#
# Ele passa menos tempo gerenciando onde rodar e como cortar os dados, e mais tempo deixando as bibliotecas de C/C++ (que o NumPy/Dask usam internamente) fazerem a matemática pura.

# %% [markdown]
# # 3º Script: Dask compute com pool de núcleos
#
# - Script usa a velocidade do *da.matmul* nativo, mas restringe o Cluster inteiro a rodar apenas nos E-cores ou apenas nos P-cores (sem setar afinidade por worker individual, mas sim pelo processo pai)
#
# - O isolamento rigoroso de hardware (P-cores vs E-cores) é aplicado com o conceito de **Herança de Afinidade de Processo**.
#     - Isolamento Real: Ao definir a afinidade no processo **pai** antes do *fork*, o Kernel do Linux garante que nenhum worker escape dos núcleos designados. Um worker tentando usar 100% de CPU não vai "vazar" para um E-core se você definiu apenas P-cores.
#
#
# ## A Lógica da Solução
# Em sistemas Linux, quando um processo pai cria um processo filho (que é o que o *LocalCluster* faz ao criar workers), o filho **herda** a máscara de afinidade de CPU do pai.
#
# 1. **Antes** de iniciar o Cluster, o script principal define sua própria afinidade (ex: "Só posso usar os núcleos 16 a 23").
#
# 2. O script inicia o *LocalCluster*.
#
# 3. O Cluster lança 8 workers. Como o pai está restrito a um conjunto de núcleos, o sistema operacional obriga os 8 workers a nascerem e viverem apenas nesses núcleos.
#
# 4. **Resultado**: Você tem controle total do hardware sem precisar colocar código *psutil* lento dentro do loop de cálculo do Dask.
#
#
# ## Informações importantes
#
# Tecnicamente, ao definir *processes=True* e *threads_per_worker=1*:
#
# 1. **Dask Scheduler**: O Dask entende que cada worker só consegue lidar com **uma tarefa Python** por vez.
#
# 2. **Python**: Haverá 8 processos Python independentes rodando no SO.
#
# 3. **Concorrência**: O Dask não tentará fazer duas coisas ao mesmo tempo dentro do mesmo worker.

# %% [markdown]
# # 3º Script: Dask compute com pool de núcleos - Sem leitura de arquivo

# %%
import getpass
import os
import sys
import time
import psutil
import numpy as np
import pandas as pd
import dask.array as da
from datetime import datetime
from dask.distributed import Client, LocalCluster

# --------------------------------------
# CONFIGURATION
MATRIX_SIZE = 6000
CPU_SETS = {    
    "8P_HT_OFF": [0, 2, 4, 6, 8, 10, 12, 14], 
    "4P_HT_ON": [0, 1, 2, 3, 4, 5, 6, 7], 
    "4P_4E_HT_OFF": [0, 2, 4, 6, 16, 17, 18, 19], 
    "8E": [16, 17, 18, 19, 20, 21, 22, 23] 
}
NUM_RUNS = 5
GOVERNOR = "performance"
IDLE_TIME = 5
N_WORKERS = 8 # Mantendo fixo conforme solicitado

# --------------------------------------
# Helper Functions
def get_worker_info():
    """
    Esta função roda dentro de cada worker.
    Retorna o PID e o Núcleo (Core) que está sendo usado naquele instante.
    """
    import psutil
    import os
    p = psutil.Process(os.getpid())
    
    return {
        "pid": os.getpid(),
        # cpu_num() retorna o ID do núcleo físico/lógico onde o processo está rodando AGORA
        "core": p.cpu_num(), 
        # cpu_affinity() retorna a lista de núcleos PERMITIDOS para este worker
        "affinity": p.cpu_affinity() 
    }

def set_governor(governor: str):
    try:
        password = getpass.getpass("Sudo password (para governor): ")
        bash_command = f"""
        for cpu_file in $(ls -v /sys/devices/system/cpu/cpu*/cpufreq/scaling_governor); do
            echo "{governor}" | sudo tee $cpu_file > /dev/null
        done
        """
        command = f'echo "{password}" | sudo -S bash -c \'{bash_command}\''
        os.system(command)
        print(f"Governor definido para: {governor}")
    except Exception as e:
        print(f"Erro ao definir governor: {e}")

def get_current_governor(cpu_id=0):
    path = f"/sys/devices/system/cpu/cpu{cpu_id}/cpufreq/scaling_governor"
    try:
        with open(path) as f: return f.read().strip()
    except FileNotFoundError: return "N/A"

# --------------------------------------
# Main Execution
if __name__ == "__main__":
    # set_governor(GOVERNOR) # Descomente para ativar

    # Gerar dados uma única vez na memória principal
    print("Gerando matrizes no Host...")
    A_host = np.random.rand(MATRIX_SIZE, MATRIX_SIZE).astype(np.float64)
    B_host = np.random.rand(MATRIX_SIZE, MATRIX_SIZE).astype(np.float64)

    results = []

    # Loop pelos Cenários de CPU (P-cores, E-cores, etc)
    for label, cores in CPU_SETS.items():
        print(f"\n--- Iniciando Cenário: {label} ---")
        print(f"Restringindo processo Pai aos núcleos: {cores}")
        
        # 1. MÁGICA AQUI: Restringir o Processo Pai (Script Python atual)
        # Todos os processos filhos (Dask Workers) criados a seguir herdarão essa restrição.
        parent = psutil.Process(os.getpid())
        parent.cpu_affinity(cores)
        
        # Verificação de segurança
        chunk_size = MATRIX_SIZE // N_WORKERS
        
        # 2. Iniciar Cluster (Os workers nascerão "presos" aos núcleos definidos acima)
        # Recriamos o cluster a cada cenário para garantir que a nova afinidade seja aplicada
        with LocalCluster(n_workers=N_WORKERS, 
                          threads_per_worker=1, 
                          processes=True, # Obrigatório para herança de afinidade funcionar bem aqui
                          silence_logs=40) as cluster:
            
            with Client(cluster) as client:
                # Aquecimento opcional ou apenas info
                # print(f"Client pronto: {client.dashboard_link}")
                
                # --- SONDA: VERIFICAR ONDE OS WORKERS ESTÃO ---
                # client.run executa a função em TODOS os workers e retorna um dicionário
                workers_info = client.run(get_worker_info)
                
                print("\n[Status dos Workers]")
                for worker_addr, info in workers_info.items():
                    # Extraímos o IP/Porta ou apenas usamos um contador se preferir
                    print(f" -> Worker PID {info['pid']} | Core Atual: {info['core']:>2} | Afinidade: {info['affinity']}")
                print("-" * 60)
                # ----------------------------------------------
                
                for run in range(1, NUM_RUNS + 1):
                    # Coleta governor do primeiro núcleo do set atual para registro
                    gov_actual = get_current_governor(cores[0])
                    
                    start_time = time.time()

                    # ---------------------------------------------------
                    # OPERAÇÃO NATIVA DO DASK
                    # ---------------------------------------------------
                    
                    # Criação dos arrays distribuídos (Lazy)
                    # chunks=(CHUNK_SIZE, MATRIX_SIZE) -> divide em fatias horizontais
                    dask_A = da.from_array(A_host, chunks=(chunk_size, MATRIX_SIZE))
                    dask_B = da.from_array(B_host, chunks=(MATRIX_SIZE, chunk_size)) 
                    
                    # Multiplicação
                    result_lazy = da.matmul(dask_A, dask_B)
                    
                    # Computação (Dispara para os workers restritos)
                    C = result_lazy.compute()
                    
                    # ---------------------------------------------------
                    
                    end_time = time.time()
                    total_time = end_time - start_time
                    
                    print(f"Run {run} | {label} | Time: {total_time:.4f}s")
                    
                    results.append({
                        "Run": run,
                        "Scenario": label,
                        "CPUs_used": str(cores),
                        "Governor": gov_actual,
                        "Time_sec": total_time,
                        "Result_shape": C.shape
                    })
                    
                    time.sleep(IDLE_TIME)

    # Restaurar afinidade para todos os cores no final (opcional, boa prática)
    all_cores = list(range(psutil.cpu_count()))
    parent.cpu_affinity(all_cores)
    print("\nRestaurada afinidade para todos os núcleos.")

    # Salvar Resultados
    df_results = pd.DataFrame(results)
    print("\nResumo Final:\n", df_results.groupby("Scenario")["Time_sec"].mean())
    
    now = datetime.now()
    filename = f"experimentos03_dask_native_affinity/{now.strftime('%Y%m%d_%H%M%S')}_matrix{MATRIX_SIZE}.csv"
    os.makedirs(os.path.dirname(filename), exist_ok=True)
    df_results.to_csv(filename, index=False)
    print(f"Salvo em: {filename}")
# Out:
# Gerando matrizes no Host...
#
# --- Iniciando Cenário: 8P_HT_OFF ---
# Restringindo processo Pai aos núcleos: [0, 2, 4, 6, 8, 10, 12, 14]
#
# [Status dos Workers]
#  -> Worker PID 288589 | Core Atual:  0 | Afinidade: [0, 2, 4, 6, 8, 10, 12, 14]
#  -> Worker PID 288597 | Core Atual:  8 | Afinidade: [0, 2, 4, 6, 8, 10, 12, 14]
#  -> Worker PID 288609 | Core Atual: 10 | Afinidade: [0, 2, 4, 6, 8, 10, 12, 14]
#  -> Worker PID 288610 | Core Atual: 12 | Afinidade: [0, 2, 4, 6, 8, 10, 12, 14]
#  -> Worker PID 288585 | Core Atual: 14 | Afinidade: [0, 2, 4, 6, 8, 10, 12, 14]
#  -> Worker PID 288590 | Core Atual:  2 | Afinidade: [0, 2, 4, 6, 8, 10, 12, 14]
#  -> Worker PID 288605 | Core Atual:  0 | Afinidade: [0, 2, 4, 6, 8, 10, 12, 14]
#  -> Worker PID 288598 | Core Atual:  8 | Afinidade: [0, 2, 4, 6, 8, 10, 12, 14]
# ------------------------------------------------------------
# /usr/lib/python3/dist-packages/distributed/client.py:3162: UserWarning: Sending large graph of size 549.32 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# Run 1 | 8P_HT_OFF | Time: 40.3896s
# /usr/lib/python3/dist-packages/distributed/client.py:3162: UserWarning: Sending large graph of size 549.32 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# Run 2 | 8P_HT_OFF | Time: 42.3477s
# /usr/lib/python3/dist-packages/distributed/client.py:3162: UserWarning: Sending large graph of size 549.32 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# Run 3 | 8P_HT_OFF | Time: 51.3200s
# /usr/lib/python3/dist-packages/distributed/client.py:3162: UserWarning: Sending large graph of size 549.32 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# Run 4 | 8P_HT_OFF | Time: 52.0668s
# /usr/lib/python3/dist-packages/distributed/client.py:3162: UserWarning: Sending large graph of size 549.32 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# Run 5 | 8P_HT_OFF | Time: 52.4952s
#
# --- Iniciando Cenário: 4P_HT_ON ---
# Restringindo processo Pai aos núcleos: [0, 1, 2, 3, 4, 5, 6, 7]
#
# [Status dos Workers]
#  -> Worker PID 288932 | Core Atual:  4 | Afinidade: [0, 1, 2, 3, 4, 5, 6, 7]
#  -> Worker PID 288948 | Core Atual:  2 | Afinidade: [0, 1, 2, 3, 4, 5, 6, 7]
#  -> Worker PID 288936 | Core Atual:  3 | Afinidade: [0, 1, 2, 3, 4, 5, 6, 7]
#  -> Worker PID 288943 | Core Atual:  6 | Afinidade: [0, 1, 2, 3, 4, 5, 6, 7]
#  -> Worker PID 288926 | Core Atual:  0 | Afinidade: [0, 1, 2, 3, 4, 5, 6, 7]
#  -> Worker PID 288938 | Core Atual:  5 | Afinidade: [0, 1, 2, 3, 4, 5, 6, 7]
#  -> Worker PID 288927 | Core Atual:  1 | Afinidade: [0, 1, 2, 3, 4, 5, 6, 7]
#  -> Worker PID 288951 | Core Atual:  2 | Afinidade: [0, 1, 2, 3, 4, 5, 6, 7]
# ------------------------------------------------------------
# /usr/lib/python3/dist-packages/distributed/client.py:3162: UserWarning: Sending large graph of size 549.32 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# Run 1 | 4P_HT_ON | Time: 44.1149s
# /usr/lib/python3/dist-packages/distributed/client.py:3162: UserWarning: Sending large graph of size 549.32 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# Run 2 | 4P_HT_ON | Time: 43.9946s
# /usr/lib/python3/dist-packages/distributed/client.py:3162: UserWarning: Sending large graph of size 549.32 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# Run 3 | 4P_HT_ON | Time: 44.0084s
# /usr/lib/python3/dist-packages/distributed/client.py:3162: UserWarning: Sending large graph of size 549.32 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# Run 4 | 4P_HT_ON | Time: 43.8424s
# /usr/lib/python3/dist-packages/distributed/client.py:3162: UserWarning: Sending large graph of size 549.32 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# Run 5 | 4P_HT_ON | Time: 44.4406s
#
# --- Iniciando Cenário: 4P_4E_HT_OFF ---
# Restringindo processo Pai aos núcleos: [0, 2, 4, 6, 16, 17, 18, 19]
#
# [Status dos Workers]
#  -> Worker PID 289259 | Core Atual: 16 | Afinidade: [0, 2, 4, 6, 16, 17, 18, 19]
#  -> Worker PID 289233 | Core Atual: 17 | Afinidade: [0, 2, 4, 6, 16, 17, 18, 19]
#  -> Worker PID 289244 | Core Atual:  0 | Afinidade: [0, 2, 4, 6, 16, 17, 18, 19]
#  -> Worker PID 289249 | Core Atual:  6 | Afinidade: [0, 2, 4, 6, 16, 17, 18, 19]
#  -> Worker PID 289237 | Core Atual: 18 | Afinidade: [0, 2, 4, 6, 16, 17, 18, 19]
#  -> Worker PID 289256 | Core Atual:  2 | Afinidade: [0, 2, 4, 6, 16, 17, 18, 19]
#  -> Worker PID 289239 | Core Atual: 19 | Afinidade: [0, 2, 4, 6, 16, 17, 18, 19]
#  -> Worker PID 289253 | Core Atual:  6 | Afinidade: [0, 2, 4, 6, 16, 17, 18, 19]
# ------------------------------------------------------------
# /usr/lib/python3/dist-packages/distributed/client.py:3162: UserWarning: Sending large graph of size 549.32 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# Run 1 | 4P_4E_HT_OFF | Time: 47.5837s
# /usr/lib/python3/dist-packages/distributed/client.py:3162: UserWarning: Sending large graph of size 549.32 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# Run 2 | 4P_4E_HT_OFF | Time: 47.9086s
# /usr/lib/python3/dist-packages/distributed/client.py:3162: UserWarning: Sending large graph of size 549.32 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# Run 3 | 4P_4E_HT_OFF | Time: 49.9601s
# /usr/lib/python3/dist-packages/distributed/client.py:3162: UserWarning: Sending large graph of size 549.32 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# Run 4 | 4P_4E_HT_OFF | Time: 48.7453s
# /usr/lib/python3/dist-packages/distributed/client.py:3162: UserWarning: Sending large graph of size 549.32 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# Run 5 | 4P_4E_HT_OFF | Time: 49.2096s
#
# --- Iniciando Cenário: 8E ---
# Restringindo processo Pai aos núcleos: [16, 17, 18, 19, 20, 21, 22, 23]
#
# [Status dos Workers]
#  -> Worker PID 289604 | Core Atual: 18 | Afinidade: [16, 17, 18, 19, 20, 21, 22, 23]
#  -> Worker PID 289600 | Core Atual: 19 | Afinidade: [16, 17, 18, 19, 20, 21, 22, 23]
#  -> Worker PID 289612 | Core Atual: 16 | Afinidade: [16, 17, 18, 19, 20, 21, 22, 23]
#  -> Worker PID 289619 | Core Atual: 20 | Afinidade: [16, 17, 18, 19, 20, 21, 22, 23]
#  -> Worker PID 289596 | Core Atual: 21 | Afinidade: [16, 17, 18, 19, 20, 21, 22, 23]
#  -> Worker PID 289617 | Core Atual: 18 | Afinidade: [16, 17, 18, 19, 20, 21, 22, 23]
#  -> Worker PID 289608 | Core Atual: 19 | Afinidade: [16, 17, 18, 19, 20, 21, 22, 23]
#  -> Worker PID 289593 | Core Atual: 16 | Afinidade: [16, 17, 18, 19, 20, 21, 22, 23]
# ------------------------------------------------------------
# /usr/lib/python3/dist-packages/distributed/client.py:3162: UserWarning: Sending large graph of size 549.32 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# Run 1 | 8E | Time: 65.3763s
# /usr/lib/python3/dist-packages/distributed/client.py:3162: UserWarning: Sending large graph of size 549.32 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# Run 2 | 8E | Time: 64.7390s
# /usr/lib/python3/dist-packages/distributed/client.py:3162: UserWarning: Sending large graph of size 549.32 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# Run 3 | 8E | Time: 64.6205s
# /usr/lib/python3/dist-packages/distributed/client.py:3162: UserWarning: Sending large graph of size 549.32 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# Run 4 | 8E | Time: 64.0809s
# /usr/lib/python3/dist-packages/distributed/client.py:3162: UserWarning: Sending large graph of size 549.32 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# Run 5 | 8E | Time: 64.2562s
#
# Restaurada afinidade para todos os núcleos.
#
# Resumo Final:
#  Scenario
# 4P_4E_HT_OFF    48.681477
# 4P_HT_ON        44.080172
# 8E              64.614592
# 8P_HT_OFF       47.723856
# Name: Time_sec, dtype: float64
# Salvo em: experimentos03_dask_native_affinity/20251123_203215_matrix6000.csv

# %% [markdown]
# # 3º Script: Dask compute com pool de núcleos - Com leitura de arquivo
#
# ```bash
# pyenv global 3.12.12
# pyenv shell 3.12.12
#
# OMP_NUM_THREADS=1 MKL_NUM_THREADS=1 VECLIB_MAXIMUM_THREADS=1 OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 jupyter notebook
# ```

# %%
import getpass
import os
import sys
import time
import psutil
import numpy as np
import pandas as pd
import dask.array as da
from datetime import datetime
from dask.distributed import Client, LocalCluster
import gc

# --------------------------------------
# CONFIGURATION GLOBAL
np.random.seed(42)

PLAN_FILE = "experiments_plan.csv"
GOVERNOR = "performance"
IDLE_TIME = 10  # Tempo de resfriamento entre experimentos

print(sys.version_info)

# --------------------------------------
# Helper Functions
def get_worker_info():
    """
    Esta função roda dentro de cada worker.
    Retorna o PID e o Núcleo (Core) que está sendo usado naquele instante.
    """
    import psutil
    import os
    p = psutil.Process(os.getpid())
    
    return {
        "pid": os.getpid(),
        # cpu_num() retorna o ID do núcleo físico/lógico onde o processo está rodando AGORA
        "core": p.cpu_num(), 
        # cpu_affinity() retorna a lista de núcleos PERMITIDOS para este worker
        "affinity": p.cpu_affinity() 
    }

def set_governor(governor: str):
    try:
        password = getpass.getpass("Sudo password (para governor): ")
        bash_command = f"""
        for cpu_file in $(ls -v /sys/devices/system/cpu/cpu*/cpufreq/scaling_governor); do
            echo "{governor}" | sudo tee $cpu_file > /dev/null
        done
        """
        command = f'echo "{password}" | sudo -S bash -c \'{bash_command}\''
        os.system(command)
        print(f"Governor definido para: {governor}")
    except Exception as e:
        print(f"Erro ao definir governor: {e}")

def get_governor(cpu_id=0):
    path = f"/sys/devices/system/cpu/cpu{cpu_id}/cpufreq/scaling_governor"
    try:
        with open(path) as f: return f.read().strip()
    except FileNotFoundError: return "N/A"

def parse_cpu_list_string(cpu_str):
    """
    Converte string "[0; 2; 4]" para lista [0, 2, 4]
    """
    clean_str = cpu_str.replace('[', '').replace(']', '').replace(' ', '')
    if not clean_str:
        return []
    return [int(x) for x in clean_str.split(';')]

def get_cpu_temperature():
    """
    Retorna a temperatura atual da CPU.
    Tenta identificar sensores comuns (coretemp, k10temp).
    Retorna a temperatura máxima entre os núcleos (pior caso) ou None se falhar.
    """
    try:
        temps = psutil.sensors_temperatures()
        if not temps:
            return None

        # Sensores comuns em Linux x86
        # 'coretemp' geralmente é Intel, 'k10temp' é AMD
        sensor_names = ['coretemp', 'k10temp', 'cpu_thermal', 'acpitz']
        
        for name in sensor_names:
            if name in temps:
                # Retorna a temperatura máxima registrada entre os cores desse sensor
                return max(entry.current for entry in temps[name])
        
        # Fallback: pega o primeiro sensor disponível se não achar os conhecidos
        first_key = next(iter(temps))
        return max(entry.current for entry in temps[first_key])

    except Exception as e:
        print(f"Aviso: Não foi possível ler temperatura: {e}")
        return None

# --------------------------------------
# Main Execution
if __name__ == "__main__":
    # 1. Configuração Inicial
    set_governor(GOVERNOR)

    # 2. Carregar Plano de Experimentos
    if not os.path.exists(PLAN_FILE):
        print(f"Erro: Arquivo '{PLAN_FILE}' não encontrado.")
        sys.exit(1)
    
    df_plan = pd.read_csv(PLAN_FILE)
    print(f"Carregado plano com {len(df_plan)} experimentos.")
    
    # 3. Preparar arquivo de saída
    now = datetime.now()
    timestamp_str = now.strftime("%Y%m%d_%H%M%S")
    output_filename = f"exp02-dask-pool/result_exp_dask_{timestamp_str}.csv"
    
    print(f"Resultados salvos incrementalmente em: {output_filename}")

    # 4. Loop de Execução
    for idx, row in df_plan.iterrows():
        print(f"Linha {idx}: ", end="", flush=True)
        
        # Extrair dados da linha
        exp_id = row['Experiment_ID']
        matrix_size = int(row['Matrix_Size'])
        cpu_set_name = row['CPU_Set_Name']
        run_number = row['Run_Number']
    
        # Parse da lista de cores
        try:
            cores = parse_cpu_list_string(row['CPU_Cores_List'])
        except Exception as e:
            print(f"Erro ao ler lista de CPUs na linha {idx}: {e}")
            continue
    
        if len(cores) == 0:
            print("Lista de CPUs vazia. Pulando.")
            continue
    
        # Validação de segurança
        if matrix_size % len(cores) != 0:
            print(f"AVISO: Matrix size {matrix_size} não é divisível por {len(cores)} cores.")
            sys.exit(0)
    
        # Gerar Matrizes (Dinâmico tamanho muda)
        #---------
          
        # Garantir que o governor está correto
        current_governor = get_governor(cores[0])
    
        #print(f"Restringindo processo Pai aos núcleos: {cores}")
        
        # 5. MÁGICA AQUI: Restringir o Processo Pai (Script Python atual)
        # Todos os processos filhos (Dask Workers) criados a seguir herdarão essa restrição.
        parent = psutil.Process(os.getpid())
        parent.cpu_affinity(cores)
        
        chunk_size = matrix_size // len(cores)
        total_time = 0
        
        # 6. Iniciar Cluster (Os workers nascerão "presos" aos núcleos definidos acima)
        # Recriamos o cluster a cada cenário para garantir que a nova afinidade seja aplicada
        with LocalCluster(n_workers=len(cores), 
                          threads_per_worker=1, 
                          processes=True, # Obrigatório para herança de afinidade funcionar bem aqui
                          silence_logs=40) as cluster:
            
            with Client(cluster) as client:
                # Aquecimento opcional ou apenas info
                # print(f"Client pronto: {client.dashboard_link}")
                
                # --- SONDA: VERIFICAR ONDE OS WORKERS ESTÃO ---
                # client.run executa a função em TODOS os workers e retorna um dicionário
                #workers_info = client.run(get_worker_info)
                
                #print("\n[Status dos Workers]")
                #for worker_addr, info in workers_info.items():
                    # Extraímos o IP/Porta ou apenas usamos um contador se preferir
                #    print(f" -> Worker PID {info['pid']} | Core Atual: {info['core']:>2} | Afinidade: {info['affinity']}")
                #print("-" * 60)
                # ----------------------------------------------

                # ---------------------------------------------------
                # OPERAÇÃO NATIVA DO DASK
                # ---------------------------------------------------
                
                # Criação dos arrays distribuídos (Lazy)
                # Cria no Host (Numpy) para termos a "Verdade Absoluta"
                #A_host = np.random.rand(matrix_size, matrix_size).astype(np.float64)
                #B_host = np.random.rand(matrix_size, matrix_size).astype(np.float64)
        
                # Envia para o Dask (Scatter/Slice)
                # Isso garante que o Dask calcule EXATAMENTE os mesmos números que o Numpy
                #dask_A = da.from_array(A_host, chunks=(chunk_size, matrix_size))
                #dask_B = da.from_array(B_host, chunks=(matrix_size, chunk_size))
                
                # chunks=(CHUNK_SIZE, MATRIX_SIZE) -> divide em fatias horizontais                
                dask_A = da.random.random((matrix_size, matrix_size), chunks=(chunk_size, chunk_size))
                dask_B = da.random.random((matrix_size, matrix_size), chunks=(chunk_size, chunk_size))
                
                start_time = time.time()
                
                # Multiplicação
                result_lazy = da.matmul(dask_A, dask_B)

                # Computação (Dispara para os workers restritos)
                C = result_lazy.compute()

                end_time = time.time()
                total_time = end_time - start_time
                
                # Validação de resultados
                # Dados na memória principal
                # Inicializa as matrizes globais
                #print(f"Gerando matrizes {matrix_size}x{matrix_size}...", end="", flush=True)       
                #C_reference = np.matmul(A_host, B_host)
                #is_match = np.allclose(C, C_reference)
                #validacao_ok = "OK" if is_match else "FAIL"
                #print(f"  -> Validação: {validacao_ok}")
                
                # ---------------------------------------------------                

        print(f"Fim:{exp_id}|Size:{matrix_size}|Time:{total_time:.4f}s...", end="", flush=True)

        # Leitura de temperatura
        current_temp = get_cpu_temperature()
        #print(f" Temp: {current_temp}°C ... ", end="", flush=True)

        # 5. Salvar Resultado (Append)
        result_row = row.to_dict()
        result_row['Experiment_ID'] = exp_id
        result_row['Matrix_Size'] = matrix_size
        result_row['CPU_Set_Name'] = cpu_set_name
        result_row['Run_Number'] = run_number
        result_row['Executed_Governor'] = current_governor
        result_row['Time_sec'] = total_time
        result_row['Temp°C'] = current_temp
        result_row['Timestamp'] = datetime.now().isoformat()

        df_result_row = pd.DataFrame([result_row])

        # Se o arquivo não existe, escreve header. Se existe, append sem header.
        header_mode = not os.path.exists(output_filename)
        df_result_row.to_csv(output_filename, mode='a', header=header_mode, index=False)               

        
        # Limpeza agressiva
        A_host = None
        B_host = None
        dask_A = None
        dask_B = None
        del result_lazy
        
        del C
        gc.collect() # Força limpeza das variáveis

        # Resfriamento
        print(f"{IDLE_TIME}s para estabilização.")
        time.sleep(IDLE_TIME)

    print("\nTodos os experimentos do plano foram concluídos.")
# Out:
# sys.version_info(major=3, minor=12, micro=3, releaselevel='final', serial=0)
# Sudo password (para governor): ········
# Governor definido para: performance
# Carregado plano com 606 experimentos.
# Resultados salvos incrementalmente em: exp02-dask-pool/result_exp_dask_20251126_033107.csv
# Linha 0:
# [sudo] senha para jgross:
# Fim:EXP_WARMUP|Size:8000|Time:67.6359s...10s para estabilização.
# Linha 1: Fim:EXP_WARMUP|Size:8000|Time:101.8282s...10s para estabilização.
# Linha 2: Fim:EXP_WARMUP|Size:8000|Time:104.1143s...10s para estabilização.
# Linha 3: Fim:EXP_WARMUP|Size:8000|Time:103.9730s...10s para estabilização.
# Linha 4: Fim:EXP_WARMUP|Size:8000|Time:104.6262s...10s para estabilização.
# Linha 5: Fim:EXP_WARMUP|Size:8000|Time:103.8819s...10s para estabilização.
# Linha 6: Fim:EXP_0111|Size:1000|Time:0.6357s...10s para estabilização.
# Linha 7: Fim:EXP_0420|Size:6000|Time:26.2735s...10s para estabilização.
# Linha 8: Fim:EXP_0566|Size:8000|Time:77.6838s...10s para estabilização.
# Linha 9: Fim:EXP_0078|Size:1000|Time:0.5165s...10s para estabilização.
# Linha 10: Fim:EXP_0182|Size:2000|Time:1.0964s...10s para estabilização.
# Linha 11: Fim:EXP_0285|Size:4000|Time:6.4963s...10s para estabilização.
# Linha 12: Fim:EXP_0011|Size:1000|Time:0.4651s...10s para estabilização.
# Linha 13: Fim:EXP_0470|Size:6000|Time:34.6447s...10s para estabilização.
# Linha 14: Fim:EXP_0079|Size:1000|Time:0.5090s...10s para estabilização.
# Linha 15: Fim:EXP_0350|Size:4000|Time:8.2136s...10s para estabilização.
# Linha 16: Fim:EXP_0056|Size:1000|Time:0.6002s...10s para estabilização.
# Linha 17: Fim:EXP_0119|Size:1000|Time:0.6407s...10s para estabilização.
# Linha 18: Fim:EXP_0110|Size:1000|Time:0.6262s...10s para estabilização.
# Linha 19: Fim:EXP_0589|Size:8000|Time:142.9773s...10s para estabilização.
# Linha 20: Fim:EXP_0370|Size:6000|Time:27.9077s...10s para estabilização.
# Linha 21: Fim:EXP_0235|Size:2000|Time:1.4373s...10s para estabilização.
# Linha 22: Fim:EXP_0031|Size:1000|Time:0.5643s...10s para estabilização.
# Linha 23: Fim:EXP_0213|Size:2000|Time:1.4072s...10s para estabilização.
# Linha 24: Fim:EXP_0185|Size:2000|Time:1.0875s...10s para estabilização.
# Linha 25: Fim:EXP_0087|Size:1000|Time:0.4926s...10s para estabilização.
# Linha 26: Fim:EXP_0003|Size:1000|Time:0.4685s...10s para estabilização.
# Linha 27: Fim:EXP_0588|Size:8000|Time:141.7617s...10s para estabilização.
# Linha 28: Fim:EXP_0536|Size:8000|Time:85.5881s...10s para estabilização.
# Linha 29: Fim:EXP_0597|Size:8000|Time:145.6811s...10s para estabilização.
# Linha 30: Fim:EXP_0369|Size:6000|Time:27.2331s...10s para estabilização.
# Linha 31: Fim:EXP_0540|Size:8000|Time:82.1017s...10s para estabilização.
# Linha 32: Fim:EXP_0073|Size:1000|Time:0.5190s...10s para estabilização.
# Linha 33: Fim:EXP_0136|Size:2000|Time:0.9855s...10s para estabilização.
# Linha 34: Fim:EXP_0557|Size:8000|Time:74.3473s...10s para estabilização.
# Linha 35: Fim:EXP_0438|Size:6000|Time:25.7519s...10s para estabilização.
# Linha 36: Fim:EXP_0596|Size:8000|Time:145.1272s...10s para estabilização.
# Linha 37: Fim:EXP_0164|Size:2000|Time:1.2555s...10s para estabilização.
# Linha 38: Fim:EXP_0083|Size:1000|Time:0.5073s...10s para estabilização.
# Linha 39: Fim:EXP_0258|Size:4000|Time:4.4153s...10s para estabilização.
# Linha 40: Fim:EXP_0193|Size:2000|Time:1.0996s...10s para estabilização.
# Linha 41: Fim:EXP_0454|Size:6000|Time:33.8666s...10s para estabilização.
# Linha 42: Fim:EXP_0133|Size:2000|Time:0.9736s...10s para estabilização.
# Linha 43: Fim:EXP_0516|Size:8000|Time:81.9032s...10s para estabilização.
# Linha 44: Fim:EXP_0442|Size:6000|Time:26.1361s...10s para estabilização.
# Linha 45: Fim:EXP_0276|Size:4000|Time:6.6673s...10s para estabilização.
# Linha 46: Fim:EXP_0365|Size:6000|Time:28.7635s...10s para estabilização.
# Linha 47: Fim:EXP_0030|Size:1000|Time:0.4668s...10s para estabilização.
# Linha 48: Fim:EXP_0507|Size:8000|Time:96.9815s...10s para estabilização.
# Linha 49: Fim:EXP_0571|Size:8000|Time:145.2039s...10s para estabilização.
# Linha 50: Fim:EXP_0025|Size:1000|Time:0.4864s...10s para estabilização.
# Linha 51: Fim:EXP_0183|Size:2000|Time:1.1009s...10s para estabilização.
# Linha 52: Fim:EXP_0474|Size:6000|Time:35.1304s...10s para estabilização.
# Linha 53: Fim:EXP_0105|Size:1000|Time:0.6236s...10s para estabilização.
# Linha 54: Fim:EXP_0064|Size:1000|Time:0.5134s...10s para estabilização.
# Linha 55: Fim:EXP_0491|Size:8000|Time:94.9044s...10s para estabilização.
# Linha 56: Fim:EXP_0246|Size:4000|Time:4.3479s...10s para estabilização.
# Linha 57: Fim:EXP_0249|Size:4000|Time:4.3818s...10s para estabilização.
# Linha 58: Fim:EXP_0102|Size:1000|Time:0.6498s...10s para estabilização.
# Linha 59: Fim:EXP_0556|Size:8000|Time:75.1852s...10s para estabilização.
# Linha 60: Fim:EXP_0592|Size:8000|Time:145.2232s...10s para estabilização.
# Linha 61: Fim:EXP_0357|Size:4000|Time:8.0305s...10s para estabilização.
# Linha 62: Fim:EXP_0210|Size:2000|Time:1.0867s...10s para estabilização.
# Linha 63: Fim:EXP_0166|Size:2000|Time:1.3454s...10s para estabilização.
# Linha 64: Fim:EXP_0138|Size:2000|Time:0.9780s...10s para estabilização.
# Linha 65: Fim:EXP_0196|Size:2000|Time:1.0741s...10s para estabilização.
# Linha 66: Fim:EXP_0077|Size:1000|Time:0.5126s...10s para estabilização.
# Linha 67: Fim:EXP_0177|Size:2000|Time:1.2464s...10s para estabilização.
# Linha 68: Fim:EXP_0330|Size:4000|Time:5.3791s...10s para estabilização.
# Linha 69: Fim:EXP_0537|Size:8000|Time:77.1231s...10s para estabilização.
# Linha 70: Fim:EXP_0549|Size:8000|Time:78.3436s...10s para estabilização.
# Linha 71: Fim:EXP_0071|Size:1000|Time:0.5047s...10s para estabilização.
# Linha 72: Fim:EXP_0562|Size:8000|Time:76.6215s...10s para estabilização.
# Linha 73: Fim:EXP_0590|Size:8000|Time:145.2265s...10s para estabilização.
# Linha 74: Fim:EXP_0082|Size:1000|Time:0.5064s...10s para estabilização.
# Linha 75: Fim:EXP_0317|Size:4000|Time:5.3547s...10s para estabilização.
# Linha 76: Fim:EXP_0305|Size:4000|Time:5.3140s...10s para estabilização.
# Linha 77: Fim:EXP_0007|Size:1000|Time:0.4652s...10s para estabilização.
# Linha 78: Fim:EXP_0424|Size:6000|Time:20.5749s...10s para estabilização.
# Linha 79: Fim:EXP_0375|Size:6000|Time:27.9620s...10s para estabilização.
# Linha 80: Fim:EXP_0430|Size:6000|Time:25.6603s...10s para estabilização.
# Linha 81: Fim:EXP_0538|Size:8000|Time:82.5365s...10s para estabilização.
# Linha 82: Fim:EXP_0313|Size:4000|Time:5.3343s...10s para estabilização.
# Linha 83: Fim:EXP_0239|Size:2000|Time:1.4235s...10s para estabilização.
# Linha 84: Fim:EXP_0560|Size:8000|Time:77.3703s...10s para estabilização.
# Linha 85: Fim:EXP_0433|Size:6000|Time:25.9146s...10s para estabilização.
# Linha 86: Fim:EXP_0287|Size:4000|Time:6.5024s...10s para estabilização.
# Linha 87: Fim:EXP_0427|Size:6000|Time:28.0938s...10s para estabilização.
# Linha 88: Fim:EXP_0599|Size:8000|Time:145.3658s...10s para estabilização.
# Linha 89: Fim:EXP_0362|Size:6000|Time:29.0472s...10s para estabilização.
# Linha 90: Fim:EXP_0074|Size:1000|Time:0.5086s...10s para estabilização.
# Linha 91: Fim:EXP_0040|Size:1000|Time:0.5538s...10s para estabilização.
# Linha 92: Fim:EXP_0156|Size:2000|Time:1.2339s...10s para estabilização.
# Linha 93: Fim:EXP_0219|Size:2000|Time:1.4208s...10s para estabilização.
# Linha 94: Fim:EXP_0371|Size:6000|Time:14.4746s...10s para estabilização.
# Linha 95: Fim:EXP_0211|Size:2000|Time:1.4113s...10s para estabilização.
# Linha 96: Fim:EXP_0236|Size:2000|Time:1.3991s...10s para estabilização.
# Linha 97: Fim:EXP_0547|Size:8000|Time:73.2691s...10s para estabilização.
# Linha 98: Fim:EXP_0061|Size:1000|Time:0.5092s...10s para estabilização.
# Linha 99:
# 2025-11-26 04:46:19,770 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/distributed/worker.py", line 1252, in heartbeat
#     response = await retry_operation(
#                ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/distributed/utils_comm.py", line 455, in retry_operation
#     return await retry(
#            ^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/distributed/utils_comm.py", line 434, in retry
#     return await coro()
#            ^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/distributed/core.py", line 1394, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/distributed/core.py", line 1153, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/usr/lib/python3/dist-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:43712 remote=tcp://127.0.0.1:38577>: Stream is closed
# Fim:EXP_0301|Size:4000|Time:5.3313s...10s para estabilização.
# Linha 100: Fim:EXP_0260|Size:4000|Time:4.3870s...10s para estabilização.
# Linha 101: Fim:EXP_0281|Size:4000|Time:6.4964s...10s para estabilização.
# Linha 102: Fim:EXP_0229|Size:2000|Time:1.4091s...10s para estabilização.
# Linha 103: Fim:EXP_0012|Size:1000|Time:0.4813s...10s para estabilização.
# Linha 104: Fim:EXP_0413|Size:6000|Time:23.8127s...10s para estabilização.
# Linha 105: Fim:EXP_0084|Size:1000|Time:0.5126s...10s para estabilização.
# Linha 106: Fim:EXP_0091|Size:1000|Time:0.6520s...10s para estabilização.
# Linha 107: Fim:EXP_0209|Size:2000|Time:1.0854s...10s para estabilização.
# Linha 108: Fim:EXP_0539|Size:8000|Time:78.5991s...10s para estabilização.
# Linha 109: Fim:EXP_0336|Size:4000|Time:8.1141s...10s para estabilização.
# Linha 110: Fim:EXP_0080|Size:1000|Time:0.5035s...10s para estabilização.
# Linha 111: Fim:EXP_0435|Size:6000|Time:22.3758s...10s para estabilização.
# Linha 112: Fim:EXP_0141|Size:2000|Time:0.9770s...10s para estabilização.
# Linha 113: Fim:EXP_0282|Size:4000|Time:6.4858s...10s para estabilização.
# Linha 114: Fim:EXP_0269|Size:4000|Time:4.3395s...10s para estabilização.
# Linha 115: Fim:EXP_0415|Size:6000|Time:27.3079s...10s para estabilização.
# Linha 116: Fim:EXP_0200|Size:2000|Time:1.0939s...10s para estabilização.
# Linha 117:
# 2025-11-26 04:53:22,035 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/distributed/worker.py", line 1252, in heartbeat
#     response = await retry_operation(
#                ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/distributed/utils_comm.py", line 455, in retry_operation
#     return await retry(
#            ^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/distributed/utils_comm.py", line 434, in retry
#     return await coro()
#            ^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/distributed/core.py", line 1394, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/distributed/core.py", line 1153, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/usr/lib/python3/dist-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:57172 remote=tcp://127.0.0.1:46125>: Stream is closed
# 2025-11-26 04:53:22,036 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/distributed/worker.py", line 1252, in heartbeat
#     response = await retry_operation(
#                ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/distributed/utils_comm.py", line 455, in retry_operation
#     return await retry(
#            ^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/distributed/utils_comm.py", line 434, in retry
#     return await coro()
#            ^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/distributed/core.py", line 1394, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/distributed/core.py", line 1153, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/usr/lib/python3/dist-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:57158 remote=tcp://127.0.0.1:46125>: Stream is closed
# 2025-11-26 04:53:22,037 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/distributed/worker.py", line 1252, in heartbeat
#     response = await retry_operation(
#                ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/distributed/utils_comm.py", line 455, in retry_operation
#     return await retry(
#            ^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/distributed/utils_comm.py", line 434, in retry
#     return await coro()
#            ^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/distributed/core.py", line 1394, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/distributed/core.py", line 1153, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/usr/lib/python3/dist-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:57186 remote=tcp://127.0.0.1:46125>: Stream is closed
# 2025-11-26 04:53:22,037 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/distributed/worker.py", line 1252, in heartbeat
#     response = await retry_operation(
#                ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/distributed/utils_comm.py", line 455, in retry_operation
#     return await retry(
#            ^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/distributed/utils_comm.py", line 434, in retry
#     return await coro()
#            ^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/distributed/core.py", line 1394, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/distributed/core.py", line 1153, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/usr/lib/python3/dist-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:57178 remote=tcp://127.0.0.1:46125>: Stream is closed
# 2025-11-26 04:53:22,037 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/distributed/worker.py", line 1252, in heartbeat
#     response = await retry_operation(
#                ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/distributed/utils_comm.py", line 455, in retry_operation
#     return await retry(
#            ^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/distributed/utils_comm.py", line 434, in retry
#     return await coro()
#            ^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/distributed/core.py", line 1394, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/distributed/core.py", line 1153, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/usr/lib/python3/dist-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:57160 remote=tcp://127.0.0.1:46125>: Stream is closed
# 2025-11-26 04:53:22,040 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/distributed/worker.py", line 1252, in heartbeat
#     response = await retry_operation(
#                ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/distributed/utils_comm.py", line 455, in retry_operation
#     return await retry(
#            ^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/distributed/utils_comm.py", line 434, in retry
#     return await coro()
#            ^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/distributed/core.py", line 1394, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/distributed/core.py", line 1153, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/usr/lib/python3/dist-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:57218 remote=tcp://127.0.0.1:46125>: Stream is closed
# Fim:EXP_0465|Size:6000|Time:35.9746s...10s para estabilização.
# Linha 118: Fim:EXP_0576|Size:8000|Time:145.3857s...10s para estabilização.
# Linha 119: Fim:EXP_0585|Size:8000|Time:145.7042s...10s para estabilização.
# Linha 120: Fim:EXP_0372|Size:6000|Time:26.5887s...10s para estabilização.
# Linha 121: Fim:EXP_0400|Size:6000|Time:28.7852s...10s para estabilização.
# Linha 122: Fim:EXP_0341|Size:4000|Time:8.1466s...10s para estabilização.
# Linha 123: Fim:EXP_0149|Size:2000|Time:0.9875s...10s para estabilização.
# Linha 124: Fim:EXP_0495|Size:8000|Time:97.8355s...10s para estabilização.
# Linha 125: Fim:EXP_0440|Size:6000|Time:26.5980s...10s para estabilização.
# Linha 126: Fim:EXP_0146|Size:2000|Time:0.9827s...10s para estabilização.
# Linha 127: Fim:EXP_0010|Size:1000|Time:0.4648s...10s para estabilização.
# Linha 128: Fim:EXP_0376|Size:6000|Time:14.6282s...10s para estabilização.
# Linha 129: Fim:EXP_0524|Size:8000|Time:86.0483s...10s para estabilização.
# Linha 130: Fim:EXP_0189|Size:2000|Time:1.0922s...10s para estabilização.
# Linha 131: Fim:EXP_0132|Size:2000|Time:0.9931s...10s para estabilização.
# Linha 132: Fim:EXP_0573|Size:8000|Time:144.6047s...10s para estabilização.
# Linha 133: Fim:EXP_0299|Size:4000|Time:6.5147s...10s para estabilização.
# Linha 134: Fim:EXP_0587|Size:8000|Time:145.3879s...10s para estabilização.
# Linha 135: Fim:EXP_0447|Size:6000|Time:26.7380s...10s para estabilização.
# Linha 136: Fim:EXP_0085|Size:1000|Time:0.5140s...10s para estabilização.
# Linha 137: Fim:EXP_0593|Size:8000|Time:144.4788s...10s para estabilização.
# Linha 138: Fim:EXP_0178|Size:2000|Time:1.2504s...10s para estabilização.
# Linha 139: Fim:EXP_0154|Size:2000|Time:1.2481s...10s para estabilização.
# Linha 140: Fim:EXP_0453|Size:6000|Time:36.1630s...10s para estabilização.
# Linha 141: Fim:EXP_0197|Size:2000|Time:1.0826s...10s para estabilização.
# Linha 142: Fim:EXP_0076|Size:1000|Time:0.5118s...10s para estabilização.
# Linha 143: Fim:EXP_0093|Size:1000|Time:0.6482s...10s para estabilização.
# Linha 144: Fim:EXP_0297|Size:4000|Time:6.4308s...10s para estabilização.
# Linha 145: Fim:EXP_0069|Size:1000|Time:0.5005s...10s para estabilização.
# Linha 146: Fim:EXP_0016|Size:1000|Time:0.4693s...10s para estabilização.
# Linha 147: Fim:EXP_0205|Size:2000|Time:1.0827s...10s para estabilização.
# Linha 148: Fim:EXP_0159|Size:2000|Time:1.2290s...10s para estabilização.
# Linha 149: Fim:EXP_0089|Size:1000|Time:0.5075s...10s para estabilização.
# Linha 150: Fim:EXP_0498|Size:8000|Time:77.8185s...10s para estabilização.
# Linha 151: Fim:EXP_0118|Size:1000|Time:0.6430s...10s para estabilização.
# Linha 152: Fim:EXP_0383|Size:6000|Time:18.0025s...10s para estabilização.
# Linha 153: Fim:EXP_0406|Size:6000|Time:28.9749s...10s para estabilização.
# Linha 154: Fim:EXP_0034|Size:1000|Time:0.5520s...10s para estabilização.
# Linha 155: Fim:EXP_0001|Size:1000|Time:0.4664s...10s para estabilização.
# Linha 156: Fim:EXP_0594|Size:8000|Time:143.8318s...10s para estabilização.
# Linha 157: Fim:EXP_0532|Size:8000|Time:85.3702s...10s para estabilização.
# Linha 158: Fim:EXP_0354|Size:4000|Time:8.0914s...10s para estabilização.
# Linha 159: Fim:EXP_0333|Size:4000|Time:8.0556s...10s para estabilização.
# Linha 160: Fim:EXP_0535|Size:8000|Time:83.7483s...10s para estabilização.
# Linha 161: Fim:EXP_0245|Size:4000|Time:4.4099s...10s para estabilização.
# Linha 162: Fim:EXP_0023|Size:1000|Time:0.4671s...10s para estabilização.
# Linha 163: Fim:EXP_0441|Size:6000|Time:21.6742s...10s para estabilização.
# Linha 164: Fim:EXP_0117|Size:1000|Time:0.6352s...10s para estabilização.
# Linha 165: Fim:EXP_0090|Size:1000|Time:0.5206s...10s para estabilização.
# Linha 166: Fim:EXP_0366|Size:6000|Time:14.7001s...10s para estabilização.
# Linha 167: Fim:EXP_0212|Size:2000|Time:1.4193s...10s para estabilização.
# Linha 168: Fim:EXP_0019|Size:1000|Time:0.4720s...10s para estabilização.
# Linha 169: Fim:EXP_0408|Size:6000|Time:25.5698s...10s para estabilização.
# Linha 170: Fim:EXP_0321|Size:4000|Time:5.3824s...10s para estabilização.
# Linha 171: Fim:EXP_0145|Size:2000|Time:0.9926s...10s para estabilização.
# Linha 172: Fim:EXP_0290|Size:4000|Time:6.4675s...10s para estabilização.
# Linha 173: Fim:EXP_0275|Size:4000|Time:6.4959s...10s para estabilização.
# Linha 174: Fim:EXP_0542|Size:8000|Time:77.3286s...10s para estabilização.
# Linha 175: Fim:EXP_0361|Size:6000|Time:28.0369s...10s para estabilização.
# Linha 176: Fim:EXP_0251|Size:4000|Time:4.3305s...10s para estabilização.
# Linha 177: Fim:EXP_0288|Size:4000|Time:6.5760s...10s para estabilização.
# Linha 178: Fim:EXP_0529|Size:8000|Time:83.4136s...10s para estabilização.
# Linha 179: Fim:EXP_0401|Size:6000|Time:28.3334s...10s para estabilização.
# Linha 180: Fim:EXP_0168|Size:2000|Time:1.3067s...10s para estabilização.
# Linha 181: Fim:EXP_0055|Size:1000|Time:0.5581s...10s para estabilização.
# Linha 182: Fim:EXP_0494|Size:8000|Time:95.8059s...10s para estabilização.
# Linha 183: Fim:EXP_0047|Size:1000|Time:0.5599s...10s para estabilização.
# Linha 184: Fim:EXP_0094|Size:1000|Time:0.6591s...10s para estabilização.
# Linha 185: Fim:EXP_0265|Size:4000|Time:4.3644s...10s para estabilização.
# Linha 186: Fim:EXP_0109|Size:1000|Time:0.6314s...10s para estabilização.
# Linha 187: Fim:EXP_0273|Size:4000|Time:6.4612s...10s para estabilização.
# Linha 188: Fim:EXP_0600|Size:8000|Time:143.1934s...10s para estabilização.
# Linha 189: Fim:EXP_0480|Size:6000|Time:37.8992s...10s para estabilização.
# Linha 190: Fim:EXP_0437|Size:6000|Time:26.0275s...10s para estabilização.
# Linha 191: Fim:EXP_0384|Size:6000|Time:27.6441s...10s para estabilização.
# Linha 192: Fim:EXP_0381|Size:6000|Time:27.4539s...10s para estabilização.
# Linha 193: Fim:EXP_0463|Size:6000|Time:37.5058s...10s para estabilização.
# Linha 194: Fim:EXP_0395|Size:6000|Time:28.2477s...10s para estabilização.
# Linha 195: Fim:EXP_0266|Size:4000|Time:4.3764s...10s para estabilização.
# Linha 196: Fim:EXP_0481|Size:8000|Time:102.4137s...10s para estabilização.
# Linha 197: Fim:EXP_0518|Size:8000|Time:83.8462s...10s para estabilização.
# Linha 198: Fim:EXP_0070|Size:1000|Time:0.5104s...10s para estabilização.
# Linha 199: Fim:EXP_0232|Size:2000|Time:1.4214s...10s para estabilização.
# Linha 200: Fim:EXP_0404|Size:6000|Time:25.1790s...10s para estabilização.
# Linha 201: Fim:EXP_0279|Size:4000|Time:6.4988s...10s para estabilização.
# Linha 202: Fim:EXP_0473|Size:6000|Time:38.5161s...10s para estabilização.
# Linha 203: Fim:EXP_0351|Size:4000|Time:8.0193s...10s para estabilização.
# Linha 204: Fim:EXP_0510|Size:8000|Time:103.6985s...10s para estabilização.
# Linha 205: Fim:EXP_0150|Size:2000|Time:0.9919s...10s para estabilização.
# Linha 206: Fim:EXP_0125|Size:2000|Time:0.9671s...10s para estabilização.
# Linha 207: Fim:EXP_0429|Size:6000|Time:20.1373s...10s para estabilização.
# Linha 208: Fim:EXP_0466|Size:6000|Time:37.2050s...10s para estabilização.
# Linha 209: Fim:EXP_0186|Size:2000|Time:1.0897s...10s para estabilização.
# Linha 210: Fim:EXP_0228|Size:2000|Time:1.4422s...10s para estabilização.
# Linha 211: Fim:EXP_0292|Size:4000|Time:6.5126s...10s para estabilização.
# Linha 212: Fim:EXP_0248|Size:4000|Time:4.3781s...10s para estabilização.
# Linha 213: Fim:EXP_0291|Size:4000|Time:6.5328s...10s para estabilização.
# Linha 214: Fim:EXP_0250|Size:4000|Time:4.3483s...10s para estabilização.
# Linha 215: Fim:EXP_0444|Size:6000|Time:23.2947s...10s para estabilização.
# Linha 216: Fim:EXP_0552|Size:8000|Time:78.6194s...10s para estabilização.
# Linha 217: Fim:EXP_0553|Size:8000|Time:80.0357s...10s para estabilização.
# Linha 218: Fim:EXP_0551|Size:8000|Time:79.2693s...10s para estabilização.
# Linha 219: Fim:EXP_0115|Size:1000|Time:0.6613s...10s para estabilização.
# Linha 220: Fim:EXP_0204|Size:2000|Time:1.0749s...10s para estabilização.
# Linha 221: Fim:EXP_0142|Size:2000|Time:0.9853s...10s para estabilização.
# Linha 222: Fim:EXP_0339|Size:4000|Time:8.0041s...10s para estabilização.
# Linha 223: Fim:EXP_0008|Size:1000|Time:0.4673s...10s para estabilização.
# Linha 224: Fim:EXP_0522|Size:8000|Time:79.1144s...10s para estabilização.
# Linha 225: Fim:EXP_0020|Size:1000|Time:0.4629s...10s para estabilização.
# Linha 226: Fim:EXP_0173|Size:2000|Time:1.2466s...10s para estabilização.
# Linha 227: Fim:EXP_0452|Size:6000|Time:34.9101s...10s para estabilização.
# Linha 228: Fim:EXP_0057|Size:1000|Time:0.5625s...10s para estabilização.
# Linha 229: Fim:EXP_0302|Size:4000|Time:5.3693s...10s para estabilização.
# Linha 230: Fim:EXP_0337|Size:4000|Time:8.1120s...10s para estabilização.
# Linha 231: Fim:EXP_0451|Size:6000|Time:37.1465s...10s para estabilização.
# Linha 232: Fim:EXP_0323|Size:4000|Time:5.5133s...10s para estabilização.
# Linha 233: Fim:EXP_0311|Size:4000|Time:5.3474s...10s para estabilização.
# Linha 234: Fim:EXP_0050|Size:1000|Time:0.5694s...10s para estabilização.
# Linha 235: Fim:EXP_0345|Size:4000|Time:8.0017s...10s para estabilização.
# Linha 236: Fim:EXP_0026|Size:1000|Time:0.4631s...10s para estabilização.
# Linha 237: Fim:EXP_0443|Size:6000|Time:19.5734s...10s para estabilização.
# Linha 238: Fim:EXP_0221|Size:2000|Time:1.4093s...10s para estabilização.
# Linha 239: Fim:EXP_0484|Size:8000|Time:99.3572s...10s para estabilização.
# Linha 240: Fim:EXP_0541|Size:8000|Time:78.5558s...10s para estabilização.
# Linha 241: Fim:EXP_0043|Size:1000|Time:0.5636s...10s para estabilização.
# Linha 242: Fim:EXP_0417|Size:6000|Time:26.9406s...10s para estabilização.
# Linha 243: Fim:EXP_0262|Size:4000|Time:4.4324s...
# 2025-11-26 06:14:07,839 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/distributed/worker.py", line 1252, in heartbeat
#     response = await retry_operation(
#                ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/distributed/utils_comm.py", line 455, in retry_operation
#     return await retry(
#            ^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/distributed/utils_comm.py", line 434, in retry
#     return await coro()
#            ^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/distributed/core.py", line 1394, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/distributed/core.py", line 1153, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/usr/lib/python3/dist-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:36292 remote=tcp://127.0.0.1:39351>: Stream is closed
# 10s para estabilização.
# Linha 244: Fim:EXP_0409|Size:6000|Time:28.2689s...10s para estabilização.
# Linha 245: Fim:EXP_0278|Size:4000|Time:8.3900s...10s para estabilização.
# Linha 246: Fim:EXP_0570|Size:8000|Time:78.0602s...10s para estabilização.
# Linha 247: Fim:EXP_0382|Size:6000|Time:30.6507s...10s para estabilização.
# Linha 248: Fim:EXP_0412|Size:6000|Time:28.4020s...10s para estabilização.
# Linha 249: Fim:EXP_0155|Size:2000|Time:1.2502s...10s para estabilização.
# Linha 250: Fim:EXP_0127|Size:2000|Time:0.9722s...10s para estabilização.
# Linha 251: Fim:EXP_0310|Size:4000|Time:5.3143s...10s para estabilização.
# Linha 252: Fim:EXP_0520|Size:8000|Time:79.2762s...10s para estabilização.
# Linha 253: Fim:EXP_0446|Size:6000|Time:26.4901s...10s para estabilização.
# Linha 254: Fim:EXP_0175|Size:2000|Time:1.2299s...10s para estabilização.
# Linha 255: Fim:EXP_0032|Size:1000|Time:0.5597s...10s para estabilização.
# Linha 256: Fim:EXP_0114|Size:1000|Time:0.6405s...10s para estabilização.
# Linha 257: Fim:EXP_0024|Size:1000|Time:0.4724s...10s para estabilização.
# Linha 258: Fim:EXP_0174|Size:2000|Time:1.2707s...10s para estabilização.
# Linha 259: Fim:EXP_0558|Size:8000|Time:70.6212s...10s para estabilização.
# Linha 260: Fim:EXP_0067|Size:1000|Time:0.5084s...10s para estabilização.
# Linha 261: Fim:EXP_0058|Size:1000|Time:0.5645s...10s para estabilização.
# Linha 262: Fim:EXP_0322|Size:4000|Time:5.3496s...10s para estabilização.
# Linha 263:
# 2025-11-26 06:23:57,438 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/distributed/worker.py", line 1252, in heartbeat
#     response = await retry_operation(
#                ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/distributed/utils_comm.py", line 455, in retry_operation
#     return await retry(
#            ^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/distributed/utils_comm.py", line 434, in retry
#     return await coro()
#            ^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/distributed/core.py", line 1394, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/distributed/core.py", line 1153, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/usr/lib/python3/dist-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:50748 remote=tcp://127.0.0.1:40949>: Stream is closed
# Fim:EXP_0223|Size:2000|Time:1.4341s...10s para estabilização.
# Linha 264: Fim:EXP_0018|Size:1000|Time:0.4802s...10s para estabilização.
# Linha 265: Fim:EXP_0300|Size:4000|Time:6.4762s...10s para estabilização.
# Linha 266: Fim:EXP_0256|Size:4000|Time:4.3801s...10s para estabilização.
# Linha 267: Fim:EXP_0306|Size:4000|Time:5.4634s...10s para estabilização.
# Linha 268: Fim:EXP_0574|Size:8000|Time:143.0170s...10s para estabilização.
# Linha 269: Fim:EXP_0191|Size:2000|Time:1.0984s...10s para estabilização.
# Linha 270: Fim:EXP_0319|Size:4000|Time:5.3160s...10s para estabilização.
# Linha 271: Fim:EXP_0528|Size:8000|Time:83.3034s...10s para estabilização.
# Linha 272: Fim:EXP_0272|Size:4000|Time:6.5035s...10s para estabilização.
# Linha 273: Fim:EXP_0095|Size:1000|Time:0.6447s...10s para estabilização.
# Linha 274: Fim:EXP_0181|Size:2000|Time:1.0950s...10s para estabilização.
# Linha 275: Fim:EXP_0332|Size:4000|Time:8.0531s...10s para estabilização.
# Linha 276: Fim:EXP_0329|Size:4000|Time:5.3232s...10s para estabilização.
# Linha 277: Fim:EXP_0312|Size:4000|Time:5.2726s...10s para estabilização.
# Linha 278: Fim:EXP_0006|Size:1000|Time:0.4679s...10s para estabilização.
# Linha 279: Fim:EXP_0046|Size:1000|Time:0.5657s...10s para estabilização.
# Linha 280: Fim:EXP_0399|Size:6000|Time:23.5763s...10s para estabilização.
# Linha 281: Fim:EXP_0577|Size:8000|Time:145.6595s...10s para estabilização.
# Linha 282: Fim:EXP_0469|Size:6000|Time:38.0880s...10s para estabilização.
# Linha 283: Fim:EXP_0017|Size:1000|Time:0.4712s...10s para estabilização.
# Linha 284: Fim:EXP_0049|Size:1000|Time:0.5647s...10s para estabilização.
# Linha 285: Fim:EXP_0580|Size:8000|Time:144.1120s...10s para estabilização.
# Linha 286: Fim:EXP_0488|Size:8000|Time:106.3500s...10s para estabilização.
# Linha 287: Fim:EXP_0004|Size:1000|Time:0.4738s...10s para estabilização.
# Linha 288: Fim:EXP_0487|Size:8000|Time:99.2525s...10s para estabilização.
# Linha 289: Fim:EXP_0439|Size:6000|Time:26.6492s...10s para estabilização.
# Linha 290: Fim:EXP_0363|Size:6000|Time:26.9457s...10s para estabilização.
# Linha 291: Fim:EXP_0434|Size:6000|Time:26.0319s...10s para estabilização.
# Linha 292: Fim:EXP_0303|Size:4000|Time:5.2992s...10s para estabilização.
# Linha 293:
# 2025-11-26 06:44:49,051 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/distributed/worker.py", line 1252, in heartbeat
#     response = await retry_operation(
#                ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/distributed/utils_comm.py", line 455, in retry_operation
#     return await retry(
#            ^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/distributed/utils_comm.py", line 434, in retry
#     return await coro()
#            ^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/distributed/core.py", line 1394, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/distributed/core.py", line 1153, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/usr/lib/python3/dist-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:36782 remote=tcp://127.0.0.1:35455>: Stream is closed
# Fim:EXP_0226|Size:2000|Time:1.4326s...10s para estabilização.
# Linha 294: Fim:EXP_0027|Size:1000|Time:0.4762s...10s para estabilização.
# Linha 295: Fim:EXP_0425|Size:6000|Time:19.8453s...10s para estabilização.
# Linha 296: Fim:EXP_0264|Size:4000|Time:4.3847s...10s para estabilização.
# Linha 297: Fim:EXP_0051|Size:1000|Time:0.5649s...10s para estabilização.
# Linha 298: Fim:EXP_0230|Size:2000|Time:1.4180s...10s para estabilização.
# Linha 299: Fim:EXP_0038|Size:1000|Time:0.5610s...10s para estabilização.
# Linha 300: Fim:EXP_0158|Size:2000|Time:1.2452s...10s para estabilização.
# Linha 301: Fim:EXP_0238|Size:2000|Time:1.4196s...10s para estabilização.
# Linha 302: Fim:EXP_0575|Size:8000|Time:143.0001s...10s para estabilização.
# Linha 303: Fim:EXP_0176|Size:2000|Time:1.2406s...10s para estabilização.
# Linha 304: Fim:EXP_0515|Size:8000|Time:83.4031s...10s para estabilização.
# Linha 305: Fim:EXP_0358|Size:4000|Time:8.0424s...10s para estabilização.
# Linha 306: Fim:EXP_0195|Size:2000|Time:1.0992s...10s para estabilização.
# Linha 307: Fim:EXP_0504|Size:8000|Time:103.8363s...10s para estabilização.
# Linha 308: Fim:EXP_0579|Size:8000|Time:145.2970s...10s para estabilização.
# Linha 309: Fim:EXP_0512|Size:8000|Time:84.0506s...10s para estabilização.
# Linha 310: Fim:EXP_0068|Size:1000|Time:0.5107s...10s para estabilização.
# Linha 311: Fim:EXP_0320|Size:4000|Time:5.3106s...10s para estabilização.
# Linha 312: Fim:EXP_0169|Size:2000|Time:1.2513s...10s para estabilização.
# Linha 313: Fim:EXP_0368|Size:6000|Time:20.2522s...10s para estabilização.
# Linha 314: Fim:EXP_0163|Size:2000|Time:1.2344s...10s para estabilização.
# Linha 315: Fim:EXP_0194|Size:2000|Time:1.0976s...10s para estabilização.
# Linha 316: Fim:EXP_0153|Size:2000|Time:1.2441s...10s para estabilização.
# Linha 317: Fim:EXP_0502|Size:8000|Time:93.3222s...10s para estabilização.
# Linha 318: Fim:EXP_0347|Size:4000|Time:8.1034s...10s para estabilização.
# Linha 319: Fim:EXP_0486|Size:8000|Time:105.4282s...10s para estabilização.
# Linha 320: Fim:EXP_0334|Size:4000|Time:8.0753s...10s para estabilização.
# Linha 321: Fim:EXP_0104|Size:1000|Time:0.6730s...10s para estabilização.
# Linha 322: Fim:EXP_0391|Size:6000|Time:27.2155s...10s para estabilização.
# Linha 323: Fim:EXP_0075|Size:1000|Time:0.5146s...10s para estabilização.
# Linha 324: Fim:EXP_0423|Size:6000|Time:23.5175s...10s para estabilização.
# Linha 325: Fim:EXP_0578|Size:8000|Time:145.9143s...10s para estabilização.
# Linha 326: Fim:EXP_0120|Size:1000|Time:0.6354s...10s para estabilização.
# Linha 327: Fim:EXP_0397|Size:6000|Time:26.7688s...10s para estabilização.
# Linha 328: Fim:EXP_0410|Size:6000|Time:29.1724s...10s para estabilização.
# Linha 329: Fim:EXP_0482|Size:8000|Time:103.5804s...10s para estabilização.
# Linha 330: Fim:EXP_0208|Size:2000|Time:1.1011s...10s para estabilização.
# Linha 331: Fim:EXP_0335|Size:4000|Time:8.0262s...10s para estabilização.
# Linha 332: Fim:EXP_0353|Size:4000|Time:8.1598s...10s para estabilização.
# Linha 333: Fim:EXP_0342|Size:4000|Time:8.0493s...10s para estabilização.
# Linha 334: Fim:EXP_0405|Size:6000|Time:27.7689s...10s para estabilização.
# Linha 335: Fim:EXP_0009|Size:1000|Time:0.4720s...10s para estabilização.
# Linha 336: Fim:EXP_0378|Size:6000|Time:19.1595s...10s para estabilização.
# Linha 337: Fim:EXP_0037|Size:1000|Time:0.5667s...10s para estabilização.
# Linha 338: Fim:EXP_0140|Size:2000|Time:0.9824s...10s para estabilização.
# Linha 339: Fim:EXP_0254|Size:4000|Time:4.3580s...10s para estabilização.
# Linha 340: Fim:EXP_0304|Size:4000|Time:5.3952s...10s para estabilização.
# Linha 341: Fim:EXP_0543|Size:8000|Time:74.2007s...10s para estabilização.
# Linha 342: Fim:EXP_0060|Size:1000|Time:0.5696s...10s para estabilização.
# Linha 343: Fim:EXP_0112|Size:1000|Time:0.6358s...10s para estabilização.
# Linha 344: Fim:EXP_0364|Size:6000|Time:14.5723s...10s para estabilização.
# Linha 345: Fim:EXP_0355|Size:4000|Time:8.0153s...10s para estabilização.
# Linha 346: Fim:EXP_0263|Size:4000|Time:4.3359s...10s para estabilização.
# Linha 347: Fim:EXP_0526|Size:8000|Time:83.7309s...10s para estabilização.
# Linha 348: Fim:EXP_0298|Size:4000|Time:6.5254s...10s para estabilização.
# Linha 349: Fim:EXP_0151|Size:2000|Time:1.3082s...10s para estabilização.
# Linha 350: Fim:EXP_0267|Size:4000|Time:4.3956s...10s para estabilização.
# Linha 351: Fim:EXP_0519|Size:8000|Time:82.4520s...10s para estabilização.
# Linha 352: Fim:EXP_0531|Size:8000|Time:84.5864s...10s para estabilização.
# Linha 353: Fim:EXP_0039|Size:1000|Time:0.5630s...10s para estabilização.
# Linha 354: Fim:EXP_0432|Size:6000|Time:23.2367s...10s para estabilização.
# Linha 355: Fim:EXP_0308|Size:4000|Time:5.4214s...10s para estabilização.
# Linha 356: Fim:EXP_0199|Size:2000|Time:1.0887s...10s para estabilização.
# Linha 357: Fim:EXP_0356|Size:4000|Time:8.0586s...10s para estabilização.
# Linha 358: Fim:EXP_0147|Size:2000|Time:1.0806s...10s para estabilização.
# Linha 359: Fim:EXP_0471|Size:6000|Time:35.6205s...10s para estabilização.
# Linha 360: Fim:EXP_0533|Size:8000|Time:84.8910s...10s para estabilização.
# Linha 361: Fim:EXP_0148|Size:2000|Time:0.9896s...10s para estabilização.
# Linha 362: Fim:EXP_0421|Size:6000|Time:23.9456s...10s para estabilização.
# Linha 363: Fim:EXP_0349|Size:4000|Time:8.0649s...10s para estabilização.
# Linha 364: Fim:EXP_0326|Size:4000|Time:5.2993s...10s para estabilização.
# Linha 365: Fim:EXP_0514|Size:8000|Time:83.8819s...10s para estabilização.
# Linha 366: Fim:EXP_0124|Size:2000|Time:0.9799s...10s para estabilização.
# Linha 367: Fim:EXP_0503|Size:8000|Time:98.2854s...10s para estabilização.
# Linha 368: Fim:EXP_0097|Size:1000|Time:0.6383s...10s para estabilização.
# Linha 369: Fim:EXP_0144|Size:2000|Time:0.9783s...10s para estabilização.
# Linha 370: Fim:EXP_0240|Size:2000|Time:1.4204s...10s para estabilização.
# Linha 371: Fim:EXP_0426|Size:6000|Time:17.9572s...10s para estabilização.
# Linha 372: Fim:EXP_0098|Size:1000|Time:0.6455s...10s para estabilização.
# Linha 373: Fim:EXP_0325|Size:4000|Time:5.2406s...10s para estabilização.
# Linha 374: Fim:EXP_0280|Size:4000|Time:6.4977s...10s para estabilização.
# Linha 375: Fim:EXP_0294|Size:4000|Time:6.4892s...10s para estabilização.
# Linha 376: Fim:EXP_0478|Size:6000|Time:37.2994s...10s para estabilização.
# Linha 377: Fim:EXP_0123|Size:2000|Time:0.9634s...10s para estabilização.
# Linha 378: Fim:EXP_0184|Size:2000|Time:1.0774s...10s para estabilização.
# Linha 379: Fim:EXP_0203|Size:2000|Time:1.0856s...10s para estabilização.
# Linha 380: Fim:EXP_0324|Size:4000|Time:5.3044s...10s para estabilização.
# Linha 381: Fim:EXP_0247|Size:4000|Time:4.3763s...10s para estabilização.
# Linha 382: Fim:EXP_0513|Size:8000|Time:79.3328s...10s para estabilização.
# Linha 383: Fim:EXP_0458|Size:6000|Time:37.8007s...10s para estabilização.
# Linha 384: Fim:EXP_0479|Size:6000|Time:37.9415s...10s para estabilização.
# Linha 385: Fim:EXP_0500|Size:8000|Time:103.5222s...10s para estabilização.
# Linha 386: Fim:EXP_0530|Size:8000|Time:84.4703s...10s para estabilização.
# Linha 387: Fim:EXP_0389|Size:6000|Time:27.2386s...10s para estabilização.
# Linha 388: Fim:EXP_0126|Size:2000|Time:0.9832s...10s para estabilização.
# Linha 389: Fim:EXP_0582|Size:8000|Time:143.5446s...10s para estabilização.
# Linha 390: Fim:EXP_0224|Size:2000|Time:1.4206s...10s para estabilização.
# Linha 391: Fim:EXP_0343|Size:4000|Time:8.0211s...10s para estabilização.
# Linha 392: Fim:EXP_0054|Size:1000|Time:0.5609s...10s para estabilização.
# Linha 393: Fim:EXP_0220|Size:2000|Time:1.4142s...10s para estabilização.
# Linha 394: Fim:EXP_0130|Size:2000|Time:0.9658s...10s para estabilização.
# Linha 395: Fim:EXP_0544|Size:8000|Time:71.6062s...10s para estabilização.
# Linha 396: Fim:EXP_0394|Size:6000|Time:28.8276s...10s para estabilização.
# Linha 397: Fim:EXP_0448|Size:6000|Time:25.8019s...10s para estabilização.
# Linha 398: Fim:EXP_0546|Size:8000|Time:77.9926s...10s para estabilização.
# Linha 399: Fim:EXP_0396|Size:6000|Time:29.2910s...10s para estabilização.
# Linha 400: Fim:EXP_0567|Size:8000|Time:81.2729s...10s para estabilização.
# Linha 401: Fim:EXP_0403|Size:6000|Time:29.3058s...10s para estabilização.
# ...
# Fim:EXP_0431|Size:6000|Time:26.9315s...10s para estabilização.
# Linha 490: Fim:EXP_0101|Size:1000|Time:0.6422s...10s para estabilização.
# Linha 491: Fim:EXP_0227|Size:2000|Time:1.4231s...10s para estabilização.
# Linha 492: Fim:EXP_0449|Size:6000|Time:20.0322s...10s para estabilização.
# Linha 493: Fim:EXP_0548|Size:8000|Time:78.1094s...10s para estabilização.
# Linha 494: Fim:EXP_0572|Size:8000|Time:146.2752s...10s para estabilização.
# Linha 495: Fim:EXP_0214|Size:2000|Time:1.4238s...10s para estabilização.
# Linha 496: Fim:EXP_0360|Size:4000|Time:8.1885s...10s para estabilização.
# Linha 497: Fim:EXP_0172|Size:2000|Time:1.2597s...10s para estabilização.
# Linha 498: Fim:EXP_0099|Size:1000|Time:0.6455s...10s para estabilização.
# Linha 499: Fim:EXP_0293|Size:4000|Time:6.5270s...10s para estabilização.
# Linha 500: Fim:EXP_0216|Size:2000|Time:1.4091s...10s para estabilização.
# Linha 501: Fim:EXP_0062|Size:1000|Time:0.5193s...10s para estabilização.
# Linha 502: Fim:EXP_0407|Size:6000|Time:23.6674s...10s para estabilização.
# Linha 503: Fim:EXP_0048|Size:1000|Time:0.5646s...10s para estabilização.
# Linha 504: Fim:EXP_0033|Size:1000|Time:0.6067s...10s para estabilização.
# Linha 505: Fim:EXP_0418|Size:6000|Time:25.3076s...10s para estabilização.
# Linha 506: Fim:EXP_0268|Size:4000|Time:4.4158s...10s para estabilização.
# Linha 507: Fim:EXP_0328|Size:4000|Time:5.5026s...10s para estabilização.
# Linha 508: Fim:EXP_0201|Size:2000|Time:1.0872s...10s para estabilização.
# Linha 509: Fim:EXP_0135|Size:2000|Time:0.9983s...10s para estabilização.
# Linha 510: Fim:EXP_0028|Size:1000|Time:0.4721s...10s para estabilização.
# Linha 511: Fim:EXP_0525|Size:8000|Time:78.3090s...10s para estabilização.
# Linha 512: Fim:EXP_0506|Size:8000|Time:105.2974s...10s para estabilização.
# Linha 513: Fim:EXP_0231|Size:2000|Time:1.4270s...10s para estabilização.
# Linha 514: Fim:EXP_0490|Size:8000|Time:101.0955s...10s para estabilização.
# Linha 515: Fim:EXP_0261|Size:4000|Time:4.4067s...10s para estabilização.
# Linha 516: Fim:EXP_0379|Size:6000|Time:25.7365s...10s para estabilização.
# Linha 517: Fim:EXP_0289|Size:4000|Time:6.6977s...10s para estabilização.
# Linha 518: Fim:EXP_0419|Size:6000|Time:28.5747s...10s para estabilização.
# Linha 519: Fim:EXP_0392|Size:6000|Time:28.4808s...10s para estabilização.
# Linha 520: Fim:EXP_0499|Size:8000|Time:104.9487s...10s para estabilização.
# Linha 521: Fim:EXP_0139|Size:2000|Time:0.9794s...10s para estabilização.
# Linha 522: Fim:EXP_0063|Size:1000|Time:0.5118s...10s para estabilização.
# Linha 523: Fim:EXP_0472|Size:6000|Time:35.4207s...10s para estabilização.
# Linha 524: Fim:EXP_0129|Size:2000|Time:0.9736s...10s para estabilização.
# Linha 525: Fim:EXP_0584|Size:8000|Time:144.8527s...10s para estabilização.
# Linha 526: Fim:EXP_0521|Size:8000|Time:85.1865s...10s para estabilização.
# Linha 527: Fim:EXP_0065|Size:1000|Time:0.5234s...10s para estabilização.
# Linha 528: Fim:EXP_0015|Size:1000|Time:0.4704s...10s para estabilização.
# Linha 529: Fim:EXP_0157|Size:2000|Time:1.2828s...10s para estabilização.
# Linha 530: Fim:EXP_0041|Size:1000|Time:0.5665s...10s para estabilização.
# Linha 531: Fim:EXP_0493|Size:8000|Time:87.2149s...10s para estabilização.
# Linha 532: Fim:EXP_0380|Size:6000|Time:28.0595s...10s para estabilização.
# Linha 533: Fim:EXP_0188|Size:2000|Time:1.0949s...10s para estabilização.
# Linha 534: Fim:EXP_0217|Size:2000|Time:1.4298s...10s para estabilização.
# Linha 535: Fim:EXP_0053|Size:1000|Time:0.5540s...10s para estabilização.
# Linha 536: Fim:EXP_0338|Size:4000|Time:8.1540s...10s para estabilização.
# Linha 537: Fim:EXP_0296|Size:4000|Time:6.4729s...10s para estabilização.
# Linha 538: Fim:EXP_0252|Size:4000|Time:4.3840s...10s para estabilização.
# Linha 539: Fim:EXP_0462|Size:6000|Time:35.8024s...10s para estabilização.
# Linha 540: Fim:EXP_0456|Size:6000|Time:37.7734s...10s para estabilização.
# Linha 541: Fim:EXP_0598|Size:8000|Time:145.6760s...10s para estabilização.
# Linha 542: Fim:EXP_0270|Size:4000|Time:4.4407s...
# 2025-11-26 09:27:22,191 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/distributed/worker.py", line 1252, in heartbeat
#     response = await retry_operation(
#                ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/distributed/utils_comm.py", line 455, in retry_operation
#     return await retry(
#            ^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/distributed/utils_comm.py", line 434, in retry
#     return await coro()
#            ^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/distributed/core.py", line 1394, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/distributed/core.py", line 1153, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/usr/lib/python3/dist-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:46412 remote=tcp://127.0.0.1:44615>: Stream is closed
# 10s para estabilização.
# Linha 543: Fim:EXP_0202|Size:2000|Time:1.0973s...10s para estabilização.
# Linha 544: Fim:EXP_0162|Size:2000|Time:1.2493s...10s para estabilização.
# Linha 545: Fim:EXP_0402|Size:6000|Time:25.5824s...10s para estabilização.
# Linha 546: Fim:EXP_0477|Size:6000|Time:38.1038s...10s para estabilização.
# Linha 547: Fim:EXP_0106|Size:1000|Time:0.6377s...10s para estabilização.
# Linha 548: Fim:EXP_0390|Size:6000|Time:20.8783s...10s para estabilização.
# Linha 549: Fim:EXP_0002|Size:1000|Time:0.4750s...10s para estabilização.
# Linha 550: Fim:EXP_0559|Size:8000|Time:75.5202s...10s para estabilização.
# Linha 551: Fim:EXP_0081|Size:1000|Time:0.5419s...10s para estabilização.
# Linha 552: Fim:EXP_0206|Size:2000|Time:1.0986s...10s para estabilização.
# Linha 553: Fim:EXP_0035|Size:1000|Time:0.5481s...10s para estabilização.
# Linha 554: Fim:EXP_0509|Size:8000|Time:92.7032s...10s para estabilização.
# Linha 555: Fim:EXP_0428|Size:6000|Time:26.0912s...10s para estabilização.
# Linha 556: Fim:EXP_0455|Size:6000|Time:38.1110s...10s para estabilização.
# Linha 557: Fim:EXP_0367|Size:6000|Time:28.0682s...10s para estabilização.
# Linha 558: Fim:EXP_0092|Size:1000|Time:0.6575s...10s para estabilização.
# Linha 559: Fim:EXP_0340|Size:4000|Time:8.0649s...10s para estabilização.
# Linha 560: Fim:EXP_0346|Size:4000|Time:8.0741s...10s para estabilização.
# Linha 561: Fim:EXP_0242|Size:4000|Time:4.4232s...10s para estabilização.
# Linha 562: Fim:EXP_0014|Size:1000|Time:0.4760s...10s para estabilização.
# Linha 563: Fim:EXP_0316|Size:4000|Time:5.2862s...10s para estabilização.
# Linha 564: Fim:EXP_0388|Size:6000|Time:20.9751s...10s para estabilização.
# Linha 565: Fim:EXP_0274|Size:4000|Time:7.2811s...10s para estabilização.
# Linha 566: Fim:EXP_0167|Size:2000|Time:1.2417s...10s para estabilização.
# Linha 567: Fim:EXP_0595|Size:8000|Time:144.9848s...10s para estabilização.
# Linha 568: Fim:EXP_0485|Size:8000|Time:108.5386s...10s para estabilização.
# Linha 569: Fim:EXP_0586|Size:8000|Time:145.2849s...10s para estabilização.
# Linha 570: Fim:EXP_0505|Size:8000|Time:106.0505s...10s para estabilização.
# Linha 571: Fim:EXP_0244|Size:4000|Time:4.3899s...10s para estabilização.
# Linha 572: Fim:EXP_0563|Size:8000|Time:78.4002s...10s para estabilização.
# Linha 573: Fim:EXP_0190|Size:2000|Time:1.0825s...10s para estabilização.
# Linha 574: Fim:EXP_0476|Size:6000|Time:36.5973s...10s para estabilização.
# Linha 575: Fim:EXP_0511|Size:8000|Time:85.1595s...10s para estabilização.
# Linha 576: Fim:EXP_0059|Size:1000|Time:0.5688s...10s para estabilização.
# Linha 577: Fim:EXP_0475|Size:6000|Time:36.4287s...10s para estabilização.
# Linha 578: Fim:EXP_0561|Size:8000|Time:78.5756s...10s para estabilização.
# Linha 579: Fim:EXP_0253|Size:4000|Time:4.4253s...10s para estabilização.
# Linha 580: Fim:EXP_0022|Size:1000|Time:0.4754s...10s para estabilização.
# Linha 581: Fim:EXP_0314|Size:4000|Time:5.3839s...10s para estabilização.
# Linha 582: Fim:EXP_0460|Size:6000|Time:35.9577s...10s para estabilização.
# Linha 583: Fim:EXP_0161|Size:2000|Time:1.2472s...10s para estabilização.
# Linha 584: Fim:EXP_0277|Size:4000|Time:6.5954s...10s para estabilização.
# Linha 585: Fim:EXP_0192|Size:2000|Time:1.0792s...10s para estabilização.
# Linha 586: Fim:EXP_0386|Size:6000|Time:17.7240s...10s para estabilização.
# Linha 587: Fim:EXP_0414|Size:6000|Time:28.8891s...10s para estabilização.
# Linha 588: Fim:EXP_0492|Size:8000|Time:105.8712s...10s para estabilização.
# Linha 589: Fim:EXP_0344|Size:4000|Time:8.1619s...10s para estabilização.
# Linha 590: Fim:EXP_0309|Size:4000|Time:5.3402s...10s para estabilização.
# Linha 591: Fim:EXP_0131|Size:2000|Time:0.9934s...10s para estabilização.
# Linha 592: Fim:EXP_0100|Size:1000|Time:0.6393s...10s para estabilização.
# Linha 593: Fim:EXP_0373|Size:6000|Time:14.7265s...10s para estabilização.
# Linha 594: Fim:EXP_0088|Size:1000|Time:0.5224s...10s para estabilização.
# Linha 595: Fim:EXP_0459|Size:6000|Time:36.0686s...10s para estabilização.
# Linha 596: Fim:EXP_0331|Size:4000|Time:8.0956s...10s para estabilização.
# Linha 597: Fim:EXP_0215|Size:2000|Time:1.4113s...10s para estabilização.
# Linha 598: Fim:EXP_0467|Size:6000|Time:36.5115s...10s para estabilização.
# Linha 599: Fim:EXP_0122|Size:2000|Time:0.9876s...10s para estabilização.
# Linha 600: Fim:EXP_0021|Size:1000|Time:0.4835s...10s para estabilização.
# Linha 601: Fim:EXP_0072|Size:1000|Time:0.5116s...10s para estabilização.
# Linha 602: Fim:EXP_0107|Size:1000|Time:0.6521s...10s para estabilização.
# Linha 603:
# 2025-11-26 10:04:35,134 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/distributed/worker.py", line 1252, in heartbeat
#     response = await retry_operation(
#                ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/distributed/utils_comm.py", line 455, in retry_operation
#     return await retry(
#            ^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/distributed/utils_comm.py", line 434, in retry
#     return await coro()
#            ^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/distributed/core.py", line 1394, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/distributed/core.py", line 1153, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/usr/lib/python3/dist-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:34462 remote=tcp://127.0.0.1:45127>: Stream is closed
# 2025-11-26 10:04:35,134 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/distributed/worker.py", line 1252, in heartbeat
#     response = await retry_operation(
#                ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/distributed/utils_comm.py", line 455, in retry_operation
#     return await retry(
#            ^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/distributed/utils_comm.py", line 434, in retry
#     return await coro()
#            ^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/distributed/core.py", line 1394, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/distributed/core.py", line 1153, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/usr/lib/python3/dist-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:34438 remote=tcp://127.0.0.1:45127>: Stream is closed
# 2025-11-26 10:04:35,136 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/distributed/worker.py", line 1252, in heartbeat
#     response = await retry_operation(
#                ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/distributed/utils_comm.py", line 455, in retry_operation
#     return await retry(
#            ^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/distributed/utils_comm.py", line 434, in retry
#     return await coro()
#            ^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/distributed/core.py", line 1394, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/distributed/core.py", line 1153, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/usr/lib/python3/dist-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:34474 remote=tcp://127.0.0.1:45127>: Stream is closed
# Fim:EXP_0271|Size:4000|Time:6.4657s...10s para estabilização.
# Linha 604: Fim:EXP_0436|Size:6000|Time:20.1386s...10s para estabilização.
# Linha 605: Fim:EXP_0103|Size:1000|Time:0.6422s...10s para estabilização.
#
# Todos os experimentos do plano foram concluídos.
