# %% [markdown]
# # Implementacão - Python 3.14 (threading)
#
# ## Detalhes
#
# 1. GIL free
# - Python 3.14 não prossui a trava de GIL (Global Interpreter Lock) ou seja é "free-threaded". Isso significa que ao executar um programa Python com múltiplas threads não haverá bloqueio entre as threads, comportamento aplicado pelo GIL que serializava sua execução. Com Python 3.14 o comportamento das threads é de fato paralelo.
#
# 2. Multiprocessing vs Threading
# - Com *multiprocessing* o comportamento é semelhante ao Python 3.12
# - Já com *threading* há compartilhamento real de memória.

# %% [markdown]
# ## Instalação Python 3.14.0t (sem GIL)
#
# 1. Verificação das versões disponíveis
#
# ```python
# pyenv install --list | grep 3.14
#   3.14.0
#   3.14.0t
#   3.14-dev
#   3.14t-dev
#   miniconda2-4.3.14
#   miniconda3-4.3.14
#   pypy2.7-7.3.14-src
#   pypy2.7-7.3.14
#   pypy3.9-7.3.14-src
#   pypy3.9-7.3.14
#   pypy3.10-7.3.14-src
#   pypy3.10-7.3.14
# ```
#
# 2. Seleção da versão correta (sem GIL)
#
# - 3.14.0t: Recomendada. É a versão **estável** (não-dev) do Python 3.14 já **compilada com o suporte Free-Threaded (sem GIL)**. O sufixo *t* é o indicativo oficial disso.
#     - Não é necessário usar a variável PYTHON_CONFIGURE_OPTS="--disable-gil" para a versão 3.14.0t, pois o *pyenv* já sabe que essa variante deve ser compilada sem o GIL.
#
# - 3.14.0: Versão padrão do Python 3.14 com GIL. Não atende ao seu objetivo.
#
# 3. Instalação d aversão free-threaded (sem GIL)
#
# ```python
# pyenv install 3.14.0t
# ```
#
# 4. Ativação da nova versão
# - Isso garantirá que 'python' neste diretório use a versão sem GIL
#
# ```python
# pyenv local 3.14.0t
# pyenv shell 3.14.0t
# ```
#
# 5. Verificar versão
#
# ```python
# python --version
# > Python 3.14.0
# ```
#
# 6. Atualizar atalhos (*Shims*)
# - Necessário recirar os atalhos de comando (shims) para os novos executáveis (como o jupyter) dentro da versão 3.14.0t que foi aitvada
#
# ```python
# pyenv rehash
# ```
#
# - Agora ```jupyter notebook``` deve funcionar
# - Se ainda houver problemas, o comando python abaixo usará a versão 3.14.0t ativa
#
# ```python
# python -m pip install notebook jupyterlab
# ```

# %% [markdown]
# ## Configuração ipykernel para Jupyer Notebook
#
# 1. Exclusão do kernel antigo (com GIL)
# - Excluir kernel associado à versão 3.14.0 que ainda possui GIL.
#
# ```python
# jupyter kernelspec uninstall python-3.14
# ```
#
# 2. Ativar a Versão Python 3.14.0t (Sem GIL)
# - Certifique-se de que o *pyenv* está usando a versão 3.14.0t (a versão sem GIL) para que o ipykernel seja instalado nesse ambiente.
#
# ```python
# pyenv local 3.14.0t
# ```
#
# 3. Instalar o *ipykernel* e o *notebook*
# - Dentro do ambiente 3.14.0t:
#
# ```python
# python -m pip install ipykernel notebook --proxy "http://proxy.tjrs.gov.br:8080"
# pip install --upgrade pip --proxy "http://proxy.tjrs.gov.br:8080"
# ```
#
# 4. Criar o Novo Kernel (Sem GIL)
#
# ```python
# python -m ipykernel install --user --name "python-3.14t-nogil" --display-name "Python 3.14 (No GIL)"
# ```

# %% [markdown]
# ## Execução do Jupyer Notebook
#
# 1. No terminal:
#
# ```bash
# pyenv shell 3.14.0t
# python3 -V
#
# OMP_NUM_THREADS=1 MKL_NUM_THREADS=1 VECLIB_MAXIMUM_THREADS=1 OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 PYTHON_GIL=0 jupyter notebook
# ```
#
# - *OPENBLAS_NUM_THREADS=1* força o numpy a executar a executar o *np.dot()* com apenas uma thread para cada chamada.
#     - Sem essas variáveis de ambiente, para cada chamada do *np.dot()* são disparadas várias threads internas do OpenBLAS.
#     - Assim, com 8 threads no script, cada uma chamadando *np.dot()*, que por sua vez criam várias threads, há excesso de paralelismo, sobrecarga de context switching e muito mais tempo gasto pelos núcleos invalidando e recarregando cache da CPU, impactando o desempenho sobremaneira.
#
# - *PYTHON_GIL=0* força o processo principal do Jupyter (e todos os kernels que ele carrega) a manter o GIL desabilitado.

# %% [markdown]
# ## Aplicação com Threading

# %% [markdown]
# ## Confirmação de versão do Python em uso

# %%
import sys
print(sys.version_info)
# Out:
# sys.version_info(major=3, minor=14, micro=0, releaselevel='final', serial=0)

# %%
# Verificação de versão apenas informativa
print(f"Executando em Python {sys.version}")
# Em Python 3.14 experimental, podemos verificar se o GIL está desabilitado:
try:
    # sys._is_gil_enabled() é esperado nas builds 3.13+/3.14 free-threaded
    gil_status = sys._is_gil_enabled() 
    print(f"GIL Ativo: {gil_status}")
except AttributeError:
    print("Status do GIL: Desconhecido (API sys._is_gil_enabled não encontrada)")
# Out:
# Executando em Python 3.14.0 free-threading build (main, Nov 18 2025, 11:23:52) [GCC 13.3.0]
# GIL Ativo: False

# %%
# !pip install numpy --proxy "http://proxy.tjrs.gov.br:8080"
# !pip install pandas --proxy "http://proxy.tjrs.gov.br:8080"
# Out:
# Requirement already satisfied: numpy in /home/jgross/.pyenv/versions/3.14.0t/lib/python3.14t/site-packages (2.3.5)
# Requirement already satisfied: pandas in /home/jgross/.pyenv/versions/3.14.0t/lib/python3.14t/site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in /home/jgross/.pyenv/versions/3.14.0t/lib/python3.14t/site-packages (from pandas) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/jgross/.pyenv/versions/3.14.0t/lib/python3.14t/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/jgross/.pyenv/versions/3.14.0t/lib/python3.14t/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/jgross/.pyenv/versions/3.14.0t/lib/python3.14t/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/jgross/.pyenv/versions/3.14.0t/lib/python3.14t/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import numpy as np
import sys

# Mostra a versão do NumPy para contexto
print(f"Versão do NumPy: {np.__version__}")
print(f"Versão do Python: {sys.version.split()[0]}\n")

# Usa a API pública para mostrar a configuração
config = np.show_config()
# Out:
# Versão do NumPy: 2.3.5
# Versão do Python: 3.14.0
#
# Build Dependencies:
#   blas:
#     detection method: pkgconfig
#     found: true
#     include directory: /opt/_internal/cpython-3.14.0-nogil/lib/python3.14t/site-packages/scipy_openblas64/include
#     lib directory: /opt/_internal/cpython-3.14.0-nogil/lib/python3.14t/site-packages/scipy_openblas64/lib
#     name: scipy-openblas
#     openblas configuration: OpenBLAS 0.3.30  USE64BITINT DYNAMIC_ARCH NO_AFFINITY
#       Haswell MAX_THREADS=64
#     pc file directory: /project/.openblas
#     version: 0.3.30
#   lapack:
#     detection method: pkgconfig
#     found: true
#     include directory: /opt/_internal/cpython-3.14.0-nogil/lib/python3.14t/site-packages/scipy_openblas64/include
#     lib directory: /opt/_internal/cpython-3.14.0-nogil/lib/python3.14t/site-packages/scipy_openblas64/lib
#     name: scipy-openblas
#     openblas configuration: OpenBLAS 0.3.30  USE64BITINT DYNAMIC_ARCH NO_AFFINITY
#       Haswell MAX_THREADS=64
#     pc file directory: /project/.openblas
#     version: 0.3.30
# Compilers:
#   c:
#     commands: cc
#     linker: ld.bfd
#     name: gcc
#     version: 14.2.1
#   c++:
#     commands: c++
#     linker: ld.bfd
#     name: gcc
#     version: 14.2.1
#   cython:
#     commands: cython
#     linker: cython
#     name: cython
#     version: 3.2.1
# Machine Information:
#   build:
#     cpu: x86_64
#     endian: little
#     family: x86_64
#     system: linux
#   host:
#     cpu: x86_64
#     endian: little
#     family: x86_64
#     system: linux
# Python Information:
#   path: /tmp/build-env-1cal2tar/bin/python
#   version: '3.14'
# SIMD Extensions:
#   baseline:
#   - SSE
#   - SSE2
#   - SSE3
#   found:
#   - SSSE3
#   - SSE41
#   - POPCNT
#   - SSE42
#   - AVX
#   - F16C
#   - FMA3
#   - AVX2
#   not found:
#   - AVX512F
#   - AVX512CD
#   - AVX512_KNL
#   - AVX512_KNM
#   - AVX512_SKX
#   - AVX512_CLX
#   - AVX512_CNL
#   - AVX512_ICL
#   - AVX512_SPR

# %% [markdown]
# # Script 3: Python 3.14.0t com Threading, sem GIL - sem leitura de arquivo

# %%
import concurrent.futures
import os
import sys
import time
import getpass
import numpy as np
import pandas as pd
from datetime import datetime

# --------------------------------------
# CONFIGURATION
MATRIX_SIZE = 1000  # size of NxN matrices

CPU_SETS = {   
    "8P_HT_OFF": [0, 2, 4, 6, 8, 10, 12, 14], # p-cores (8 cores, 1 thread per core)
    "4P_HT_ON": [0, 1, 2, 3, 4, 5, 6, 7], # p-cores (4 cores, 2 threads per core)
    "4P_4E_HT_OFF": [0, 2, 4, 6, 16, 17, 18, 19], # p-cores e e-cores (4 cores p-core, 4 cores e-core)
    "8E": [16, 17, 18, 19, 20, 21, 22, 23] # e-cores (8 cores, 1 thread per core)
}

NUM_RUNS = 1   # runs per CPU set
GOVERNOR = "performance"
IDLE_TIME = 3  # segundos entre execuções

# Variáveis globais (matrizes)
# Em threading, elas são compartilhadas nativamente (Shared Memory)
A_global = None
B_global = None

# --------------------------------------
# Safety check
def safety_check(cpu_ids):
    if MATRIX_SIZE % len(cpu_ids) != 0:
        print(f"Error: MATRIX_SIZE ({MATRIX_SIZE}) is not divisible by number of workers ({len(cpu_ids)}).")
        sys.exit(1)

# --------------------------------------
# Governor configuration (Mantido igual, pois é comando de SO)
def set_governor(governor: str):
    password = getpass.getpass("Sudo password: ")
    bash_command = f"""
    for cpu_file in $(ls -v /sys/devices/system/cpu/cpu*/cpufreq/scaling_governor); do
        cpu_name=$(basename $(dirname $(dirname $cpu_file)))
        echo "{governor}" | sudo tee $cpu_file > /dev/null
        current_gov=$(cat $cpu_file)
        #echo "$cpu_name: $current_gov"
    done
    """
    command = f'echo "{password}" | sudo -S bash -c \'{bash_command}\''
    os.system(command)    
        
# --------------------------------------
# Governor detection
def get_governor(cpu_id):
    path = f"/sys/devices/system/cpu/cpu{cpu_id}/cpufreq/scaling_governor"
    try:
        with open(path) as f:
            return f.read().strip()
    except FileNotFoundError:
        return "N/A"

# --------------------------------------
# Worker task (Threading Version)
def worker_thread_task(args):
    row_index, chunk_size, cpu_ids = args
    
    # Identifica qual worker "lógico" é este com base na linha
    worker_id = row_index // chunk_size
    target_cpu = cpu_ids[worker_id]
    
    # --- DEFINIR AFINIDADE DA THREAD ---
    # No Linux, os.sched_setaffinity(0, ...) aplica-se à thread chamadora (LWP)
    # Isso garante que esta thread Python rode APENAS no núcleo especificado.
    try:
        os.sched_setaffinity(0, {target_cpu})
    except Exception as e:
        print(f"Erro ao definir afinidade na thread para CPU {target_cpu}: {e}")

    # Acesso direto à memória compartilhada (Zero Copy)
    start_row = row_index
    end_row = row_index + chunk_size
    
    # Slicing em numpy cria uma "view", não copia dados, o que é muito eficiente
    A_chunk = A_global[start_row:end_row, :]
    
    # Cálculo
    # Nota: Ao usar Python 3.14, np.dot libera o GIL internamente 
    # permitindo paralelismo real mesmo em Python < 3.13.
    return np.dot(A_chunk, B_global)

# --------------------------------------
# Main execution loop
if __name__ == "__main__":
    
    # Verificação de versão apenas informativa
    print(f"Executando em Python {sys.version}")
    # Em Python 3.14 experimental, podemos verificar se o GIL está desabilitado:
    try:
        # sys._is_gil_enabled() é esperado nas builds 3.13+/3.14 free-threaded
        gil_status = sys._is_gil_enabled() 
        print(f"GIL Ativo: {gil_status}")
    except AttributeError:
        print("Status do GIL: Desconhecido (API sys._is_gil_enabled não encontrada)")

    print("Passo 1: Configurar governor")
    set_governor(GOVERNOR)
    
    results = [] 
    
    # Inicializa as matrizes globais
    # Em threading, não precisamos nos preocupar com fork/spawn, apenas alocamos.
    print("Alocando matrizes...")
    A_global = np.random.rand(MATRIX_SIZE, MATRIX_SIZE).astype(np.float64)
    B_global = np.random.rand(MATRIX_SIZE, MATRIX_SIZE).astype(np.float64)
    
    print("Passo 2: Execuções (Threading Mode)")
    for run in range(1, NUM_RUNS + 1):        
        for label, cores in CPU_SETS.items():
            safety_check(cores)
            
            governor = get_governor(cores[0])
            chunk_size = MATRIX_SIZE // len(cores)
            
            # Tarefas
            tasks = [(i*chunk_size, chunk_size, cores) for i in range(len(cores))]

            start_time = time.time()
            
            # ThreadPoolExecutor substitui mp.Pool
            # max_workers=len(cores) cria exatamente uma thread por núcleo desejado
            with concurrent.futures.ThreadPoolExecutor(max_workers=len(cores)) as executor:
                # executor.map funciona similar ao pool.map, mantendo a ordem
                C_chunks = list(executor.map(worker_thread_task, tasks))
            
            # Combinação de resultados
            C = np.vstack(C_chunks)
            
            end_time = time.time()
            total_time = end_time - start_time
            
            # Validação de resultados
            #C_reference = np.matmul(A_global, B_global)
            #is_match = np.allclose(C, C_reference)
            #validacao_ok = "OK" if is_match else "FAIL"
            #print(f"  -> Validação: {validacao_ok}")
            
            results.append({
                "Run": run,
                "Scenario": label,
                "CPUs_used": cores,
                "Governor": governor,
                "Time_sec": total_time,
                "Result_shape": C.shape
            })
            
            print(f"Run {run} | Time: {total_time:.4f}s | Governor: {governor} | {label}: {cores}")

            #print(f"Aguardando {IDLE_TIME} segundos...\n")
            time.sleep(IDLE_TIME)
            
    df_results = pd.DataFrame(results)
    pd.set_option('display.width', 1000)
    df_reduced = df_results[["Run", "Scenario", "Governor", "Time_sec"]]
    df_sorted = df_reduced.sort_values(by="Scenario", ascending=False)
    print("\nResumo em DataFrame:\n", df_sorted)
    
    now = datetime.now()
    data_str = now.strftime("%Y%m%d") # formato aaaammdd
    hora_str = now.strftime("%H%M%S") # formato hhmmss
    filename = (
    f"experimentos03-threading/{data_str}_{hora_str}_matrix{MATRIX_SIZE}_"
        f"numruns{NUM_RUNS}_{GOVERNOR}.csv"
    )
    df_results.to_csv(filename, index=False)
    print(f"\nResultados salvos em: {filename}")
# Out:
# Executando em Python 3.14.0 free-threading build (main, Nov 18 2025, 11:23:52) [GCC 13.3.0]
# GIL Ativo: False
# Passo 1: Configurar governor
# Sudo password:  ········
# Alocando matrizes...
# Passo 2: Execuções (Threading Mode)
# Run 1 | Time: 0.0128s | Governor: performance | 8P_HT_OFF: [0, 2, 4, 6, 8, 10, 12, 14]
# Run 1 | Time: 0.0137s | Governor: performance | 4P_HT_ON: [0, 1, 2, 3, 4, 5, 6, 7]
# Run 1 | Time: 0.0199s | Governor: performance | 4P_4E_HT_OFF: [0, 2, 4, 6, 16, 17, 18, 19]
# Run 1 | Time: 0.0170s | Governor: performance | 8E: [16, 17, 18, 19, 20, 21, 22, 23]
#
# Resumo em DataFrame:
#     Run      Scenario     Governor  Time_sec
# 0    1     8P_HT_OFF  performance  0.012830
# 3    1            8E  performance  0.017042
# 1    1      4P_HT_ON  performance  0.013664
# 2    1  4P_4E_HT_OFF  performance  0.019866
#
# Resultados salvos em: experimentos03-threading/20251121_065331_matrix1000_numruns1_performance.csv

# %%
# !pip --proxy "http://proxy.tjrs.gov.br:8080" install matplotlib
# !pip --proxy "http://proxy.tjrs.gov.br:8080" install seaborn
# Out:
# Requirement already satisfied: matplotlib in /home/jgross/.pyenv/versions/3.14.0t/lib/python3.14t/site-packages (3.10.7)
# Requirement already satisfied: contourpy>=1.0.1 in /home/jgross/.pyenv/versions/3.14.0t/lib/python3.14t/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/jgross/.pyenv/versions/3.14.0t/lib/python3.14t/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/jgross/.pyenv/versions/3.14.0t/lib/python3.14t/site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/jgross/.pyenv/versions/3.14.0t/lib/python3.14t/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /home/jgross/.pyenv/versions/3.14.0t/lib/python3.14t/site-packages (from matplotlib) (2.3.5)
# Requirement already satisfied: packaging>=20.0 in /home/jgross/.pyenv/versions/3.14.0t/lib/python3.14t/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /home/jgross/.pyenv/versions/3.14.0t/lib/python3.14t/site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /home/jgross/.pyenv/versions/3.14.0t/lib/python3.14t/site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /home/jgross/.pyenv/versions/3.14.0t/lib/python3.14t/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/jgross/.pyenv/versions/3.14.0t/lib/python3.14t/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: seaborn in /home/jgross/.pyenv/versions/3.14.0t/lib/python3.14t/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /home/jgross/.pyenv/versions/3.14.0t/lib/python3.14t/site-packages (from seaborn) (2.3.5)
# Requirement already satisfied: pandas>=1.2 in /home/jgross/.pyenv/versions/3.14.0t/lib/python3.14t/site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /home/jgross/.pyenv/versions/3.14.0t/lib/python3.14t/site-packages (from seaborn) (3.10.7)
# Requirement already satisfied: contourpy>=1.0.1 in /home/jgross/.pyenv/versions/3.14.0t/lib/python3.14t/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/jgross/.pyenv/versions/3.14.0t/lib/python3.14t/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/jgross/.pyenv/versions/3.14.0t/lib/python3.14t/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/jgross/.pyenv/versions/3.14.0t/lib/python3.14t/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /home/jgross/.pyenv/versions/3.14.0t/lib/python3.14t/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in /home/jgross/.pyenv/versions/3.14.0t/lib/python3.14t/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /home/jgross/.pyenv/versions/3.14.0t/lib/python3.14t/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /home/jgross/.pyenv/versions/3.14.0t/lib/python3.14t/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/jgross/.pyenv/versions/3.14.0t/lib/python3.14t/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/jgross/.pyenv/versions/3.14.0t/lib/python3.14t/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/jgross/.pyenv/versions/3.14.0t/lib/python3.14t/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Supondo que seus arquivos estejam em CSV
df1 = pd.read_csv('experimentos03-threading/20251121_065331_matrix1000_numruns1_performance.csv') # Com Turbo Bost
#df2 = pd.read_csv('20251111_170848_matrix1000_numruns5_performance.csv') 

df1['Dataset'] = 'TB-ON'
#df2['Dataset'] = '-'

#df_combined = pd.concat([df1, df2], ignore_index=True)

plt.figure(figsize=(10,6))
#sns.barplot(x='Scenario', y='Time_sec', hue='Dataset', data=df_combined, ci='sd')
sns.barplot(
    x='Scenario',
    y='Time_sec',
    hue='Dataset',
    data=df1,
    estimator='mean'       # calcula a média automaticamente
    #errorbar='sd'           # mostra desvio padrão
)
plt.title('Comparação de Tempo de Execução por Cenário (média ± desvio padrão)')
plt.ylabel('Tempo (segundos)')
plt.xlabel('Cenário')
plt.legend(title='Observações')

# Salvar como PDF
#plt.savefig('grafico_time_sec.pdf', format='pdf', bbox_inches='tight')

# Salvar como PNG
plt.savefig('grafico_time_sec.png', format='png', dpi=300, bbox_inches='tight')

plt.show()

# %% [markdown]
# # Script 3: Python 3.14.0t com Threading, sem GIL - com leitura de arquivo
#
# - Mesmo process id (pid)
# - Cada Thread em um core distinto
# - Memória compartilhada entre as threads (Zero copy)
#
#
# ## Características dos Scripts
#
# 1. Script Multiprocessing:
# - Criadas matrizes globais nulas
# - Estas matrizes são inicializadas dentro da contagem de tempo
# - Os processos filho compartilham a memória do pai (Copy on Write)
#
# 2. Script Dask
# - Matrizes criadas e inicializadas dentro da contagem de tempo
# - Dask cria um grafo para distribuir entre as tarefas
# - Não há memória
#
# 3. Script Threading
# - Criadas matrizes globais nulas
# - Estas matrizes são inicializadas dentro da contagem de tempo
# - As threads compartilham a memória do processo pai (Zero Copy)

# %%
import concurrent.futures
import os
import sys
import time
import psutil
import getpass
import numpy as np
import pandas as pd
from datetime import datetime
import gc

# --------------------------------------
# CONFIGURATION GLOBAL
np.random.seed(42)

PLAN_FILE = "experiments_plan.csv"
GOVERNOR = "performance"
IDLE_TIME = 10  # Tempo de resfriamento entre experimentos

# Variáveis globais (matrizes) para serem herdadas pelos workers
A_global = None
B_global = None

# --------------------------------------
# Governor configuration (Mantido igual, pois é comando de SO)
def set_governor(governor: str):
    password = getpass.getpass("Sudo password: ")
    bash_command = f"""
    for cpu_file in $(ls -v /sys/devices/system/cpu/cpu*/cpufreq/scaling_governor); do
        cpu_name=$(basename $(dirname $(dirname $cpu_file)))
        echo "{governor}" | sudo tee $cpu_file > /dev/null
        current_gov=$(cat $cpu_file)
        #echo "$cpu_name: $current_gov"
    done
    """
    command = f'echo "{password}" | sudo -S bash -c \'{bash_command}\''
    os.system(command)    
        
# --------------------------------------
# Governor detection
def get_governor(cpu_id):
    path = f"/sys/devices/system/cpu/cpu{cpu_id}/cpufreq/scaling_governor"
    try:
        with open(path) as f:
            return f.read().strip()
    except FileNotFoundError:
        return "N/A"

# --------------------------------------
# Worker task (Threading Version)
def worker_thread_task(args):
    row_index, chunk_size, cpu_ids = args
    
    # Identifica qual worker "lógico" é este com base na linha
    worker_id = row_index // chunk_size
    target_cpu = cpu_ids[worker_id]
    
    # Define a afinidade
    p = psutil.Process(os.getpid())
    p.cpu_affinity([cpu_ids[worker_id]])

    # Verifica onde o SO realmente colocou o processo
    # (Pode variar momentaneamente se o scheduler ainda estiver movendo a task)
    #actual_pid = os.getpid()
    #actual_core = p.cpu_num() 
    
    # O flush=True é vital em multiprocessing para o print não sair embaralhado
    #print(f"[Worker {worker_id}] PID: {actual_pid} | Alvo: {[cpu_ids[worker_id]]} | Real: {actual_core}\n", end="", flush=True)
    
    # Acesso direto à memória compartilhada (Zero Copy)
    start_row = row_index
    end_row = row_index + chunk_size
    
    # Slicing em numpy cria uma "view", não copia dados, o que é muito eficiente
    A_chunk = A_global[start_row:end_row, :]
    
    # Cálculo
    # Nota: Ao usar Python 3.14, np.dot libera o GIL internamente 
    # permitindo paralelismo real mesmo em Python < 3.13.
    return np.dot(A_chunk, B_global)

def parse_cpu_list_string(cpu_str):
    """
    Converte string "[0; 2; 4]" para lista [0, 2, 4]
    """
    clean_str = cpu_str.replace('[', '').replace(']', '').replace(' ', '')
    if not clean_str:
        return []
    return [int(x) for x in clean_str.split(';')]

def get_cpu_temperature():
    """
    Retorna a temperatura atual da CPU.
    Tenta identificar sensores comuns (coretemp, k10temp).
    Retorna a temperatura máxima entre os núcleos (pior caso) ou None se falhar.
    """
    try:
        temps = psutil.sensors_temperatures()
        if not temps:
            return None

        # Sensores comuns em Linux x86
        # 'coretemp' geralmente é Intel, 'k10temp' é AMD
        sensor_names = ['coretemp', 'k10temp', 'cpu_thermal', 'acpitz']
        
        for name in sensor_names:
            if name in temps:
                # Retorna a temperatura máxima registrada entre os cores desse sensor
                return max(entry.current for entry in temps[name])
        
        # Fallback: pega o primeiro sensor disponível se não achar os conhecidos
        first_key = next(iter(temps))
        return max(entry.current for entry in temps[first_key])

    except Exception as e:
        print(f"Aviso: Não foi possível ler temperatura: {e}")
        return None

# --------------------------------------
# Main execution loop
if __name__ == "__main__":
    
    # Verificação de versão apenas informativa
    print(f"Executando em Python {sys.version}")
    # Em Python 3.14 experimental, podemos verificar se o GIL está desabilitado:
    try:
        # sys._is_gil_enabled() é esperado nas builds 3.13+/3.14 free-threaded
        gil_status = sys._is_gil_enabled() 
        print(f"GIL Ativo: {gil_status}")
    except AttributeError:
        print("Status do GIL: Desconhecido (API sys._is_gil_enabled não encontrada)")

    # 1. Configuração Inicial
    set_governor(GOVERNOR)

    # 2. Carregar Plano de Experimentos
    if not os.path.exists(PLAN_FILE):
        print(f"Erro: Arquivo '{PLAN_FILE}' não encontrado.")
        sys.exit(1)
    
    df_plan = pd.read_csv(PLAN_FILE)
    print(f"Carregado plano com {len(df_plan)} experimentos.")

    # 3. Preparar arquivo de saída
    now = datetime.now()
    timestamp_str = now.strftime("%Y%m%d_%H%M%S")
    output_filename = f"exp03-threading/result_exp_threading_{timestamp_str}.csv"
    
    print(f"Resultados salvos incrementalmente em: {output_filename}")

    # 4. Loop de Execução
    for idx, row in df_plan.iterrows():
        print(f"Linha {idx}: ", end="", flush=True)
        
        # Extrair dados da linha
        exp_id = row['Experiment_ID']
        matrix_size = int(row['Matrix_Size'])
        cpu_set_name = row['CPU_Set_Name']
        run_number = row['Run_Number']
    
        # Parse da lista de cores
        try:
            cores = parse_cpu_list_string(row['CPU_Cores_List'])
        except Exception as e:
            print(f"Erro ao ler lista de CPUs na linha {idx}: {e}")
            continue
    
        if len(cores) == 0:
            print("Lista de CPUs vazia. Pulando.")
            continue
    
        # Validação de segurança
        if matrix_size % len(cores) != 0:
            print(f"AVISO: Matrix size {matrix_size} não é divisível por {len(cores)} cores.")
            sys.exit(0)  

        # Garantir que o governor está correto
        current_governor = get_governor(cores[0])
        
        # Inicializa as matrizes
        # Em threading, não precisamos nos preocupar com fork/spawn, apenas alocamos.
        print(f"Gerando matrizes {matrix_size}x{matrix_size}...", end="", flush=True)       
        A_global = np.random.rand(matrix_size, matrix_size).astype(np.float64)
        B_global = np.random.rand(matrix_size, matrix_size).astype(np.float64)

        chunk_size = matrix_size // len(cores)
            
        # Tarefas
        tasks = [(i*chunk_size, chunk_size, cores) for i in range(len(cores))]
        
        start_time = time.time()
        
        # ThreadPoolExecutor substitui mp.Pool
        # max_workers=len(cores) cria exatamente uma thread por núcleo desejado
        with concurrent.futures.ThreadPoolExecutor(max_workers=len(cores)) as executor:
            # executor.map funciona similar ao pool.map, mantendo a ordem
            C_chunks = list(executor.map(worker_thread_task, tasks))
            
        # Combinação de resultados
        C = np.vstack(C_chunks)
        
        end_time = time.time()
        total_time = end_time - start_time
        
        # Validação de resultados
        #C_reference = np.matmul(A_global, B_global)
        #is_match = np.allclose(C, C_reference)
        #validacao_ok = "OK" if is_match else "FAIL"
        #print(f"  -> Validação: {validacao_ok}")
                        
        print(f"Fim:{exp_id}|Size:{matrix_size}|Time:{total_time:.4f}s...", end="", flush=True)

        # Leitura de temperatura
        current_temp = get_cpu_temperature()
        #print(f" Temp: {current_temp}°C ... ", end="", flush=True)
        
        # 5. Salvar Resultado (Append)
        # Copiamos a linha original e adicionamos as métricas
        result_row = row.to_dict()
        result_row['Experiment_ID'] = exp_id
        result_row['Matrix_Size'] = matrix_size
        result_row['CPU_Set_Name'] = cpu_set_name
        result_row['Run_Number'] = run_number
        result_row['Executed_Governor'] = current_governor
        result_row['Time_sec'] = total_time
        result_row['Temp°C'] = current_temp
        result_row['Timestamp'] = datetime.now().isoformat()

        df_result_row = pd.DataFrame([result_row])

        # Se o arquivo não existe, escreve header. Se existe, append sem header.
        header_mode = not os.path.exists(output_filename)
        df_result_row.to_csv(output_filename, mode='a', header=header_mode, index=False)               
        
        # Limpeza agressiva
        A_global = None
        B_global = None
        del C_chunks
        del C
        gc.collect() # Força limpeza das variáveis

        # Resfriamento
        print(f"{IDLE_TIME}s para estabilização.")
        time.sleep(IDLE_TIME)

    print("\nTodos os experimentos do plano foram concluídos.")
# Out:
# Executando em Python 3.14.0 free-threading build (main, Nov 18 2025, 11:23:52) [GCC 13.3.0]
# GIL Ativo: False
# Sudo password:  ········
# Carregado plano com 606 experimentos.
# Resultados salvos incrementalmente em: exp03-threading/result_exp_threading_20251126_131759.csv
# Linha 0: Gerando matrizes 8000x8000...Fim:EXP_WARMUP|Size:8000|Time:2.5428s...10s para estabilização.
# Linha 1: Gerando matrizes 8000x8000...Fim:EXP_WARMUP|Size:8000|Time:2.5132s...10s para estabilização.
# Linha 2: Gerando matrizes 8000x8000...Fim:EXP_WARMUP|Size:8000|Time:2.5276s...10s para estabilização.
# Linha 3: Gerando matrizes 8000x8000...Fim:EXP_WARMUP|Size:8000|Time:2.5757s...10s para estabilização.
# Linha 4: Gerando matrizes 8000x8000...Fim:EXP_WARMUP|Size:8000|Time:2.5606s...10s para estabilização.
# Linha 5: Gerando matrizes 8000x8000...Fim:EXP_WARMUP|Size:8000|Time:2.5523s...10s para estabilização.
# Linha 6: Gerando matrizes 1000x1000...Fim:EXP_0111|Size:1000|Time:0.0428s...10s para estabilização.
# Linha 7: Gerando matrizes 6000x6000...Fim:EXP_0420|Size:6000|Time:2.2394s...10s para estabilização.
# Linha 8: Gerando matrizes 8000x8000...Fim:EXP_0566|Size:8000|Time:5.5873s...10s para estabilização.
# Linha 9: Gerando matrizes 1000x1000...Fim:EXP_0078|Size:1000|Time:0.0213s...10s para estabilização.
# Linha 10: Gerando matrizes 2000x2000...Fim:EXP_0182|Size:2000|Time:0.1108s...10s para estabilização.
# Linha 11: Gerando matrizes 4000x4000...Fim:EXP_0285|Size:4000|Time:0.6645s...10s para estabilização.
# Linha 12: Gerando matrizes 1000x1000...Fim:EXP_0011|Size:1000|Time:0.0125s...10s para estabilização.
# Linha 13: Gerando matrizes 6000x6000...Fim:EXP_0470|Size:6000|Time:2.6234s...10s para estabilização.
# Linha 14: Gerando matrizes 1000x1000...Fim:EXP_0079|Size:1000|Time:0.0216s...10s para estabilização.
# Linha 15: Gerando matrizes 4000x4000...Fim:EXP_0350|Size:4000|Time:2.0457s...10s para estabilização.
# Linha 16: Gerando matrizes 1000x1000...Fim:EXP_0056|Size:1000|Time:0.0145s...10s para estabilização.
# Linha 17: Gerando matrizes 1000x1000...Fim:EXP_0119|Size:1000|Time:0.0193s...10s para estabilização.
# Linha 18: Gerando matrizes 1000x1000...Fim:EXP_0110|Size:1000|Time:0.0230s...10s para estabilização.
# Linha 19: Gerando matrizes 8000x8000...Fim:EXP_0589|Size:8000|Time:5.9681s...10s para estabilização.
# Linha 20: Gerando matrizes 6000x6000...Fim:EXP_0370|Size:6000|Time:2.4012s...10s para estabilização.
# Linha 21: Gerando matrizes 2000x2000...Fim:EXP_0235|Size:2000|Time:0.1081s...10s para estabilização.
# Linha 22: Gerando matrizes 1000x1000...Fim:EXP_0031|Size:1000|Time:0.0160s...10s para estabilização.
# Linha 23: Gerando matrizes 2000x2000...Fim:EXP_0213|Size:2000|Time:0.1074s...10s para estabilização.
# Linha 24: Gerando matrizes 2000x2000...Fim:EXP_0185|Size:2000|Time:0.0994s...10s para estabilização.
# Linha 25: Gerando matrizes 1000x1000...Fim:EXP_0087|Size:1000|Time:0.0214s...10s para estabilização.
# Linha 26: Gerando matrizes 1000x1000...Fim:EXP_0003|Size:1000|Time:0.0165s...10s para estabilização.
# Linha 27: Gerando matrizes 8000x8000...Fim:EXP_0588|Size:8000|Time:10.2551s...10s para estabilização.
# Linha 28: Gerando matrizes 8000x8000...Fim:EXP_0536|Size:8000|Time:5.2743s...10s para estabilização.
# Linha 29: Gerando matrizes 8000x8000...Fim:EXP_0597|Size:8000|Time:5.9972s...10s para estabilização.
# Linha 30: Gerando matrizes 6000x6000...Fim:EXP_0369|Size:6000|Time:2.3992s...10s para estabilização.
# Linha 31: Gerando matrizes 8000x8000...Fim:EXP_0540|Size:8000|Time:4.0580s...10s para estabilização.
# Linha 32: Gerando matrizes 1000x1000...Fim:EXP_0073|Size:1000|Time:0.0198s...10s para estabilização.
# Linha 33: Gerando matrizes 2000x2000...Fim:EXP_0136|Size:2000|Time:0.0969s...10s para estabilização.
# Linha 34: Gerando matrizes 8000x8000...Fim:EXP_0557|Size:8000|Time:5.4142s...10s para estabilização.
# Linha 35: Gerando matrizes 6000x6000...Fim:EXP_0438|Size:6000|Time:2.3406s...10s para estabilização.
# Linha 36: Gerando matrizes 8000x8000...Fim:EXP_0596|Size:8000|Time:15.9813s...10s para estabilização.
# Linha 37: Gerando matrizes 2000x2000...Fim:EXP_0164|Size:2000|Time:0.0897s...10s para estabilização.
# Linha 38: Gerando matrizes 1000x1000...Fim:EXP_0083|Size:1000|Time:0.0214s...10s para estabilização.
# Linha 39: Gerando matrizes 4000x4000...Fim:EXP_0258|Size:4000|Time:0.7246s...10s para estabilização.
# Linha 40: Gerando matrizes 2000x2000...Fim:EXP_0193|Size:2000|Time:0.1042s...10s para estabilização.
# Linha 41: Gerando matrizes 6000x6000...Fim:EXP_0454|Size:6000|Time:6.8523s...10s para estabilização.
# Linha 42: Gerando matrizes 2000x2000...Fim:EXP_0133|Size:2000|Time:0.0966s...10s para estabilização.
# Linha 43: Gerando matrizes 8000x8000...Fim:EXP_0516|Size:8000|Time:4.0382s...10s para estabilização.
# Linha 44: Gerando matrizes 6000x6000...Fim:EXP_0442|Size:6000|Time:2.3500s...10s para estabilização.
# Linha 45: Gerando matrizes 4000x4000...Fim:EXP_0276|Size:4000|Time:0.9235s...10s para estabilização.
# Linha 46: Gerando matrizes 6000x6000...Fim:EXP_0365|Size:6000|Time:2.4230s...10s para estabilização.
# Linha 47: Gerando matrizes 1000x1000...Fim:EXP_0030|Size:1000|Time:0.0121s...10s para estabilização.
# Linha 48: Gerando matrizes 8000x8000...Fim:EXP_0507|Size:8000|Time:2.5170s...10s para estabilização.
# Linha 49: Gerando matrizes 8000x8000...Fim:EXP_0571|Size:8000|Time:5.9850s...10s para estabilização.
# Linha 50: Gerando matrizes 1000x1000...Fim:EXP_0025|Size:1000|Time:0.0164s...10s para estabilização.
# Linha 51: Gerando matrizes 2000x2000...Fim:EXP_0183|Size:2000|Time:0.1047s...10s para estabilização.
# Linha 52: Gerando matrizes 6000x6000...Fim:EXP_0474|Size:6000|Time:4.7131s...10s para estabilização.
# Linha 53: Gerando matrizes 1000x1000...Fim:EXP_0105|Size:1000|Time:0.0345s...10s para estabilização.
# Linha 54: Gerando matrizes 1000x1000...Fim:EXP_0064|Size:1000|Time:0.0210s...10s para estabilização.
# Linha 55: Gerando matrizes 8000x8000...Fim:EXP_0491|Size:8000|Time:5.5803s...10s para estabilização.
# Linha 56: Gerando matrizes 4000x4000...Fim:EXP_0246|Size:4000|Time:0.3450s...10s para estabilização.
# Linha 57: Gerando matrizes 4000x4000...Fim:EXP_0249|Size:4000|Time:0.5487s...10s para estabilização.
# Linha 58: Gerando matrizes 1000x1000...Fim:EXP_0102|Size:1000|Time:0.0335s...10s para estabilização.
# Linha 59: Gerando matrizes 8000x8000...Fim:EXP_0556|Size:8000|Time:5.4754s...10s para estabilização.
# Linha 60: Gerando matrizes 8000x8000...Fim:EXP_0592|Size:8000|Time:10.9720s...10s para estabilização.
# Linha 61: Gerando matrizes 4000x4000...Fim:EXP_0357|Size:4000|Time:0.7776s...10s para estabilização.
# Linha 62: Gerando matrizes 2000x2000...Fim:EXP_0210|Size:2000|Time:0.0994s...10s para estabilização.
# Linha 63: Gerando matrizes 2000x2000...Fim:EXP_0166|Size:2000|Time:0.0890s...10s para estabilização.
# Linha 64: Gerando matrizes 2000x2000...Fim:EXP_0138|Size:2000|Time:0.0713s...10s para estabilização.
# Linha 65: Gerando matrizes 2000x2000...Fim:EXP_0196|Size:2000|Time:0.1862s...10s para estabilização.
# Linha 66: Gerando matrizes 1000x1000...Fim:EXP_0077|Size:1000|Time:0.0220s...10s para estabilização.
# Linha 67: Gerando matrizes 2000x2000...Fim:EXP_0177|Size:2000|Time:0.0911s...10s para estabilização.
# Linha 68: Gerando matrizes 4000x4000...Fim:EXP_0330|Size:4000|Time:0.7529s...10s para estabilização.
# Linha 69: Gerando matrizes 8000x8000...Fim:EXP_0537|Size:8000|Time:5.2331s...10s para estabilização.
# Linha 70: Gerando matrizes 8000x8000...Fim:EXP_0549|Size:8000|Time:7.0454s...10s para estabilização.
# Linha 71: Gerando matrizes 1000x1000...Fim:EXP_0071|Size:1000|Time:0.0313s...10s para estabilização.
# Linha 72: Gerando matrizes 8000x8000...Fim:EXP_0562|Size:8000|Time:15.3740s...10s para estabilização.
# Linha 73: Gerando matrizes 8000x8000...Fim:EXP_0590|Size:8000|Time:15.9797s...10s para estabilização.
# Linha 74: Gerando matrizes 1000x1000...Fim:EXP_0082|Size:1000|Time:0.0206s...10s para estabilização.
# Linha 75: Gerando matrizes 4000x4000...Fim:EXP_0317|Size:4000|Time:0.7952s...10s para estabilização.
# Linha 76: Gerando matrizes 4000x4000...Fim:EXP_0305|Size:4000|Time:0.7985s...10s para estabilização.
# Linha 77: Gerando matrizes 1000x1000...Fim:EXP_0007|Size:1000|Time:0.0160s...10s para estabilização.
# Linha 78: Gerando matrizes 6000x6000...Fim:EXP_0424|Size:6000|Time:2.4077s...10s para estabilização.
# Linha 79: Gerando matrizes 6000x6000...Fim:EXP_0375|Size:6000|Time:2.4436s...10s para estabilização.
# Linha 80: Gerando matrizes 6000x6000...Fim:EXP_0430|Size:6000|Time:2.4133s...10s para estabilização.
# Linha 81: Gerando matrizes 8000x8000...Fim:EXP_0538|Size:8000|Time:5.2344s...10s para estabilização.
# Linha 82: Gerando matrizes 4000x4000...Fim:EXP_0313|Size:4000|Time:1.9564s...10s para estabilização.
# Linha 83: Gerando matrizes 2000x2000...Fim:EXP_0239|Size:2000|Time:0.2708s...10s para estabilização.
# Linha 84: Gerando matrizes 8000x8000...Fim:EXP_0560|Size:8000|Time:5.3775s...10s para estabilização.
# Linha 85: Gerando matrizes 6000x6000...Fim:EXP_0433|Size:6000|Time:2.6446s...10s para estabilização.
# Linha 86: Gerando matrizes 4000x4000...Fim:EXP_0287|Size:4000|Time:0.6809s...10s para estabilização.
# Linha 87: Gerando matrizes 6000x6000...Fim:EXP_0427|Size:6000|Time:2.3560s...10s para estabilização.
# Linha 88: Gerando matrizes 8000x8000...Fim:EXP_0599|Size:8000|Time:10.9724s...10s para estabilização.
# Linha 89: Gerando matrizes 6000x6000...Fim:EXP_0362|Size:6000|Time:2.3997s...10s para estabilização.
# Linha 90: Gerando matrizes 1000x1000...Fim:EXP_0074|Size:1000|Time:0.0204s...10s para estabilização.
# Linha 91: Gerando matrizes 1000x1000...Fim:EXP_0040|Size:1000|Time:0.0155s...10s para estabilização.
# Linha 92: Gerando matrizes 2000x2000...Fim:EXP_0156|Size:2000|Time:0.0740s...10s para estabilização.
# Linha 93: Gerando matrizes 2000x2000...Fim:EXP_0219|Size:2000|Time:0.1068s...10s para estabilização.
# Linha 94: Gerando matrizes 6000x6000...Fim:EXP_0371|Size:6000|Time:2.4033s...10s para estabilização.
# Linha 95: Gerando matrizes 2000x2000...Fim:EXP_0211|Size:2000|Time:0.1919s...10s para estabilização.
# Linha 96: Gerando matrizes 2000x2000...Fim:EXP_0236|Size:2000|Time:0.1879s...10s para estabilização.
# Linha 97: Gerando matrizes 8000x8000...Fim:EXP_0547|Size:8000|Time:5.4607s...10s para estabilização.
# Linha 98: Gerando matrizes 1000x1000...Fim:EXP_0061|Size:1000|Time:0.0225s...10s para estabilização.
# Linha 99: Gerando matrizes 4000x4000...Fim:EXP_0301|Size:4000|Time:0.7966s...10s para estabilização.
# Linha 100: Gerando matrizes 4000x4000...Fim:EXP_0260|Size:4000|Time:0.7221s...10s para estabilização.
# Linha 101: Gerando matrizes 4000x4000...Fim:EXP_0281|Size:4000|Time:0.5049s...10s para estabilização.
# Linha 102: Gerando matrizes 2000x2000...Fim:EXP_0229|Size:2000|Time:0.1086s...10s para estabilização.
# Linha 103: Gerando matrizes 1000x1000...Fim:EXP_0012|Size:1000|Time:0.0174s...10s para estabilização.
# Linha 104: Gerando matrizes 6000x6000...Fim:EXP_0413|Size:6000|Time:2.3808s...10s para estabilização.
# Linha 105: Gerando matrizes 1000x1000...Fim:EXP_0084|Size:1000|Time:0.0179s...10s para estabilização.
# Linha 106: Gerando matrizes 1000x1000...Fim:EXP_0091|Size:1000|Time:0.0328s...10s para estabilização.
# Linha 107: Gerando matrizes 2000x2000...Fim:EXP_0209|Size:2000|Time:0.1010s...10s para estabilização.
# Linha 108: Gerando matrizes 8000x8000...Fim:EXP_0539|Size:8000|Time:5.2338s...10s para estabilização.
# Linha 109: Gerando matrizes 4000x4000...Fim:EXP_0336|Size:4000|Time:0.7904s...10s para estabilização.
# Linha 110: Gerando matrizes 1000x1000...Fim:EXP_0080|Size:1000|Time:0.0383s...10s para estabilização.
# Linha 111: Gerando matrizes 6000x6000...Fim:EXP_0435|Size:6000|Time:2.6449s...10s para estabilização.
# Linha 112: Gerando matrizes 2000x2000...Fim:EXP_0141|Size:2000|Time:0.1025s...10s para estabilização.
# Linha 113: Gerando matrizes 4000x4000...Fim:EXP_0282|Size:4000|Time:0.5114s...10s para estabilização.
# Linha 114: Gerando matrizes 4000x4000...Fim:EXP_0269|Size:4000|Time:0.5438s...10s para estabilização.
# Linha 115: Gerando matrizes 6000x6000...Fim:EXP_0415|Size:6000|Time:1.6798s...10s para estabilização.
# Linha 116: Gerando matrizes 2000x2000...Fim:EXP_0200|Size:2000|Time:0.1006s...10s para estabilização.
# Linha 117: Gerando matrizes 6000x6000...Fim:EXP_0465|Size:6000|Time:4.7090s...10s para estabilização.
# Linha 118: Gerando matrizes 8000x8000...Fim:EXP_0576|Size:8000|Time:10.2879s...10s para estabilização.
# Linha 119: Gerando matrizes 8000x8000...Fim:EXP_0585|Size:8000|Time:15.2744s...10s para estabilização.
# Linha 120: Gerando matrizes 6000x6000...Fim:EXP_0372|Size:6000|Time:2.3979s...10s para estabilização.
# Linha 121: Gerando matrizes 6000x6000...Fim:EXP_0400|Size:6000|Time:1.6860s...10s para estabilização.
# Linha 122: Gerando matrizes 4000x4000...Fim:EXP_0341|Size:4000|Time:0.7829s...10s para estabilização.
# Linha 123: Gerando matrizes 2000x2000...Fim:EXP_0149|Size:2000|Time:0.0970s...10s para estabilização.
# Linha 124: Gerando matrizes 8000x8000...Fim:EXP_0495|Size:8000|Time:4.1573s...10s para estabilização.
# Linha 125: Gerando matrizes 6000x6000...Fim:EXP_0440|Size:6000|Time:2.4924s...10s para estabilização.
# Linha 126: Gerando matrizes 2000x2000...Fim:EXP_0146|Size:2000|Time:0.0960s...10s para estabilização.
# Linha 127: Gerando matrizes 1000x1000...Fim:EXP_0010|Size:1000|Time:0.0119s...10s para estabilização.
# Linha 128: Gerando matrizes 6000x6000...Fim:EXP_0376|Size:6000|Time:1.1070s...10s para estabilização.
# Linha 129: Gerando matrizes 8000x8000...Fim:EXP_0524|Size:8000|Time:4.0535s...10s para estabilização.
# Linha 130: Gerando matrizes 2000x2000...Fim:EXP_0189|Size:2000|Time:0.1018s...10s para estabilização.
# Linha 131: Gerando matrizes 2000x2000...Fim:EXP_0132|Size:2000|Time:0.0971s...10s para estabilização.
# Linha 132: Gerando matrizes 8000x8000...Fim:EXP_0573|Size:8000|Time:5.9950s...10s para estabilização.
# Linha 133: Gerando matrizes 4000x4000...Fim:EXP_0299|Size:4000|Time:0.6736s...10s para estabilização.
# Linha 134: Gerando matrizes 8000x8000...Fim:EXP_0587|Size:8000|Time:5.9923s...10s para estabilização.
# Linha 135: Gerando matrizes 6000x6000...Fim:EXP_0447|Size:6000|Time:2.3635s...10s para estabilização.
# Linha 136: Gerando matrizes 1000x1000...Fim:EXP_0085|Size:1000|Time:0.0219s...10s para estabilização.
# Linha 137: Gerando matrizes 8000x8000...Fim:EXP_0593|Size:8000|Time:10.9638s...10s para estabilização.
# Linha 138: Gerando matrizes 2000x2000...Fim:EXP_0178|Size:2000|Time:0.0976s...10s para estabilização.
# Linha 139: Gerando matrizes 2000x2000...Fim:EXP_0154|Size:2000|Time:0.1290s...10s para estabilização.
# Linha 140: Gerando matrizes 6000x6000...Fim:EXP_0453|Size:6000|Time:2.5804s...10s para estabilização.
# Linha 141: Gerando matrizes 2000x2000...Fim:EXP_0197|Size:2000|Time:0.1008s...10s para estabilização.
# Linha 142: Gerando matrizes 1000x1000...Fim:EXP_0076|Size:1000|Time:0.0307s...10s para estabilização.
# Linha 143: Gerando matrizes 1000x1000...Fim:EXP_0093|Size:1000|Time:0.0408s...10s para estabilização.
# Linha 144: Gerando matrizes 4000x4000...Fim:EXP_0297|Size:4000|Time:0.6648s...10s para estabilização.
# Linha 145: Gerando matrizes 1000x1000...Fim:EXP_0069|Size:1000|Time:0.0196s...10s para estabilização.
# Linha 146: Gerando matrizes 1000x1000...Fim:EXP_0016|Size:1000|Time:0.0151s...10s para estabilização.
# Linha 147: Gerando matrizes 2000x2000...Fim:EXP_0205|Size:2000|Time:0.1029s...10s para estabilização.
# Linha 148: Gerando matrizes 2000x2000...Fim:EXP_0159|Size:2000|Time:0.1052s...10s para estabilização.
# Linha 149: Gerando matrizes 1000x1000...Fim:EXP_0089|Size:1000|Time:0.0194s...10s para estabilização.
# Linha 150: Gerando matrizes 8000x8000...Fim:EXP_0498|Size:8000|Time:5.5776s...10s para estabilização.
# Linha 151: Gerando matrizes 1000x1000...Fim:EXP_0118|Size:1000|Time:0.0197s...10s para estabilização.
# Linha 152: Gerando matrizes 6000x6000...Fim:EXP_0383|Size:6000|Time:2.4049s...10s para estabilização.
# Linha 153: Gerando matrizes 6000x6000...Fim:EXP_0406|Size:6000|Time:2.4045s...10s para estabilização.
# Linha 154: Gerando matrizes 1000x1000...Fim:EXP_0034|Size:1000|Time:0.0209s...10s para estabilização.
# Linha 155: Gerando matrizes 1000x1000...Fim:EXP_0001|Size:1000|Time:0.0166s...10s para estabilização.
# Linha 156: Gerando matrizes 8000x8000...Fim:EXP_0594|Size:8000|Time:10.9899s...10s para estabilização.
# Linha 157: Gerando matrizes 8000x8000...Fim:EXP_0532|Size:8000|Time:5.5785s...10s para estabilização.
# Linha 158: Gerando matrizes 4000x4000...Fim:EXP_0354|Size:4000|Time:0.7871s...10s para estabilização.
# Linha 159: Gerando matrizes 4000x4000...Fim:EXP_0333|Size:4000|Time:0.7761s...10s para estabilização.
# Linha 160: Gerando matrizes 8000x8000...Fim:EXP_0535|Size:8000|Time:5.2232s...10s para estabilização.
# Linha 161: Gerando matrizes 4000x4000...Fim:EXP_0245|Size:4000|Time:0.7399s...10s para estabilização.
# Linha 162: Gerando matrizes 1000x1000...Fim:EXP_0023|Size:1000|Time:0.0126s...10s para estabilização.
# Linha 163: Gerando matrizes 6000x6000...Fim:EXP_0441|Size:6000|Time:2.4076s...10s para estabilização.
# Linha 164: Gerando matrizes 1000x1000...Fim:EXP_0117|Size:1000|Time:0.0425s...10s para estabilização.
# Linha 165: Gerando matrizes 1000x1000...Fim:EXP_0090|Size:1000|Time:0.0198s...10s para estabilização.
# Linha 166: Gerando matrizes 6000x6000...Fim:EXP_0366|Size:6000|Time:2.3990s...10s para estabilização.
# Linha 167: Gerando matrizes 2000x2000...Fim:EXP_0212|Size:2000|Time:0.1083s...10s para estabilização.
# Linha 168: Gerando matrizes 1000x1000...Fim:EXP_0019|Size:1000|Time:0.0156s...10s para estabilização.
# Linha 169: Gerando matrizes 6000x6000...Fim:EXP_0408|Size:6000|Time:1.6810s...10s para estabilização.
# Linha 170: Gerando matrizes 4000x4000...Fim:EXP_0321|Size:4000|Time:0.7284s...10s para estabilização.
# Linha 171: Gerando matrizes 2000x2000...Fim:EXP_0145|Size:2000|Time:0.0966s...10s para estabilização.
# Linha 172: Gerando matrizes 4000x4000...Fim:EXP_0290|Size:4000|Time:0.7146s...10s para estabilização.
# Linha 173: Gerando matrizes 4000x4000...Fim:EXP_0275|Size:4000|Time:0.9400s...10s para estabilização.
# Linha 174: Gerando matrizes 8000x8000...Fim:EXP_0542|Size:8000|Time:5.4215s...10s para estabilização.
# Linha 175: Gerando matrizes 6000x6000...Fim:EXP_0361|Size:6000|Time:2.4017s...10s para estabilização.
# Linha 176: Gerando matrizes 4000x4000...Fim:EXP_0251|Size:4000|Time:0.3441s...10s para estabilização.
# Linha 177: Gerando matrizes 4000x4000...Fim:EXP_0288|Size:4000|Time:0.5072s...10s para estabilização.
# Linha 178: Gerando matrizes 8000x8000...Fim:EXP_0529|Size:8000|Time:5.5502s...10s para estabilização.
# Linha 179: Gerando matrizes 6000x6000...Fim:EXP_0401|Size:6000|Time:1.7137s...10s para estabilização.
# Linha 180: Gerando matrizes 2000x2000...Fim:EXP_0168|Size:2000|Time:0.0993s...10s para estabilização.
# Linha 181: Gerando matrizes 1000x1000...Fim:EXP_0055|Size:1000|Time:0.0202s...10s para estabilização.
# Linha 182: Gerando matrizes 8000x8000...Fim:EXP_0494|Size:8000|Time:5.8187s...10s para estabilização.
# Linha 183: Gerando matrizes 1000x1000...Fim:EXP_0047|Size:1000|Time:0.0146s...10s para estabilização.
# Linha 184: Gerando matrizes 1000x1000...Fim:EXP_0094|Size:1000|Time:0.0323s...10s para estabilização.
# Linha 185: Gerando matrizes 4000x4000...Fim:EXP_0265|Size:4000|Time:0.7241s...10s para estabilização.
# Linha 186: Gerando matrizes 1000x1000...Fim:EXP_0109|Size:1000|Time:0.0197s...10s para estabilização.
# Linha 187: Gerando matrizes 4000x4000...Fim:EXP_0273|Size:4000|Time:0.6636s...10s para estabilização.
# Linha 188: Gerando matrizes 8000x8000...Fim:EXP_0600|Size:8000|Time:5.9766s...10s para estabilização.
# Linha 189: Gerando matrizes 6000x6000...Fim:EXP_0480|Size:6000|Time:4.4192s...10s para estabilização.
# Linha 190: Gerando matrizes 6000x6000...Fim:EXP_0437|Size:6000|Time:2.3559s...10s para estabilização.
# Linha 191: Gerando matrizes 6000x6000...Fim:EXP_0384|Size:6000|Time:2.4018s...10s para estabilização.
# Linha 192: Gerando matrizes 6000x6000...Fim:EXP_0381|Size:6000|Time:2.4478s...10s para estabilização.
# Linha 193: Gerando matrizes 6000x6000...Fim:EXP_0463|Size:6000|Time:2.5792s...10s para estabilização.
# Linha 194: Gerando matrizes 6000x6000...Fim:EXP_0395|Size:6000|Time:2.3666s...10s para estabilização.
# Linha 195: Gerando matrizes 4000x4000...Fim:EXP_0266|Size:4000|Time:0.5286s...10s para estabilização.
# Linha 196: Gerando matrizes 8000x8000...Fim:EXP_0481|Size:8000|Time:2.5012s...10s para estabilização.
# Linha 197: Gerando matrizes 8000x8000...Fim:EXP_0518|Size:8000|Time:3.9723s...10s para estabilização.
# Linha 198: Gerando matrizes 1000x1000...Fim:EXP_0070|Size:1000|Time:0.0207s...10s para estabilização.
# Linha 199: Gerando matrizes 2000x2000...Fim:EXP_0232|Size:2000|Time:0.2701s...10s para estabilização.
# Linha 200: Gerando matrizes 6000x6000...Fim:EXP_0404|Size:6000|Time:2.2348s...10s para estabilização.
# Linha 201: Gerando matrizes 4000x4000...Fim:EXP_0279|Size:4000|Time:0.5216s...10s para estabilização.
# Linha 202: Gerando matrizes 6000x6000...Fim:EXP_0473|Size:6000|Time:2.5768s...10s para estabilização.
# Linha 203: Gerando matrizes 4000x4000...Fim:EXP_0351|Size:4000|Time:0.7762s...10s para estabilização.
# Linha 204: Gerando matrizes 8000x8000...Fim:EXP_0510|Size:8000|Time:5.5825s...10s para estabilização.
# Linha 205: Gerando matrizes 2000x2000...Fim:EXP_0150|Size:2000|Time:0.0497s...10s para estabilização.
# Linha 206: Gerando matrizes 2000x2000...Fim:EXP_0125|Size:2000|Time:0.0505s...10s para estabilização.
# Linha 207: Gerando matrizes 6000x6000...Fim:EXP_0429|Size:6000|Time:2.4054s...10s para estabilização.
# Linha 208: Gerando matrizes 6000x6000...Fim:EXP_0466|Size:6000|Time:4.7161s...10s para estabilização.
# Linha 209: Gerando matrizes 2000x2000...Fim:EXP_0186|Size:2000|Time:0.1004s...10s para estabilização.
# Linha 210: Gerando matrizes 2000x2000...Fim:EXP_0228|Size:2000|Time:0.1866s...10s para estabilização.
# Linha 211: Gerando matrizes 4000x4000...Fim:EXP_0292|Size:4000|Time:0.6678s...10s para estabilização.
# Linha 212: Gerando matrizes 4000x4000...Fim:EXP_0248|Size:4000|Time:0.5270s...10s para estabilização.
# Linha 213: Gerando matrizes 4000x4000...Fim:EXP_0291|Size:4000|Time:0.7147s...10s para estabilização.
# Linha 214: Gerando matrizes 4000x4000...Fim:EXP_0250|Size:4000|Time:0.5337s...10s para estabilização.
# Linha 215: Gerando matrizes 6000x6000...Fim:EXP_0444|Size:6000|Time:2.4104s...10s para estabilização.
# Linha 216: Gerando matrizes 8000x8000...Fim:EXP_0552|Size:8000|Time:5.3991s...10s para estabilização.
# Linha 217: Gerando matrizes 8000x8000...Fim:EXP_0553|Size:8000|Time:5.4187s...10s para estabilização.
# Linha 218: Gerando matrizes 8000x8000...Fim:EXP_0551|Size:8000|Time:6.1263s...10s para estabilização.
# Linha 219: Gerando matrizes 1000x1000...Fim:EXP_0115|Size:1000|Time:0.0421s...10s para estabilização.
# Linha 220: Gerando matrizes 2000x2000...Fim:EXP_0204|Size:2000|Time:0.1001s...10s para estabilização.
# Linha 221: Gerando matrizes 2000x2000...Fim:EXP_0142|Size:2000|Time:0.0965s...10s para estabilização.
# Linha 222: Gerando matrizes 4000x4000...Fim:EXP_0339|Size:4000|Time:0.7806s...10s para estabilização.
# Linha 223: Gerando matrizes 1000x1000...Fim:EXP_0008|Size:1000|Time:0.0159s...10s para estabilização.
# Linha 224: Gerando matrizes 8000x8000...Fim:EXP_0522|Size:8000|Time:5.5318s...10s para estabilização.
# Linha 225: Gerando matrizes 1000x1000...Fim:EXP_0020|Size:1000|Time:0.0173s...10s para estabilização.
# Linha 226: Gerando matrizes 2000x2000...Fim:EXP_0173|Size:2000|Time:0.0729s...10s para estabilização.
# Linha 227: Gerando matrizes 6000x6000...Fim:EXP_0452|Size:6000|Time:6.5738s...10s para estabilização.
# Linha 228: Gerando matrizes 1000x1000...Fim:EXP_0057|Size:1000|Time:0.0159s...10s para estabilização.
# Linha 229: Gerando matrizes 4000x4000...Fim:EXP_0302|Size:4000|Time:0.7156s...10s para estabilização.
# Linha 230: Gerando matrizes 4000x4000...Fim:EXP_0337|Size:4000|Time:2.0504s...10s para estabilização.
# Linha 231: Gerando matrizes 6000x6000...Fim:EXP_0451|Size:6000|Time:2.5712s...10s para estabilização.
# Linha 232: Gerando matrizes 4000x4000...Fim:EXP_0323|Size:4000|Time:0.7124s...10s para estabilização.
# Linha 233: Gerando matrizes 4000x4000...Fim:EXP_0311|Size:4000|Time:0.7966s...10s para estabilização.
# Linha 234: Gerando matrizes 1000x1000...Fim:EXP_0050|Size:1000|Time:0.0146s...10s para estabilização.
# Linha 235: Gerando matrizes 4000x4000...Fim:EXP_0345|Size:4000|Time:0.7870s...10s para estabilização.
# Linha 236: Gerando matrizes 1000x1000...Fim:EXP_0026|Size:1000|Time:0.0210s...10s para estabilização.
# Linha 237: Gerando matrizes 6000x6000...Fim:EXP_0443|Size:6000|Time:4.4953s...10s para estabilização.
# Linha 238: Gerando matrizes 2000x2000...Fim:EXP_0221|Size:2000|Time:0.2714s...10s para estabilização.
# Linha 239: Gerando matrizes 8000x8000...Fim:EXP_0484|Size:8000|Time:5.5797s...10s para estabilização.
# Linha 240: Gerando matrizes 8000x8000...Fim:EXP_0541|Size:8000|Time:5.7362s...10s para estabilização.
# Linha 241: Gerando matrizes 1000x1000...Fim:EXP_0043|Size:1000|Time:0.0159s...10s para estabilização.
# Linha 242: Gerando matrizes 6000x6000...Fim:EXP_0417|Size:6000|Time:2.3810s...10s para estabilização.
# Linha 243: Gerando matrizes 4000x4000...Fim:EXP_0262|Size:4000|Time:0.5292s...10s para estabilização.
# Linha 244: Gerando matrizes 6000x6000...Fim:EXP_0409|Size:6000|Time:2.4009s...10s para estabilização.
# Linha 245: Gerando matrizes 4000x4000...Fim:EXP_0278|Size:4000|Time:0.9734s...10s para estabilização.
# Linha 246: Gerando matrizes 8000x8000...Fim:EXP_0570|Size:8000|Time:5.4314s...10s para estabilização.
# Linha 247: Gerando matrizes 6000x6000...Fim:EXP_0382|Size:6000|Time:2.3995s...10s para estabilização.
# Linha 248: Gerando matrizes 6000x6000...Fim:EXP_0412|Size:6000|Time:1.6866s...10s para estabilização.
# Linha 249: Gerando matrizes 2000x2000...Fim:EXP_0155|Size:2000|Time:0.0716s...10s para estabilização.
# Linha 250: Gerando matrizes 2000x2000...Fim:EXP_0127|Size:2000|Time:0.0793s...10s para estabilização.
# Linha 251: Gerando matrizes 4000x4000...Fim:EXP_0310|Size:4000|Time:0.7355s...10s para estabilização.
# Linha 252: Gerando matrizes 8000x8000...Fim:EXP_0520|Size:8000|Time:5.2161s...10s para estabilização.
# Linha 253: Gerando matrizes 6000x6000...Fim:EXP_0446|Size:6000|Time:2.3100s...10s para estabilização.
# Linha 254: Gerando matrizes 2000x2000...Fim:EXP_0175|Size:2000|Time:0.1267s...10s para estabilização.
# Linha 255: Gerando matrizes 1000x1000...Fim:EXP_0032|Size:1000|Time:0.0190s...10s para estabilização.
# Linha 256: Gerando matrizes 1000x1000...Fim:EXP_0114|Size:1000|Time:0.0192s...10s para estabilização.
# Linha 257: Gerando matrizes 1000x1000...Fim:EXP_0024|Size:1000|Time:0.0165s...10s para estabilização.
# Linha 258: Gerando matrizes 2000x2000...Fim:EXP_0174|Size:2000|Time:0.1039s...10s para estabilização.
# Linha 259: Gerando matrizes 8000x8000...Fim:EXP_0558|Size:8000|Time:15.3133s...10s para estabilização.
# Linha 260: Gerando matrizes 1000x1000...Fim:EXP_0067|Size:1000|Time:0.0227s...10s para estabilização.
# Linha 261: Gerando matrizes 1000x1000...Fim:EXP_0058|Size:1000|Time:0.0199s...10s para estabilização.
# Linha 262: Gerando matrizes 4000x4000...Fim:EXP_0322|Size:4000|Time:0.7249s...10s para estabilização.
# Linha 263: Gerando matrizes 2000x2000...Fim:EXP_0223|Size:2000|Time:0.2697s...10s para estabilização.
# Linha 264: Gerando matrizes 1000x1000...Fim:EXP_0018|Size:1000|Time:0.0145s...10s para estabilização.
# Linha 265: Gerando matrizes 4000x4000...Fim:EXP_0300|Size:4000|Time:0.7165s...10s para estabilização.
# Linha 266: Gerando matrizes 4000x4000...Fim:EXP_0256|Size:4000|Time:0.5302s...10s para estabilização.
# Linha 267: Gerando matrizes 4000x4000...Fim:EXP_0306|Size:4000|Time:0.7344s...10s para estabilização.
# Linha 268: Gerando matrizes 8000x8000...Fim:EXP_0574|Size:8000|Time:15.3345s...10s para estabilização.
# Linha 269: Gerando matrizes 2000x2000...Fim:EXP_0191|Size:2000|Time:0.0998s...10s para estabilização.
# Linha 270: Gerando matrizes 4000x4000...Fim:EXP_0319|Size:4000|Time:0.7965s...10s para estabilização.
# Linha 271: Gerando matrizes 8000x8000...Fim:EXP_0528|Size:8000|Time:5.2183s...10s para estabilização.
# Linha 272: Gerando matrizes 4000x4000...Fim:EXP_0272|Size:4000|Time:0.9215s...10s para estabilização.
# Linha 273: Gerando matrizes 1000x1000...Fim:EXP_0095|Size:1000|Time:0.0324s...10s para estabilização.
# Linha 274: Gerando matrizes 2000x2000...Fim:EXP_0181|Size:2000|Time:0.1011s...10s para estabilização.
# Linha 275: Gerando matrizes 4000x4000...Fim:EXP_0332|Size:4000|Time:2.0508s...10s para estabilização.
# Linha 276: Gerando matrizes 4000x4000...Fim:EXP_0329|Size:4000|Time:1.3359s...10s para estabilização.
# Linha 277: Gerando matrizes 4000x4000...Fim:EXP_0312|Size:4000|Time:0.7406s...10s para estabilização.
# Linha 278: Gerando matrizes 1000x1000...Fim:EXP_0006|Size:1000|Time:0.0172s...10s para estabilização.
# Linha 279: Gerando matrizes 1000x1000...Fim:EXP_0046|Size:1000|Time:0.0177s...10s para estabilização.
# Linha 280: Gerando matrizes 6000x6000...Fim:EXP_0399|Size:6000|Time:2.3637s...10s para estabilização.
# Linha 281: Gerando matrizes 8000x8000...Fim:EXP_0577|Size:8000|Time:5.9803s...10s para estabilização.
# Linha 282: Gerando matrizes 6000x6000...Fim:EXP_0469|Size:6000|Time:4.4299s...10s para estabilização.
# Linha 283: Gerando matrizes 1000x1000...Fim:EXP_0017|Size:1000|Time:0.0163s...10s para estabilização.
# Linha 284: Gerando matrizes 1000x1000...Fim:EXP_0049|Size:1000|Time:0.0179s...10s para estabilização.
# Linha 285: Gerando matrizes 8000x8000...Fim:EXP_0580|Size:8000|Time:5.9768s...10s para estabilização.
# Linha 286: Gerando matrizes 8000x8000...Fim:EXP_0488|Size:8000|Time:5.5786s...10s para estabilização.
# Linha 287: Gerando matrizes 1000x1000...Fim:EXP_0004|Size:1000|Time:0.0137s...10s para estabilização.
# Linha 288: Gerando matrizes 8000x8000...Fim:EXP_0487|Size:8000|Time:2.4993s...10s para estabilização.
# Linha 289: Gerando matrizes 6000x6000...Fim:EXP_0439|Size:6000|Time:4.4939s...10s para estabilização.
# Linha 290: Gerando matrizes 6000x6000...Fim:EXP_0363|Size:6000|Time:2.4049s...10s para estabilização.
# Linha 291: Gerando matrizes 6000x6000...Fim:EXP_0434|Size:6000|Time:2.5110s...10s para estabilização.
# Linha 292: Gerando matrizes 4000x4000...Fim:EXP_0303|Size:4000|Time:0.7982s...10s para estabilização.
# Linha 293: Gerando matrizes 2000x2000...Fim:EXP_0226|Size:2000|Time:0.2719s...10s para estabilização.
# Linha 294: Gerando matrizes 1000x1000...Fim:EXP_0027|Size:1000|Time:0.0161s...10s para estabilização.
# Linha 295: Gerando matrizes 6000x6000...Fim:EXP_0425|Size:6000|Time:2.3603s...10s para estabilização.
# Linha 296: Gerando matrizes 4000x4000...Fim:EXP_0264|Size:4000|Time:0.7218s...10s para estabilização.
# Linha 297: Gerando matrizes 1000x1000...Fim:EXP_0051|Size:1000|Time:0.0238s...10s para estabilização.
# Linha 298: Gerando matrizes 2000x2000...Fim:EXP_0230|Size:2000|Time:0.1834s...10s para estabilização.
# Linha 299: Gerando matrizes 1000x1000...Fim:EXP_0038|Size:1000|Time:0.0147s...10s para estabilização.
# Linha 300: Gerando matrizes 2000x2000...Fim:EXP_0158|Size:2000|Time:0.1034s...10s para estabilização.
# Linha 301: Gerando matrizes 2000x2000...Fim:EXP_0238|Size:2000|Time:0.1813s...10s para estabilização.
# Linha 302: Gerando matrizes 8000x8000...Fim:EXP_0575|Size:8000|Time:5.9769s...10s para estabilização.
# Linha 303: Gerando matrizes 2000x2000...Fim:EXP_0176|Size:2000|Time:0.0974s...10s para estabilização.
# Linha 304: Gerando matrizes 8000x8000...Fim:EXP_0515|Size:8000|Time:5.5587s...10s para estabilização.
# Linha 305: Gerando matrizes 4000x4000...Fim:EXP_0358|Size:4000|Time:0.7856s...10s para estabilização.
# Linha 306: Gerando matrizes 2000x2000...Fim:EXP_0195|Size:2000|Time:0.0999s...10s para estabilização.
# Linha 307: Gerando matrizes 8000x8000...Fim:EXP_0504|Size:8000|Time:5.5737s...10s para estabilização.
# Linha 308: Gerando matrizes 8000x8000...Fim:EXP_0579|Size:8000|Time:10.3046s...10s para estabilização.
# Linha 309: Gerando matrizes 8000x8000...Fim:EXP_0512|Size:8000|Time:5.2269s...10s para estabilização.
# Linha 310: Gerando matrizes 1000x1000...Fim:EXP_0068|Size:1000|Time:0.0199s...10s para estabilização.
# Linha 311: Gerando matrizes 4000x4000...Fim:EXP_0320|Size:4000|Time:0.7770s...10s para estabilização.
# Linha 312: Gerando matrizes 2000x2000...Fim:EXP_0169|Size:2000|Time:0.0910s...10s para estabilização.
# Linha 313: Gerando matrizes 6000x6000...Fim:EXP_0368|Size:6000|Time:2.4889s...10s para estabilização.
# Linha 314: Gerando matrizes 2000x2000...Fim:EXP_0163|Size:2000|Time:0.1117s...10s para estabilização.
# Linha 315: Gerando matrizes 2000x2000...Fim:EXP_0194|Size:2000|Time:0.1005s...10s para estabilização.
# Linha 316: Gerando matrizes 2000x2000...Fim:EXP_0153|Size:2000|Time:0.0896s...10s para estabilização.
# Linha 317: Gerando matrizes 8000x8000...Fim:EXP_0502|Size:8000|Time:3.9972s...10s para estabilização.
# Linha 318: Gerando matrizes 4000x4000...Fim:EXP_0347|Size:4000|Time:0.7814s...10s para estabilização.
# Linha 319: Gerando matrizes 8000x8000...Fim:EXP_0486|Size:8000|Time:5.5832s...10s para estabilização.
# Linha 320: Gerando matrizes 4000x4000...Fim:EXP_0334|Size:4000|Time:0.7824s...10s para estabilização.
# Linha 321: Gerando matrizes 1000x1000...Fim:EXP_0104|Size:1000|Time:0.0230s...10s para estabilização.
# Linha 322: Gerando matrizes 6000x6000...Fim:EXP_0391|Size:6000|Time:3.0480s...10s para estabilização.
# Linha 323: Gerando matrizes 1000x1000...Fim:EXP_0075|Size:1000|Time:0.0369s...10s para estabilização.
# Linha 324: Gerando matrizes 6000x6000...Fim:EXP_0423|Size:6000|Time:2.6364s...10s para estabilização.
# Linha 325: Gerando matrizes 8000x8000...Fim:EXP_0578|Size:8000|Time:10.9683s...10s para estabilização.
# Linha 326: Gerando matrizes 1000x1000...Fim:EXP_0120|Size:1000|Time:0.0216s...10s para estabilização.
# Linha 327: Gerando matrizes 6000x6000...Fim:EXP_0397|Size:6000|Time:2.4031s...10s para estabilização.
# Linha 328: Gerando matrizes 6000x6000...Fim:EXP_0410|Size:6000|Time:1.7256s...10s para estabilização.
# Linha 329: Gerando matrizes 8000x8000...Fim:EXP_0482|Size:8000|Time:5.6434s...10s para estabilização.
# Linha 330: Gerando matrizes 2000x2000...Fim:EXP_0208|Size:2000|Time:0.1024s...10s para estabilização.
# Linha 331: Gerando matrizes 4000x4000...Fim:EXP_0335|Size:4000|Time:2.0497s...10s para estabilização.
# Linha 332: Gerando matrizes 4000x4000...Fim:EXP_0353|Size:4000|Time:0.7726s...10s para estabilização.
# Linha 333: Gerando matrizes 4000x4000...Fim:EXP_0342|Size:4000|Time:0.7726s...10s para estabilização.
# Linha 334: Gerando matrizes 6000x6000...Fim:EXP_0405|Size:6000|Time:2.2339s...10s para estabilização.
# Linha 335: Gerando matrizes 1000x1000...Fim:EXP_0009|Size:1000|Time:0.0122s...10s para estabilização.
# Linha 336: Gerando matrizes 6000x6000...Fim:EXP_0378|Size:6000|Time:1.0919s...10s para estabilização.
# Linha 337: Gerando matrizes 1000x1000...Fim:EXP_0037|Size:1000|Time:0.0161s...10s para estabilização.
# Linha 338: Gerando matrizes 2000x2000...Fim:EXP_0140|Size:2000|Time:0.0713s...10s para estabilização.
# Linha 339: Gerando matrizes 4000x4000...Fim:EXP_0254|Size:4000|Time:0.3389s...10s para estabilização.
# Linha 340: Gerando matrizes 4000x4000...Fim:EXP_0304|Size:4000|Time:0.7339s...10s para estabilização.
# Linha 341: Gerando matrizes 8000x8000...Fim:EXP_0543|Size:8000|Time:15.3632s...10s para estabilização.
# Linha 342: Gerando matrizes 1000x1000...Fim:EXP_0060|Size:1000|Time:0.0188s...10s para estabilização.
# Linha 343: Gerando matrizes 1000x1000...Fim:EXP_0112|Size:1000|Time:0.0188s...10s para estabilização.
# Linha 344: Gerando matrizes 6000x6000...Fim:EXP_0364|Size:6000|Time:2.4020s...10s para estabilização.
# Linha 345: Gerando matrizes 4000x4000...Fim:EXP_0355|Size:4000|Time:0.7823s...10s para estabilização.
# Linha 346: Gerando matrizes 4000x4000...Fim:EXP_0263|Size:4000|Time:0.7219s...10s para estabilização.
# Linha 347: Gerando matrizes 8000x8000...Fim:EXP_0526|Size:8000|Time:5.6581s...10s para estabilização.
# Linha 348: Gerando matrizes 4000x4000...Fim:EXP_0298|Size:4000|Time:0.7212s...10s para estabilização.
# Linha 349: Gerando matrizes 2000x2000...Fim:EXP_0151|Size:2000|Time:0.1039s...10s para estabilização.
# Linha 350: Gerando matrizes 4000x4000...Fim:EXP_0267|Size:4000|Time:0.7281s...10s para estabilização.
# Linha 351: Gerando matrizes 8000x8000...Fim:EXP_0519|Size:8000|Time:3.9654s...10s para estabilização.
# Linha 352: Gerando matrizes 8000x8000...Fim:EXP_0531|Size:8000|Time:5.5617s...10s para estabilização.
# Linha 353: Gerando matrizes 1000x1000...Fim:EXP_0039|Size:1000|Time:0.0214s...10s para estabilização.
# Linha 354: Gerando matrizes 6000x6000...Fim:EXP_0432|Size:6000|Time:2.4851s...10s para estabilização.
# Linha 355: Gerando matrizes 4000x4000...Fim:EXP_0308|Size:4000|Time:0.7968s...10s para estabilização.
# Linha 356: Gerando matrizes 2000x2000...Fim:EXP_0199|Size:2000|Time:0.1095s...10s para estabilização.
# Linha 357: Gerando matrizes 4000x4000...Fim:EXP_0356|Size:4000|Time:2.0499s...10s para estabilização.
# Linha 358: Gerando matrizes 2000x2000...Fim:EXP_0147|Size:2000|Time:0.0969s...10s para estabilização.
# Linha 359: Gerando matrizes 6000x6000...Fim:EXP_0471|Size:6000|Time:2.5803s...10s para estabilização.
# Linha 360: Gerando matrizes 8000x8000...Fim:EXP_0533|Size:8000|Time:5.2194s...10s para estabilização.
# Linha 361: Gerando matrizes 2000x2000...Fim:EXP_0148|Size:2000|Time:0.0714s...10s para estabilização.
# Linha 362: Gerando matrizes 6000x6000...Fim:EXP_0421|Size:6000|Time:2.3554s...10s para estabilização.
# Linha 363: Gerando matrizes 4000x4000...Fim:EXP_0349|Size:4000|Time:2.0453s...10s para estabilização.
# Linha 364: Gerando matrizes 4000x4000...Fim:EXP_0326|Size:4000|Time:0.7131s...10s para estabilização.
# Linha 365: Gerando matrizes 8000x8000...Fim:EXP_0514|Size:8000|Time:5.5992s...10s para estabilização.
# Linha 366: Gerando matrizes 2000x2000...Fim:EXP_0124|Size:2000|Time:0.0719s...10s para estabilização.
# Linha 367: Gerando matrizes 8000x8000...Fim:EXP_0503|Size:8000|Time:2.5286s...10s para estabilização.
# Linha 368: Gerando matrizes 1000x1000...Fim:EXP_0097|Size:1000|Time:0.0193s...10s para estabilização.
# Linha 369: Gerando matrizes 2000x2000...Fim:EXP_0144|Size:2000|Time:0.0965s...10s para estabilização.
# Linha 370: Gerando matrizes 2000x2000...Fim:EXP_0240|Size:2000|Time:0.2015s...10s para estabilização.
# Linha 371: Gerando matrizes 6000x6000...Fim:EXP_0426|Size:6000|Time:2.3592s...10s para estabilização.
# Linha 372: Gerando matrizes 1000x1000...Fim:EXP_0098|Size:1000|Time:0.0430s...10s para estabilização.
# Linha 373: Gerando matrizes 4000x4000...Fim:EXP_0325|Size:4000|Time:0.7143s...10s para estabilização.
# Linha 374: Gerando matrizes 4000x4000...Fim:EXP_0280|Size:4000|Time:0.6664s...10s para estabilização.
# Linha 375: Gerando matrizes 4000x4000...Fim:EXP_0294|Size:4000|Time:0.5147s...10s para estabilização.
# Linha 376: Gerando matrizes 6000x6000...Fim:EXP_0478|Size:6000|Time:2.5796s...10s para estabilização.
# Linha 377: Gerando matrizes 2000x2000...Fim:EXP_0123|Size:2000|Time:0.0965s...10s para estabilização.
# Linha 378: Gerando matrizes 2000x2000...Fim:EXP_0184|Size:2000|Time:0.1058s...10s para estabilização.
# Linha 379: Gerando matrizes 2000x2000...Fim:EXP_0203|Size:2000|Time:0.1102s...10s para estabilização.
# Linha 380: Gerando matrizes 4000x4000...Fim:EXP_0324|Size:4000|Time:0.7983s...10s para estabilização.
# Linha 381: Gerando matrizes 4000x4000...Fim:EXP_0247|Size:4000|Time:0.7247s...10s para estabilização.
# Linha 382: Gerando matrizes 8000x8000...Fim:EXP_0513|Size:8000|Time:3.9223s...10s para estabilização.
# Linha 383: Gerando matrizes 6000x6000...Fim:EXP_0458|Size:6000|Time:2.5764s...10s para estabilização.
# Linha 384: Gerando matrizes 6000x6000...Fim:EXP_0479|Size:6000|Time:4.4298s...10s para estabilização.
# Linha 385: Gerando matrizes 8000x8000...Fim:EXP_0500|Size:8000|Time:5.4372s...10s para estabilização.
# Linha 386: Gerando matrizes 8000x8000...Fim:EXP_0530|Size:8000|Time:5.6298s...10s para estabilização.
# Linha 387: Gerando matrizes 6000x6000...Fim:EXP_0389|Size:6000|Time:2.4173s...10s para estabilização.
# Linha 388: Gerando matrizes 2000x2000...Fim:EXP_0126|Size:2000|Time:0.0583s...10s para estabilização.
# Linha 389: Gerando matrizes 8000x8000...Fim:EXP_0582|Size:8000|Time:5.3083s...10s para estabilização.
# Linha 390: Gerando matrizes 2000x2000...Fim:EXP_0224|Size:2000|Time:0.1085s...10s para estabilização.
# Linha 391: Gerando matrizes 4000x4000...Fim:EXP_0343|Size:4000|Time:1.9630s...10s para estabilização.
# Linha 392: Gerando matrizes 1000x1000...Fim:EXP_0054|Size:1000|Time:0.0255s...10s para estabilização.
# Linha 393: Gerando matrizes 2000x2000...Fim:EXP_0220|Size:2000|Time:0.1907s...10s para estabilização.
# Linha 394: Gerando matrizes 2000x2000...Fim:EXP_0130|Size:2000|Time:0.0959s...10s para estabilização.
# Linha 395: Gerando matrizes 8000x8000...Fim:EXP_0544|Size:8000|Time:5.5727s...10s para estabilização.
# Linha 396: Gerando matrizes 6000x6000...Fim:EXP_0394|Size:6000|Time:2.4097s...10s para estabilização.
# Linha 397: Gerando matrizes 6000x6000...Fim:EXP_0448|Size:6000|Time:2.4996s...10s para estabilização.
# Linha 398: Gerando matrizes 8000x8000...Fim:EXP_0546|Size:8000|Time:6.1188s...10s para estabilização.
# Linha 399: Gerando matrizes 6000x6000...Fim:EXP_0396|Size:6000|Time:2.2432s...10s para estabilização.
# Linha 400: Gerando matrizes 8000x8000...Fim:EXP_0567|Size:8000|Time:5.4425s...10s para estabilização.
# Linha 401: Gerando matrizes 6000x6000...Fim:EXP_0403|Size:6000|Time:2.2438s...10s para estabilização.
# Linha 402: Gerando matrizes 6000x6000...Fim:EXP_0387|Size:6000|Time:1.7818s...10s para estabilização.
# Linha 403: Gerando matrizes 8000x8000...Fim:EXP_0581|Size:8000|Time:10.2417s...10s para estabilização.
# Linha 404: Gerando matrizes 4000x4000...Fim:EXP_0295|Size:4000|Time:0.7279s...10s para estabilização.
# Linha 405: Gerando matrizes 8000x8000...Fim:EXP_0501|Size:8000|Time:4.0598s...10s para estabilização.
# Linha 406: Gerando matrizes 8000x8000...Fim:EXP_0483|Size:8000|Time:2.5147s...10s para estabilização.
# Linha 407: Gerando matrizes 6000x6000...Fim:EXP_0416|Size:6000|Time:1.6882s...10s para estabilização.
# Linha 408: Gerando matrizes 1000x1000...Fim:EXP_0113|Size:1000|Time:0.0317s...10s para estabilização.
# Linha 409: Gerando matrizes 2000x2000...Fim:EXP_0180|Size:2000|Time:0.0981s...10s para estabilização.
# Linha 410: Gerando matrizes 6000x6000...Fim:EXP_0422|Size:6000|Time:2.4865s...10s para estabilização.
# Linha 411: Gerando matrizes 6000x6000...Fim:EXP_0468|Size:6000|Time:4.7112s...10s para estabilização.
# Linha 412: Gerando matrizes 6000x6000...Fim:EXP_0450|Size:6000|Time:2.3543s...10s para estabilização.
# Linha 413: Gerando matrizes 6000x6000...Fim:EXP_0374|Size:6000|Time:2.4022s...10s para estabilização.
# Linha 414: Gerando matrizes 4000x4000...Fim:EXP_0315|Size:4000|Time:0.7517s...10s para estabilização.
# Linha 415: Gerando matrizes 2000x2000...Fim:EXP_0152|Size:2000|Time:0.0907s...10s para estabilização.
# Linha 416: Gerando matrizes 8000x8000...Fim:EXP_0583|Size:8000|Time:6.0068s...10s para estabilização.
# Linha 417: Gerando matrizes 2000x2000...Fim:EXP_0234|Size:2000|Time:0.1076s...10s para estabilização.
# Linha 418: Gerando matrizes 4000x4000...Fim:EXP_0307|Size:4000|Time:0.7117s...10s para estabilização.
# Linha 419: Gerando matrizes 8000x8000...Fim:EXP_0550|Size:8000|Time:5.7113s...10s para estabilização.
# Linha 420: Gerando matrizes 2000x2000...Fim:EXP_0165|Size:2000|Time:0.0963s...10s para estabilização.
# Linha 421: Gerando matrizes 4000x4000...Fim:EXP_0318|Size:4000|Time:0.7510s...10s para estabilização.
# Linha 422: Gerando matrizes 2000x2000...Fim:EXP_0137|Size:2000|Time:0.0965s...10s para estabilização.
# Linha 423: Gerando matrizes 6000x6000...Fim:EXP_0411|Size:6000|Time:1.6905s...10s para estabilização.
# Linha 424: Gerando matrizes 2000x2000...Fim:EXP_0198|Size:2000|Time:0.1086s...10s para estabilização.
# Linha 425: Gerando matrizes 8000x8000...Fim:EXP_0569|Size:8000|Time:6.1118s...10s para estabilização.
# Linha 426: Gerando matrizes 4000x4000...Fim:EXP_0259|Size:4000|Time:0.7240s...10s para estabilização.
# Linha 427: Gerando matrizes 2000x2000...Fim:EXP_0233|Size:2000|Time:0.1062s...10s para estabilização.
# Linha 428: Gerando matrizes 1000x1000...Fim:EXP_0116|Size:1000|Time:0.0338s...10s para estabilização.
# Linha 429: Gerando matrizes 2000x2000...Fim:EXP_0121|Size:2000|Time:0.0964s...10s para estabilização.
# Linha 430: Gerando matrizes 8000x8000...Fim:EXP_0489|Size:8000|Time:4.1465s...10s para estabilização.
# Linha 431: Gerando matrizes 6000x6000...Fim:EXP_0377|Size:6000|Time:1.0957s...10s para estabilização.
# Linha 432: Gerando matrizes 6000x6000...Fim:EXP_0385|Size:6000|Time:1.0938s...10s para estabilização.
# Linha 433: Gerando matrizes 2000x2000...Fim:EXP_0225|Size:2000|Time:0.1064s...10s para estabilização.
# Linha 434: Gerando matrizes 8000x8000...Fim:EXP_0568|Size:8000|Time:5.4505s...10s para estabilização.
# Linha 435: Gerando matrizes 6000x6000...Fim:EXP_0457|Size:6000|Time:4.7106s...10s para estabilização.
# Linha 436: Gerando matrizes 4000x4000...Fim:EXP_0348|Size:4000|Time:0.7713s...10s para estabilização.
# Linha 437: Gerando matrizes 2000x2000...Fim:EXP_0128|Size:2000|Time:0.0974s...10s para estabilização.
# Linha 438: Gerando matrizes 8000x8000...Fim:EXP_0591|Size:8000|Time:5.9738s...10s para estabilização.
# Linha 439: Gerando matrizes 4000x4000...Fim:EXP_0286|Size:4000|Time:0.6707s...10s para estabilização.
# Linha 440: Gerando matrizes 8000x8000...Fim:EXP_0554|Size:8000|Time:5.4789s...10s para estabilização.
# Linha 441: Gerando matrizes 1000x1000...Fim:EXP_0044|Size:1000|Time:0.0231s...10s para estabilização.
# Linha 442: Gerando matrizes 1000x1000...Fim:EXP_0108|Size:1000|Time:0.0313s...10s para estabilização.
# Linha 443: Gerando matrizes 8000x8000...Fim:EXP_0565|Size:8000|Time:15.3860s...10s para estabilização.
# Linha 444: Gerando matrizes 6000x6000...Fim:EXP_0445|Size:6000|Time:2.6512s...10s para estabilização.
# Linha 445: Gerando matrizes 2000x2000...Fim:EXP_0134|Size:2000|Time:0.0980s...10s para estabilização.
# Linha 446: Gerando matrizes 8000x8000...Fim:EXP_0496|Size:8000|Time:2.5366s...10s para estabilização.
# Linha 447: Gerando matrizes 1000x1000...Fim:EXP_0045|Size:1000|Time:0.0164s...10s para estabilização.
# Linha 448: Gerando matrizes 2000x2000...Fim:EXP_0170|Size:2000|Time:0.0727s...10s para estabilização.
# Linha 449: Gerando matrizes 1000x1000...Fim:EXP_0066|Size:1000|Time:0.0229s...10s para estabilização.
# Linha 450: Gerando matrizes 4000x4000...Fim:EXP_0284|Size:4000|Time:0.6617s...10s para estabilização.
# Linha 451: Gerando matrizes 1000x1000...Fim:EXP_0086|Size:1000|Time:0.0232s...10s para estabilização.
# Linha 452: Gerando matrizes 4000x4000...Fim:EXP_0243|Size:4000|Time:0.7193s...10s para estabilização.
# Linha 453: Gerando matrizes 2000x2000...Fim:EXP_0187|Size:2000|Time:0.1057s...10s para estabilização.
# Linha 454: Gerando matrizes 4000x4000...Fim:EXP_0327|Size:4000|Time:0.7977s...10s para estabilização.
# Linha 455: Gerando matrizes 2000x2000...Fim:EXP_0160|Size:2000|Time:0.0958s...10s para estabilização.
# Linha 456: Gerando matrizes 1000x1000...Fim:EXP_0013|Size:1000|Time:0.0169s...10s para estabilização.
# Linha 457: Gerando matrizes 1000x1000...Fim:EXP_0036|Size:1000|Time:0.0211s...10s para estabilização.
# Linha 458: Gerando matrizes 1000x1000...Fim:EXP_0029|Size:1000|Time:0.0236s...10s para estabilização.
# Linha 459: Gerando matrizes 2000x2000...Fim:EXP_0171|Size:2000|Time:0.1008s...10s para estabilização.
# Linha 460: Gerando matrizes 2000x2000...Fim:EXP_0143|Size:2000|Time:0.1043s...10s para estabilização.
# Linha 461: Gerando matrizes 2000x2000...Fim:EXP_0237|Size:2000|Time:0.1115s...10s para estabilização.
# Linha 462: Gerando matrizes 6000x6000...Fim:EXP_0464|Size:6000|Time:4.7065s...10s para estabilização.
# Linha 463: Gerando matrizes 8000x8000...Fim:EXP_0497|Size:8000|Time:5.5736s...10s para estabilização.
# Linha 464: Gerando matrizes 2000x2000...Fim:EXP_0222|Size:2000|Time:0.1067s...10s para estabilização.
# Linha 465: Gerando matrizes 8000x8000...Fim:EXP_0545|Size:8000|Time:5.3489s...10s para estabilização.
# Linha 466: Gerando matrizes 1000x1000...Fim:EXP_0096|Size:1000|Time:0.0391s...10s para estabilização.
# Linha 467: Gerando matrizes 1000x1000...Fim:EXP_0052|Size:1000|Time:0.0185s...10s para estabilização.
# Linha 468: Gerando matrizes 4000x4000...Fim:EXP_0241|Size:4000|Time:0.5277s...10s para estabilização.
# Linha 469: Gerando matrizes 8000x8000...Fim:EXP_0508|Size:8000|Time:2.5347s...10s para estabilização.
# Linha 470: Gerando matrizes 4000x4000...Fim:EXP_0352|Size:4000|Time:0.7826s...10s para estabilização.
# Linha 471: Gerando matrizes 8000x8000...Fim:EXP_0517|Size:8000|Time:5.2543s...10s para estabilização.
# Linha 472: Gerando matrizes 2000x2000...Fim:EXP_0179|Size:2000|Time:0.0981s...10s para estabilização.
# Linha 473: Gerando matrizes 6000x6000...Fim:EXP_0461|Size:6000|Time:2.5788s...10s para estabilização.
# Linha 474: Gerando matrizes 8000x8000...Fim:EXP_0527|Size:8000|Time:5.5922s...10s para estabilização.
# Linha 475: Gerando matrizes 1000x1000...Fim:EXP_0042|Size:1000|Time:0.0194s...10s para estabilização.
# Linha 476: Gerando matrizes 8000x8000...Fim:EXP_0555|Size:8000|Time:5.7080s...10s para estabilização.
# Linha 477: Gerando matrizes 8000x8000...Fim:EXP_0523|Size:8000|Time:5.6090s...10s para estabilização.
# Linha 478: Gerando matrizes 2000x2000...Fim:EXP_0207|Size:2000|Time:0.1029s...10s para estabilização.
# Linha 479: Gerando matrizes 6000x6000...Fim:EXP_0393|Size:6000|Time:2.3974s...10s para estabilização.
# Linha 480: Gerando matrizes 4000x4000...Fim:EXP_0283|Size:4000|Time:0.7162s...10s para estabilização.
# Linha 481: Gerando matrizes 4000x4000...Fim:EXP_0359|Size:4000|Time:2.0453s...10s para estabilização.
# Linha 482: Gerando matrizes 6000x6000...Fim:EXP_0398|Size:6000|Time:2.3976s...10s para estabilização.
# Linha 483: Gerando matrizes 4000x4000...Fim:EXP_0255|Size:4000|Time:0.5302s...10s para estabilização.
# Linha 484: Gerando matrizes 2000x2000...Fim:EXP_0218|Size:2000|Time:0.1078s...10s para estabilização.
# Linha 485: Gerando matrizes 1000x1000...Fim:EXP_0005|Size:1000|Time:0.0174s...10s para estabilização.
# Linha 486: Gerando matrizes 4000x4000...Fim:EXP_0257|Size:4000|Time:0.3399s...10s para estabilização.
# Linha 487: Gerando matrizes 8000x8000...Fim:EXP_0564|Size:8000|Time:5.5660s...10s para estabilização.
# Linha 488: Gerando matrizes 8000x8000...Fim:EXP_0534|Size:8000|Time:5.2073s...10s para estabilização.
# Linha 489: Gerando matrizes 6000x6000...Fim:EXP_0431|Size:6000|Time:2.3543s...10s para estabilização.
# Linha 490: Gerando matrizes 1000x1000...Fim:EXP_0101|Size:1000|Time:0.0432s...10s para estabilização.
# Linha 491: Gerando matrizes 2000x2000...Fim:EXP_0227|Size:2000|Time:0.2614s...10s para estabilização.
# Linha 492: Gerando matrizes 6000x6000...Fim:EXP_0449|Size:6000|Time:2.3588s...10s para estabilização.
# Linha 493: Gerando matrizes 8000x8000...Fim:EXP_0548|Size:8000|Time:6.1284s...10s para estabilização.
# Linha 494: Gerando matrizes 8000x8000...Fim:EXP_0572|Size:8000|Time:10.2868s...10s para estabilização.
# Linha 495: Gerando matrizes 2000x2000...Fim:EXP_0214|Size:2000|Time:0.1068s...10s para estabilização.
# Linha 496: Gerando matrizes 4000x4000...Fim:EXP_0360|Size:4000|Time:1.3286s...10s para estabilização.
# Linha 497: Gerando matrizes 2000x2000...Fim:EXP_0172|Size:2000|Time:0.0968s...10s para estabilização.
# Linha 498: Gerando matrizes 1000x1000...Fim:EXP_0099|Size:1000|Time:0.0210s...10s para estabilização.
# Linha 499: Gerando matrizes 4000x4000...Fim:EXP_0293|Size:4000|Time:0.6706s...10s para estabilização.
# Linha 500: Gerando matrizes 2000x2000...Fim:EXP_0216|Size:2000|Time:0.1076s...10s para estabilização.
# Linha 501: Gerando matrizes 1000x1000...Fim:EXP_0062|Size:1000|Time:0.0192s...10s para estabilização.
# Linha 502: Gerando matrizes 6000x6000...Fim:EXP_0407|Size:6000|Time:2.2380s...10s para estabilização.
# Linha 503: Gerando matrizes 1000x1000...Fim:EXP_0048|Size:1000|Time:0.0161s...10s para estabilização.
# Linha 504: Gerando matrizes 1000x1000...Fim:EXP_0033|Size:1000|Time:0.0193s...10s para estabilização.
# Linha 505: Gerando matrizes 6000x6000...Fim:EXP_0418|Size:6000|Time:2.3561s...10s para estabilização.
# Linha 506: Gerando matrizes 4000x4000...Fim:EXP_0268|Size:4000|Time:0.7517s...10s para estabilização.
# Linha 507: Gerando matrizes 4000x4000...Fim:EXP_0328|Size:4000|Time:0.7345s...10s para estabilização.
# Linha 508: Gerando matrizes 2000x2000...Fim:EXP_0201|Size:2000|Time:0.1095s...10s para estabilização.
# Linha 509: Gerando matrizes 2000x2000...Fim:EXP_0135|Size:2000|Time:0.0977s...10s para estabilização.
# Linha 510: Gerando matrizes 1000x1000...Fim:EXP_0028|Size:1000|Time:0.0225s...10s para estabilização.
# Linha 511: Gerando matrizes 8000x8000...Fim:EXP_0525|Size:8000|Time:3.9313s...10s para estabilização.
# Linha 512: Gerando matrizes 8000x8000...Fim:EXP_0506|Size:8000|Time:4.0544s...10s para estabilização.
# Linha 513: Gerando matrizes 2000x2000...Fim:EXP_0231|Size:2000|Time:0.1065s...10s para estabilização.
# Linha 514: Gerando matrizes 8000x8000...Fim:EXP_0490|Size:8000|Time:5.4389s...10s para estabilização.
# Linha 515: Gerando matrizes 4000x4000...Fim:EXP_0261|Size:4000|Time:0.7453s...10s para estabilização.
# Linha 516: Gerando matrizes 6000x6000...Fim:EXP_0379|Size:6000|Time:1.0885s...10s para estabilização.
# Linha 517: Gerando matrizes 4000x4000...Fim:EXP_0289|Size:4000|Time:0.5231s...10s para estabilização.
# Linha 518: Gerando matrizes 6000x6000...Fim:EXP_0419|Size:6000|Time:2.4160s...10s para estabilização.
# Linha 519: Gerando matrizes 6000x6000...Fim:EXP_0392|Size:6000|Time:3.0920s...10s para estabilização.
# Linha 520: Gerando matrizes 8000x8000...Fim:EXP_0499|Size:8000|Time:5.7549s...10s para estabilização.
# Linha 521: Gerando matrizes 2000x2000...Fim:EXP_0139|Size:2000|Time:0.0787s...10s para estabilização.
# Linha 522: Gerando matrizes 1000x1000...Fim:EXP_0063|Size:1000|Time:0.0370s...10s para estabilização.
# Linha 523: Gerando matrizes 6000x6000...Fim:EXP_0472|Size:6000|Time:6.8392s...10s para estabilização.
# Linha 524: Gerando matrizes 2000x2000...Fim:EXP_0129|Size:2000|Time:0.0936s...10s para estabilização.
# Linha 525: Gerando matrizes 8000x8000...Fim:EXP_0584|Size:8000|Time:5.9699s...10s para estabilização.
# Linha 526: Gerando matrizes 8000x8000...Fim:EXP_0521|Size:8000|Time:5.2238s...10s para estabilização.
# Linha 527: Gerando matrizes 1000x1000...Fim:EXP_0065|Size:1000|Time:0.0321s...10s para estabilização.
# Linha 528: Gerando matrizes 1000x1000...Fim:EXP_0015|Size:1000|Time:0.0172s...10s para estabilização.
# Linha 529: Gerando matrizes 2000x2000...Fim:EXP_0157|Size:2000|Time:0.0750s...10s para estabilização.
# Linha 530: Gerando matrizes 1000x1000...Fim:EXP_0041|Size:1000|Time:0.0228s...10s para estabilização.
# Linha 531: Gerando matrizes 8000x8000...Fim:EXP_0493|Size:8000|Time:4.0552s...10s para estabilização.
# Linha 532: Gerando matrizes 6000x6000...Fim:EXP_0380|Size:6000|Time:1.0874s...10s para estabilização.
# Linha 533: Gerando matrizes 2000x2000...Fim:EXP_0188|Size:2000|Time:0.1943s...10s para estabilização.
# Linha 534: Gerando matrizes 2000x2000...Fim:EXP_0217|Size:2000|Time:0.2728s...10s para estabilização.
# Linha 535: Gerando matrizes 1000x1000...Fim:EXP_0053|Size:1000|Time:0.0168s...10s para estabilização.
# Linha 536: Gerando matrizes 4000x4000...Fim:EXP_0338|Size:4000|Time:1.9666s...10s para estabilização.
# Linha 537: Gerando matrizes 4000x4000...Fim:EXP_0296|Size:4000|Time:0.7167s...10s para estabilização.
# Linha 538: Gerando matrizes 4000x4000...Fim:EXP_0252|Size:4000|Time:0.5308s...10s para estabilização.
# Linha 539: Gerando matrizes 6000x6000...Fim:EXP_0462|Size:6000|Time:2.5758s...10s para estabilização.
# Linha 540: Gerando matrizes 6000x6000...Fim:EXP_0456|Size:6000|Time:2.5668s...10s para estabilização.
# Linha 541: Gerando matrizes 8000x8000...Fim:EXP_0598|Size:8000|Time:5.9487s...10s para estabilização.
# Linha 542: Gerando matrizes 4000x4000...Fim:EXP_0270|Size:4000|Time:0.7260s...10s para estabilização.
# Linha 543: Gerando matrizes 2000x2000...Fim:EXP_0202|Size:2000|Time:0.1096s...10s para estabilização.
# Linha 544: Gerando matrizes 2000x2000...Fim:EXP_0162|Size:2000|Time:0.0887s...10s para estabilização.
# Linha 545: Gerando matrizes 6000x6000...Fim:EXP_0402|Size:6000|Time:2.4138s...10s para estabilização.
# Linha 546: Gerando matrizes 6000x6000...Fim:EXP_0477|Size:6000|Time:4.7092s...10s para estabilização.
# Linha 547: Gerando matrizes 1000x1000...Fim:EXP_0106|Size:1000|Time:0.0402s...10s para estabilização.
# Linha 548: Gerando matrizes 6000x6000...Fim:EXP_0390|Size:6000|Time:2.3998s...10s para estabilização.
# Linha 549: Gerando matrizes 1000x1000...Fim:EXP_0002|Size:1000|Time:0.0122s...10s para estabilização.
# Linha 550: Gerando matrizes 8000x8000...Fim:EXP_0559|Size:8000|Time:5.4415s...10s para estabilização.
# Linha 551: Gerando matrizes 1000x1000...Fim:EXP_0081|Size:1000|Time:0.0223s...10s para estabilização.
# Linha 552: Gerando matrizes 2000x2000...Fim:EXP_0206|Size:2000|Time:0.1822s...10s para estabilização.
# Linha 553: Gerando matrizes 1000x1000...Fim:EXP_0035|Size:1000|Time:0.0158s...10s para estabilização.
# Linha 554: Gerando matrizes 8000x8000...Fim:EXP_0509|Size:8000|Time:4.0014s...10s para estabilização.
# Linha 555: Gerando matrizes 6000x6000...Fim:EXP_0428|Size:6000|Time:2.4066s...10s para estabilização.
# Linha 556: Gerando matrizes 6000x6000...Fim:EXP_0455|Size:6000|Time:6.8408s...10s para estabilização.
# Linha 557: Gerando matrizes 6000x6000...Fim:EXP_0367|Size:6000|Time:2.3365s...10s para estabilização.
# Linha 558: Gerando matrizes 1000x1000...Fim:EXP_0092|Size:1000|Time:0.0337s...10s para estabilização.
# Linha 559: Gerando matrizes 4000x4000...Fim:EXP_0340|Size:4000|Time:0.7726s...10s para estabilização.
# Linha 560: Gerando matrizes 4000x4000...Fim:EXP_0346|Size:4000|Time:0.7720s...10s para estabilização.
# Linha 561: Gerando matrizes 4000x4000...Fim:EXP_0242|Size:4000|Time:0.7218s...10s para estabilização.
# Linha 562: Gerando matrizes 1000x1000...Fim:EXP_0014|Size:1000|Time:0.0164s...10s para estabilização.
# Linha 563: Gerando matrizes 4000x4000...Fim:EXP_0316|Size:4000|Time:0.7341s...10s para estabilização.
# Linha 564: Gerando matrizes 6000x6000...Fim:EXP_0388|Size:6000|Time:2.3897s...10s para estabilização.
# Linha 565: Gerando matrizes 4000x4000...Fim:EXP_0274|Size:4000|Time:0.7215s...10s para estabilização.
# Linha 566: Gerando matrizes 2000x2000...Fim:EXP_0167|Size:2000|Time:0.0749s...10s para estabilização.
# Linha 567: Gerando matrizes 8000x8000...Fim:EXP_0595|Size:8000|Time:6.0019s...10s para estabilização.
# Linha 568: Gerando matrizes 8000x8000...Fim:EXP_0485|Size:8000|Time:5.6054s...10s para estabilização.
# Linha 569: Gerando matrizes 8000x8000...Fim:EXP_0586|Size:8000|Time:6.0166s...10s para estabilização.
# Linha 570: Gerando matrizes 8000x8000...Fim:EXP_0505|Size:8000|Time:5.5826s...10s para estabilização.
# Linha 571: Gerando matrizes 4000x4000...Fim:EXP_0244|Size:4000|Time:0.7457s...10s para estabilização.
# Linha 572: Gerando matrizes 8000x8000...Fim:EXP_0563|Size:8000|Time:5.5689s...10s para estabilização.
# Linha 573: Gerando matrizes 2000x2000...Fim:EXP_0190|Size:2000|Time:0.1096s...10s para estabilização.
# Linha 574: Gerando matrizes 6000x6000...Fim:EXP_0476|Size:6000|Time:4.7038s...10s para estabilização.
# Linha 575: Gerando matrizes 8000x8000...Fim:EXP_0511|Size:8000|Time:5.2234s...10s para estabilização.
# Linha 576: Gerando matrizes 1000x1000...Fim:EXP_0059|Size:1000|Time:0.0195s...10s para estabilização.
# Linha 577: Gerando matrizes 6000x6000...Fim:EXP_0475|Size:6000|Time:2.5798s...10s para estabilização.
# Linha 578: Gerando matrizes 8000x8000...Fim:EXP_0561|Size:8000|Time:5.6880s...10s para estabilização.
# Linha 579: Gerando matrizes 4000x4000...Fim:EXP_0253|Size:4000|Time:0.7238s...10s para estabilização.
# Linha 580: Gerando matrizes 1000x1000...Fim:EXP_0022|Size:1000|Time:0.0148s...10s para estabilização.
# Linha 581: Gerando matrizes 4000x4000...Fim:EXP_0314|Size:4000|Time:0.7341s...10s para estabilização.
# Linha 582: Gerando matrizes 6000x6000...Fim:EXP_0460|Size:6000|Time:4.4177s...10s para estabilização.
# Linha 583: Gerando matrizes 2000x2000...Fim:EXP_0161|Size:2000|Time:0.0964s...10s para estabilização.
# Linha 584: Gerando matrizes 4000x4000...Fim:EXP_0277|Size:4000|Time:0.5176s...10s para estabilização.
# Linha 585: Gerando matrizes 2000x2000...Fim:EXP_0192|Size:2000|Time:0.1015s...10s para estabilização.
# Linha 586: Gerando matrizes 6000x6000...Fim:EXP_0386|Size:6000|Time:2.3956s...10s para estabilização.
# Linha 587: Gerando matrizes 6000x6000...Fim:EXP_0414|Size:6000|Time:1.7629s...10s para estabilização.
# Linha 588: Gerando matrizes 8000x8000...Fim:EXP_0492|Size:8000|Time:4.0542s...10s para estabilização.
# Linha 589: Gerando matrizes 4000x4000...Fim:EXP_0344|Size:4000|Time:0.7791s...10s para estabilização.
# Linha 590: Gerando matrizes 4000x4000...Fim:EXP_0309|Size:4000|Time:0.6990s...10s para estabilização.
# Linha 591: Gerando matrizes 2000x2000...Fim:EXP_0131|Size:2000|Time:0.0966s...10s para estabilização.
# Linha 592: Gerando matrizes 1000x1000...Fim:EXP_0100|Size:1000|Time:0.0313s...10s para estabilização.
# Linha 593: Gerando matrizes 6000x6000...Fim:EXP_0373|Size:6000|Time:2.3994s...10s para estabilização.
# Linha 594: Gerando matrizes 1000x1000...Fim:EXP_0088|Size:1000|Time:0.0206s...10s para estabilização.
# Linha 595: Gerando matrizes 6000x6000...Fim:EXP_0459|Size:6000|Time:4.7098s...10s para estabilização.
# Linha 596: Gerando matrizes 4000x4000...Fim:EXP_0331|Size:4000|Time:0.7715s...10s para estabilização.
# Linha 597: Gerando matrizes 2000x2000...Fim:EXP_0215|Size:2000|Time:0.1072s...10s para estabilização.
# Linha 598: Gerando matrizes 6000x6000...Fim:EXP_0467|Size:6000|Time:2.5651s...10s para estabilização.
# Linha 599: Gerando matrizes 2000x2000...Fim:EXP_0122|Size:2000|Time:0.0965s...10s para estabilização.
# Linha 600: Gerando matrizes 1000x1000...Fim:EXP_0021|Size:1000|Time:0.0163s...10s para estabilização.
# Linha 601: Gerando matrizes 1000x1000...Fim:EXP_0072|Size:1000|Time:0.0322s...10s para estabilização.
# Linha 602: Gerando matrizes 1000x1000...Fim:EXP_0107|Size:1000|Time:0.0480s...10s para estabilização.
# Linha 603: Gerando matrizes 4000x4000...Fim:EXP_0271|Size:4000|Time:0.6629s...10s para estabilização.
# Linha 604: Gerando matrizes 6000x6000...Fim:EXP_0436|Size:6000|Time:2.3325s...10s para estabilização.
# Linha 605: Gerando matrizes 1000x1000...Fim:EXP_0103|Size:1000|Time:0.0489s...10s para estabilização.
#
# Todos os experimentos do plano foram concluídos.
