# %% [markdown]
# # Trabalho Final - Parte 2 - Parcial
#
# # Experimentos
#
# - Sempre 8 processos
# - Implementações com multiprocessamento
#   - Uso do módulo **multiprocessing**
# - Cada processo em um core (físico ou lógico)
#   - Sem alocação de 2 processos/threads no mesmo core
#   - **Definição de afinidade**: Cada thread em um core
# - Setar governor para **performance**

# %%
# !lscpu --extended
# Out:
# CPU NODE SOCKET CORE L1d:L1i:L2:L3 ONLINE    MAXMHZ   MINMHZ       MHZ
#   0    0      0    0 0:0:0:0          sim 5000,0000 800,0000 4999,1479
#   1    0      0    0 0:0:0:0          sim 5000,0000 800,0000 4613,4771
#   2    0      0    1 4:4:1:0          sim 5000,0000 800,0000  800,0000
#   3    0      0    1 4:4:1:0          sim 5000,0000 800,0000  800,0000
#   4    0      0    2 8:8:2:0          sim 5000,0000 800,0000  800,0000
#   5    0      0    2 8:8:2:0          sim 5000,0000 800,0000  800,0000
#   6    0      0    3 12:12:3:0        sim 5000,0000 800,0000  800,0000
#   7    0      0    3 12:12:3:0        sim 5000,0000 800,0000  800,0000
#   8    0      0    4 16:16:4:0        sim 5200,0000 800,0000  800,3010
#   9    0      0    4 16:16:4:0        sim 5200,0000 800,0000  800,0000
#  10    0      0    5 20:20:5:0        sim 5200,0000 800,0000 1057,3130
#  11    0      0    5 20:20:5:0        sim 5200,0000 800,0000 4895,2119
#  12    0      0    6 24:24:6:0        sim 5000,0000 800,0000 3862,8101
#  13    0      0    6 24:24:6:0        sim 5000,0000 800,0000  800,0000
#  14    0      0    7 28:28:7:0        sim 5000,0000 800,0000  800,0000
#  15    0      0    7 28:28:7:0        sim 5000,0000 800,0000  800,0000
#  16    0      0    8 32:32:8:0        sim 3700,0000 800,0000 3699,4170
#  17    0      0    9 33:33:8:0        sim 3700,0000 800,0000  800,0000
#  18    0      0   10 34:34:8:0        sim 3700,0000 800,0000  800,0000
#  19    0      0   11 35:35:8:0        sim 3700,0000 800,0000  800,0000
#  20    0      0   12 36:36:9:0        sim 3700,0000 800,0000  800,0000
#  21    0      0   13 37:37:9:0        sim 3700,0000 800,0000  800,0000
#  22    0      0   14 38:38:9:0        sim 3700,0000 800,0000  800,0000
#  23    0      0   15 39:39:9:0        sim 3700,0000 800,0000  800,0000
#  24    0      0   16 40:40:10:0       sim 3700,0000 800,0000  800,0000
#  25    0      0   17 41:41:10:0       sim 3700,0000 800,0000  800,0000
#  26    0      0   18 42:42:10:0       sim 3700,0000 800,0000  800,0000
#  27    0      0   19 43:43:10:0       sim 3700,0000 800,0000  800,0000

# %% [markdown]
# # Aplicação: Multiplicação de Matrizes
#
#
# ## Cenário 1
#
# - p-cores: Enabled
# - e-cores: Enabled
# - Hyper-Threading: Enabled
# - Turbo Boost: Enabled
#
# CPU_ID = [0, 1, 2, 3, 4, 5, 6, 7]
#
# - Processo 0: CPU 0 - CORE 0
# - Processo 1: CPU 1 - CORE 0
# - Processo 2: CPU 2 - CORE 1
# - Processo 3: CPU 3 - CORE 1
# - Processo 4: CPU 4 - CORE 2
# - Processo 5: CPU 5 - CORE 2
# - Processo 6: CPU 6 - CORE 3
# - Processo 7: CPU 7 - CORE 3

# %%
import multiprocessing as mp
import psutil
import getpass
import os
import time
import numpy as np
import pandas as pd
from datetime import datetime

# --------------------------------------
# CONFIGURATION

MATRIX_SIZE = 4000  # size of NxN matrices
CPU_SETS = {
    "p-cores 1 thread": [0, 2, 4, 6, 8, 10, 12, 14], # p-cores (8 cores, 1 thread per core)
    "p-cores 2 threads": [0, 1, 2, 3, 4, 5, 6, 7], # p-cores (4 cores, 2 threads per core)
    "p-cores & e-cores 50-50": [0, 2, 4, 6, 16, 17, 18, 19], # p-cores e e-cores (4 cores p-core, 4 cores e-core)
    "e-cores": [16, 17, 18, 19, 20, 21, 22, 23] # e-cores (8 cores, 1 thread per core)
}
NUM_RUNS = 5   # runs per CPU set
GOVERNOR = "performance"
IDLE_TIME = 5  # segundos entre execuções

# --------------------------------------
# Safety check
def safety_check(cpu_ids):
    if MATRIX_SIZE % len(cpu_ids) != 0:
        print(f"Error: MATRIX_SIZE ({MATRIX_SIZE}) is not divisible by number of workers ({len(cpu_ids)}).")
        sys.exit(1)

# --------------------------------------
# Governor configuration
def set_governor(governor: str):
    """
    Altera o CPU governor de todos os núcleos para o valor especificado.

    Parâmetros:
        governor (str): nome do governor (ex.: "performance", "powersave", "schedutil").
    """
    password = getpass.getpass("Sudo password: ")

    # Interpolamos o valor do parâmetro governor dirTempetamente no comando bash
    bash_command = f"""
    for cpu_file in $(ls -v /sys/devices/system/cpu/cpu*/cpufreq/scaling_governor); do
        cpu_name=$(basename $(dirname $(dirname $cpu_file)))
        echo performance | sudo tee $cpu_file > /dev/null
        echo "$cpu_name: performance"
    done
    """

    # Usa sudo -S para aceitar senha via stdin
    command = f'echo "{password}" | sudo -S bash -c \'{bash_command}\''
    os.system(command)    
        
# --------------------------------------
# Governor detection
def get_governor(cpu_id):
    path = f"/sys/devices/system/cpu/cpu{cpu_id}/cpufreq/scaling_governor"
    try:
        with open(path) as f:
            return f.read().strip()
    except FileNotFoundError:
        return "N/A"

# --------------------------------------
# Worker task: compute one row chunk of matrix multiplication
def worker_task(args):
    row_chunk, A_chunk, B, cpu_ids = args
    p = psutil.Process(os.getpid())
    # Assign affinity based on worker ID
    p.cpu_affinity([cpu_ids[row_chunk % len(cpu_ids)]])
    return np.dot(A_chunk, B)

# --------------------------------------
# Main execution loop
if __name__ == "__main__":
    
    print("Passo 1: Configurar governor")
    set_governor(GOVERNOR)
    
    results = []  # lista para armazenar resultados
    
    print("Passo 2: Execuções")
    for run in range(1, NUM_RUNS + 1):        
        for label, cores in CPU_SETS.items():
            # Garantir que o workload será dividido igualmente
            safety_check(cores)
            
            # Garantir que o governor está correto
            governor = get_governor(cores[0])
            
            # Initialize matrices
            A = np.random.rand(MATRIX_SIZE, MATRIX_SIZE).astype(np.float64)
            B = np.random.rand(MATRIX_SIZE, MATRIX_SIZE).astype(np.float64)

            # Split A into chunks by rows
            chunk_size = MATRIX_SIZE // len(cores)
            A_chunks = [A[i*chunk_size:(i+1)*chunk_size, :] for i in range(len(cores))]
            tasks = [(i, A_chunks[i], B, cores) for i in range(len(cores))]

            # Start timing
            start_time = time.time()
            
            with mp.Pool(processes=len(cores)) as pool:
                C_chunks = pool.map(worker_task, tasks)
            
            C = np.vstack(C_chunks)  # combine results

            end_time = time.time()
            total_time = end_time - start_time
                        
            # salva os dados em um dataFrame
            results.append({
                "Run": run,
                "Scenario": label,
                "CPUs_used": cores,
                "Governor": governor,
                "Time_sec": total_time,
                "Result_shape": C.shape
            })
            
            print(f"Run {run} | {label}: {cores} | Governor: {governor} | Time: {total_time}")

            # Idle para estabilizar
            print(f"Aguardando {IDLE_TIME} segundos para estabilização...\n")
            time.sleep(IDLE_TIME)
            
    # cria dataframe com todos os resultados
    df_results = pd.DataFrame(results)
    pd.set_option('display.width', 1000) # Evita quebra de linha do print do df  
    df_reduced = df_results[["Run", "Scenario", "Governor", "Time_sec"]]
    df_sorted = df_reduced.sort_values(by="Scenario", ascending=False)
    print("\nResumo em DataFrame:\n", df_sorted)
    
    # salvar em CSV
    now = datetime.now()
    data_str = now.strftime("%Y%m%d") # formato aaaammdd
    hora_str = now.strftime("%H%M%S") # formato hhmmss
    filename = (
    f"{data_str}_{hora_str}_matrix{MATRIX_SIZE}_"
        f"numruns{NUM_RUNS}_{GOVERNOR}.csv"
    )
    df_results.to_csv(filename, index=False)
    print(f"\nResultados salvos em: {filename}")
# Out:
# Passo 1: Configurar governor
# Sudo password: ········
# [sudo] senha para jgross:
# cpu0: performance
# cpu1: performance
# cpu2: performance
# cpu3: performance
# cpu4: performance
# cpu5: performance
# cpu6: performance
# cpu7: performance
# cpu8: performance
# cpu9: performance
# cpu10: performance
# cpu11: performance
# cpu12: performance
# cpu13: performance
# cpu14: performance
# cpu15: performance
# cpu16: performance
# cpu17: performance
# cpu18: performance
# cpu19: performance
# cpu20: performance
# cpu21: performance
# cpu22: performance
# cpu23: performance
# cpu24: performance
# cpu25: performance
# cpu26: performance
# cpu27: performance
# Passo 2: Execuções
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 104
#     101 start_time = time.time()
#     103 with mp.Pool(processes=len(cores)) as pool:
# --> 104     C_chunks = pool.map(worker_task, tasks)
#     106 C = np.vstack(C_chunks)  # combine results
#     108 end_time = time.time()
#
# File /usr/lib/python3.12/multiprocessing/pool.py:367, in Pool.map(self, func, iterable, chunksize)
#     362 def map(self, func, iterable, chunksize=None):
#     363     '''
#     364     Apply `func` to each element in `iterable`, collecting the results
#     365     in a list that is returned.
#     366     '''
# --> 367     return self._map_async(func, iterable, mapstar, chunksize).get()
#
# File /usr/lib/python3.12/multiprocessing/pool.py:768, in ApplyResult.get(self, timeout)
#     767 def get(self, timeout=None):
# --> 768     self.wait(timeout)
#     769     if not self.ready():
#     770         raise TimeoutError
#
# File /usr/lib/python3.12/multiprocessing/pool.py:765, in ApplyResult.wait(self, timeout)
#     764 def wait(self, timeout=None):
# --> 765     self._event.wait(timeout)
#
# File /usr/lib/python3.12/threading.py:655, in Event.wait(self, timeout)
#     653 signaled = self._flag
#     654 if not signaled:
# --> 655     signaled = self._cond.wait(timeout)
#     656 return signaled
#
# File /usr/lib/python3.12/threading.py:355, in Condition.wait(self, timeout)
#     353 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     354     if timeout is None:
# --> 355         waiter.acquire()
#     356         gotit = True
#     357     else:
#
# KeyboardInterrupt:

# %%
# !dir 2025*
# Out:
#  O volume na unidade D ‚ Dados
#  O N£mero de S‚rie do Volume ‚ 6ED4-9502
#
#  Pasta de D:\OneDrive - TJRS\UFRGS\Doutorado\CMP223 - Computer System Performance Analysis\TF-cmp223\02-Parcial
#
# 01/10/2025  18:03             1.979 20251001_125152_matrix4000_numruns5_performance.csv
# 01/10/2025  18:03             1.975 20251001_135526_matrix4000_numruns5_performance.csv
#                2 arquivo(s)          3.954 bytes
#                0 pasta(s)   100.511.047.680 bytes dispon¡veis

# %%
df = pd.read_csv('20251001_125152_matrix4000_numruns5_performance.csv')
df_reduced = df[["Run", "Scenario", "Governor", "Time_sec"]]
print(df_reduced)
# Out:
#     Run                 Scenario     Governor   Time_sec
# 0     1         p-cores 1 thread  performance  18.116111
# 1     1        p-cores 2 threads  performance  17.734265
# 2     1  p-cores & e-cores 50-50  performance  17.927179
# 3     1                  e-cores  performance  17.600912
# 4     2         p-cores 1 thread  performance  17.897818
# 5     2        p-cores 2 threads  performance  17.989774
# 6     2  p-cores & e-cores 50-50  performance  18.150260
# 7     2                  e-cores  performance  18.400618
# 8     3         p-cores 1 thread  performance  18.398459
# 9     3        p-cores 2 threads  performance  18.355381
# 10    3  p-cores & e-cores 50-50  performance  18.431963
# 11    3                  e-cores  performance  18.391407
# 12    4         p-cores 1 thread  performance  18.398753
# 13    4        p-cores 2 threads  performance  18.349900
# 14    4  p-cores & e-cores 50-50  performance  18.893671
# 15    4                  e-cores  performance  18.659064
# 16    5         p-cores 1 thread  performance  18.555177
# 17    5        p-cores 2 threads  performance  18.241892
# 18    5  p-cores & e-cores 50-50  performance  18.442300
# 19    5                  e-cores  performance  19.061472

# %%
pd.set_option('display.width', 1000) # Evita quebra de linha do print do df

df = pd.read_csv('20251001_135526_matrix4000_numruns5_performance.csv')
df_reduced = df[["Run", "Scenario", "Governor", "Time_sec"]]
df_sorted = df_reduced.sort_values(by="Scenario", ascending=False)
print(df_sorted)
# Out:
#     Run                 Scenario     Governor   Time_sec
# 17    5        p-cores 2 threads  performance  25.106751
# 5     2        p-cores 2 threads  performance  24.581705
# 9     3        p-cores 2 threads  performance  24.865487
# 1     1        p-cores 2 threads  performance  24.975649
# 13    4        p-cores 2 threads  performance  25.006631
# 0     1         p-cores 1 thread  performance  20.149527
# 12    4         p-cores 1 thread  performance  20.242027
# 4     2         p-cores 1 thread  performance  20.322866
# 16    5         p-cores 1 thread  performance  20.333796
# 8     3         p-cores 1 thread  performance  20.292924
# 18    5  p-cores & e-cores 50-50  performance  40.502859
# 14    4  p-cores & e-cores 50-50  performance  40.575534
# 10    3  p-cores & e-cores 50-50  performance  40.961549
# 6     2  p-cores & e-cores 50-50  performance  40.581665
# 2     1  p-cores & e-cores 50-50  performance  40.544340
# 11    3                  e-cores  performance  42.115458
# 7     2                  e-cores  performance  40.669654
# 15    4                  e-cores  performance  41.053336
# 3     1                  e-cores  performance  41.801860
# 19    5                  e-cores  performance  40.477450

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Supondo que seus arquivos estejam em CSV
df1 = pd.read_csv('20251001_125152_matrix4000_numruns5_performance.csv') # Com Turbo Bost
df2 = pd.read_csv('20251001_135526_matrix4000_numruns5_performance.csv') # Sem Turbo Boost

df1['Dataset'] = 'TB-ON'
df2['Dataset'] = 'TB-OFF'

df_combined = pd.concat([df1, df2], ignore_index=True)

plt.figure(figsize=(10,6))
#sns.barplot(x='Scenario', y='Time_sec', hue='Dataset', data=df_combined, ci='sd')
sns.barplot(
    x='Scenario',
    y='Time_sec',
    hue='Dataset',
    data=df_combined,
    estimator='mean'       # calcula a média automaticamente
    #errorbar='sd'           # mostra desvio padrão
)
plt.title('Comparação de Tempo de Execução por Cenário (média ± desvio padrão)')
plt.ylabel('Tempo (segundos)')
plt.xlabel('Cenário')
plt.legend(title='Observações')

# Salvar como PDF
plt.savefig('grafico_time_sec.pdf', format='pdf', bbox_inches='tight')

# Salvar como PNG
plt.savefig('grafico_time_sec.png', format='png', dpi=300, bbox_inches='tight')

plt.show()
