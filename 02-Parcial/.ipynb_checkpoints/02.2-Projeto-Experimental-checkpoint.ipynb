# %% [markdown]
# # Trabalho Final - Parte 2 - Parcial
#
#
# # Projeto Experimental
#
# Cenários:
# 1. CPU governor
# 2. CPU driver
# 3. Freq max e min dos cores

# %% [markdown]
# ## Cenário 1
#
# - p-cores: Enabled
# - e-cores: Enabled
# - Hyper-Threading: Enabled
# - Turbo Boost: Enabled
#
# CPU_ID = [0, 1, 2, 3, 4, 5, 6, 7]
#
# - Processo 0: CPU 0 - CORE 0
# - Processo 1: CPU 1 - CORE 0
# - Processo 2: CPU 2 - CORE 1
# - Processo 3: CPU 3 - CORE 1
# - Processo 4: CPU 4 - CORE 2
# - Processo 5: CPU 5 - CORE 2
# - Processo 6: CPU 6 - CORE 3
# - Processo 7: CPU 7 - CORE 3

# %% [markdown]
# ## Cenário 2
#
# - p-cores: Enabled
# - e-cores: Enabled
# - Hyper-Threading: Disabled

# %% [markdown]
# ## Cenário 3
#
# - p-cores: Enabled
# - e-cores: Disabled
# - Hyper-Threading: Disabled
