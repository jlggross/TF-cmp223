# %% [markdown]
# # Trabalho Final - Parte 2 - Parcial
#
#
# # Projeto Experimental
#
# Cenários:
# 1. CPU governor
# 2. CPU driver
# 3. Freq max e min dos cores

# %% [markdown]
# ## Cenário 1
#
# - p-cores: Enabled
# - e-cores: Disabled
# - Hyper-Threading: Disabled

# %% [markdown]
# ## Cenário 2
#
# - p-cores: Enabled
# - e-cores: Disabled
# - Hyper-Threading: Enabled

# %% [markdown]
# ## Cenário 3
#
# - p-cores: Enabled
# - e-cores: Enabled
# - Hyper-Threading: Enabled
